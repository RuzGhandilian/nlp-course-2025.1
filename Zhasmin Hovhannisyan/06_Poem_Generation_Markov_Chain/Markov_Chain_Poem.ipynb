# %% [markdown]
# # Markov Chain Poetry Generator
# Generate poetry in the style of Robert Frost's 'The Road Not Taken'

# %%
import random
import re
from collections import defaultdict

# %% [markdown]
# ## Step 1: Text Preprocessing
# Split into lines and process each line

# %%
with open('robert_frost.txt', 'r', encoding='utf-8') as file:
    poem_text = file.read()

# %%
# Split text into lines and filter out empty lines
lines = [line.strip() for line in poem_text.split('\n') if line.strip()]

print(f"Total number of lines: {len(lines)}")
print("\nLines in the poem:")
for i, line in enumerate(lines, 1):
    print(f"{i}. {line}")
# Out:
# Total number of lines: 1436
#
# Lines in the poem:
# 1. Two roads diverged in a yellow wood,
# 2. And sorry I could not travel both
# 3. And be one traveler, long I stood
# 4. And looked down one as far as I could
# 5. To where it bent in the undergrowth;
# 6. Then took the other, as just as fair,
# 7. And having perhaps the better claim
# 8. Because it was grassy and wanted wear,
# 9. Though as for that the passing there
# 10. Had worn them really about the same,
# 11. And both that morning equally lay
# 12. In leaves no step had trodden black.
# 13. Oh, I kept the first for another day!
# 14. Yet knowing how way leads on to way
# 15. I doubted if I should ever come back.
# 16. I shall be telling this with a sigh
# 17. Somewhere ages and ages hence:
# 18. Two roads diverged in a wood, and I,
# 19. I took the one less traveled by,
# 20. And that has made all the difference.
# 21. Whose woods these are I think I know.
# 22. His house is in the village, though;
# 23. He will not see me stopping here
# 24. To watch his woods fill up with snow.
# 25. My little horse must think it queer
# 26. To stop without a farmhouse near
# 27. Between the woods and frozen lake
# 28. The darkest evening of the year.
# 29. He gives his harness bells a shake
# 30. To ask if there is some mistake.
# 31. The only other sound's the sweep
# 32. Of easy wind and downy flake.
# 33. The woods are lovely, dark and deep,
# 34. But I have promises to keep,
# 35. And miles to go before I sleep,
# 36. And miles to go before I sleep.
# 37. Some say the world will end in fire,
# 38. Some say in ice.
# 39. From what I've tasted of desire
# 40. I hold with those who favor fire.
# 41. But if it had to perish twice,
# 42. I think I know enough of hate
# 43. To say that for destruction ice
# 44. Is also great
# 45. And would suffice.
# 46. Nature's first green is gold,
# 47. Her hardest hue to hold.
# 48. Her early leaf's a flower;
# 49. But only so an hour.
# 50. Then leaf subsides to leaf,
# 51. So Eden sank to grief,
# 52. So dawn goes down to day
# 53. Nothing gold can stay.
# 54. I have been one acquainted with the night.
# 55. I have walked out in rain - and back in rain.
# 56. I have outwalked the furthest city light.
# 57. I have looked down the saddest city lane.
# 58. I have passed by the watchman on his beat
# 59. And dropped my eyes, unwilling to explain.
# 60. I have stood still and stopped the sound of feet
# 61. When far away an interrupted cry
# 62. Came over houses from another street,
# 63. But not to call me back or say good-bye;
# 64. And further still at an unearthly height,
# 65. One luminary clock against the sky
# 66. Proclaimed the time was neither wrong nor right.
# 67. I have been one acquainted with the night.
# 68. When I go up through the mowing field,
# 69. The headless aftermath,
# 70. Smooth-laid like thatch with the heavy dew,
# 71. Half closes the garden path.
# 72. And when I come to the garden ground,
# 73. The whir of sober birds
# 74. Up from the tangle of withered weeds
# 75. Is sadder than any words
# 76. A tree beside the wall stands bare,
# 77. But a leaf that lingered brown,
# 78. Disturbed, I doubt not, by my thought,
# 79. Comes softly rattling down.
# 80. I end not far from my going forth
# 81. By picking the faded blue
# 82. Of the last remaining aster flower
# 83. To carry again to you.
# 84. A voice said, Look me in the stars
# 85. And tell me truly, men of earth,
# 86. If all the soul-and-body scars
# 87. Were not too much to pay for birth.
# 88. To think to know the country and now know
# 89. The hillside on the day the sun lets go
# 90. Ten million silver lizards out of snow!
# 91. As often as I've seen it done before
# 92. I can't pretend to tell the way it's done.
# 93. It looks as if some magic of the sun
# 94. Lifted the rug that bred them on the floor
# 95. And the light breaking on them made them run.
# 96. But if I though to stop the wet stampede,
# 97. And caught one silver lizard by the tail,
# 98. And put my foot on one without avail,
# 99. And threw myself wet-elbowed and wet-kneed
# 100. In front of twenty others' wriggling speed,-
# 101. In the confusion of them all aglitter,
# 102. And birds that joined in the excited fun
# 103. By doubling and redoubling song and twitter,
# 104. I have no doubt I'd end by holding none.
# 105. It takes the moon for this. The sun's a wizard
# 106. By all I tell; but so's the moon a witch.
# 107. From the high west she makes a gentle cast
# 108. And suddenly, without a jerk or twitch,
# 109. She has her speel on every single lizard.
# 110. I fancied when I looked at six o'clock
# 111. The swarm still ran and scuttled just as fast.
# 112. The moon was waiting for her chill effect.
# 113. I looked at nine: the swarm was turned to rock
# 114. In every lifelike posture of the swarm,
# 115. Transfixed on mountain slopes almost erect.
# 116. Across each other and side by side they lay.
# 117. The spell that so could hold them as they were
# 118. Was wrought through trees without a breath of storm
# 119. To make a leaf, if there had been one, stir.
# 120. One lizard at the end of every ray.
# 121. The thought of my attempting such a stray!
# 122. ONCE on the kind of day called "weather breeder,"
# 123. When the heat slowly hazes and the sun
# 124. By its own power seems to be undone,
# 125. I was half boring through, half climbing through
# 126. A swamp of cedar. Choked with oil of cedar
# 127. And scurf of plants, and weary and over-heated,
# 128. And sorry I ever left the road I knew,
# 129. I paused and rested on a sort of hook
# 130. That had me by the coat as good as seated,
# 131. And since there was no other way to look,
# 132. Looked up toward heaven, and there against the blue,
# 133. Stood over me a resurrected tree,
# 134. A tree that had been down and raised again—
# 135. A barkless spectre. He had halted too,
# 136. As if for fear of treading upon me.
# 137. I saw the strange position of his hands—
# 138. Up at his shoulders, dragging yellow strands
# 139. Of wire with something in it from men to men.
# 140. "You here?" I said. "Where aren't you nowadays
# 141. And what's the news you carry—if you know?
# 142. And tell me where you're off for—Montreal?
# 143. Me? I'm not off for anywhere at all.
# 144. Sometimes I wander out of beaten ways
# 145. Half looking for the orchid Calypso."
# 146. Brown lived at such a lofty farm
# 147. That everyone for miles could see
# 148. His lantern when he did his chores
# 149. In winter after half-past three.
# 150. And many must have seen him make
# 151. His wild descent from there one night,
# 152. 'Cross lots, 'cross walls, 'cross everything,
# 153. Describing rings of lantern light.
# 154. Between the house and barn the gale
# 155. Got him by something he had on
# 156. And blew him out on the icy crust
# 157. That cased the world, and he was gone!
# 158. Walls were all buried, trees were few:
# 159. He saw no stay unless he stove
# 160. A hole in somewhere with his heel.
# 161. But though repeatedly he strove
# 162. And stamped and said things to himself,
# 163. And sometimes something seemed to yield,
# 164. He gained no foothold, but pursued
# 165. His journey down from field to field.
# 166. Sometimes he came with arms outspread
# 167. Like wings, revolving in the scene
# 168. Upon his longer axis, and
# 169. With no small dignity of mien.
# 170. Faster or slower as he chanced,
# 171. Sitting or standing as he chose,
# 172. According as he feared to risk
# 173. His neck, or thought to spare his clothes,
# 174. He never let the lantern drop.
# 175. And some exclaimed who saw afar
# 176. The figures he described with it,
# 177. "I wonder what those signals are
# 178. Brown makes at such an hour of night!
# 179. He's celebrating something strange.
# 180. I wonder if he's sold his farm,
# 181. Or been made Master of the Grange."
# 182. He reeled, he lurched, he bobbed, he checked;
# 183. He fell and made the lantern rattle
# 184. (But saved the light from going out.)
# 185. So half-way down he fought the battle
# 186. Incredulous of his own bad luck.
# 187. And then becoming reconciled
# 188. To everything, he gave it up
# 189. And came down like a coasting child.
# 190. "Well—I—be—" that was all he said,
# 191. As standing in the river road,
# 192. He looked back up the slippery slope
# 193. (Two miles it was) to his abode.
# 194. Sometimes as an authority
# 195. On motor-cars, I'm asked if I
# 196. Should say our stock was petered out,
# 197. And this is my sincere reply:
# 198. Yankees are what they always were.
# 199. Don't think Brown ever gave up hope
# 200. Of getting home again because
# 201. He couldn't climb that slippery slope;
# 202. Or even thought of standing there
# 203. Until the January thaw
# 204. Should take the polish off the crust.
# 205. He bowed with grace to natural law,
# 206. And then went round it on his feet,
# 207. After the manner of our stock;
# 208. Not much concerned for those to whom,
# 209. At that particular time o'clock,
# 210. It must have looked as if the course
# 211. He steered was really straight away
# 212. From that which he was headed for—
# 213. Not much concerned for them, I say:
# 214. No more so than became a man—
# 215. And politician at odd seasons.
# 216. I've kept Brown standing in the cold
# 217. While I invested him with reasons;
# 218. But now he snapped his eyes three times;
# 219. Then shook his lantern, saying, "Ile's
# 220. 'Bout out!" and took the long way home
# 221. By road, a matter of several miles.
# 222. NOW that they've got it settled whose I be,
# 223. I'm going to tell them something they won't like:
# 224. They've got it settled wrong, and I can prove it.
# 225. Flattered I must be to have two towns fighting
# 226. To make a present of me to each other.
# 227. They don't dispose me, either one of them,
# 228. To spare them any trouble. Double trouble's
# 229. Always the witch's motto anyway.
# 230. I'll double theirs for both of them- you watch me.
# 231. They'll find they've got the whole thing to do over,
# 232. That is, if facts is what they want to go by.
# 233. They set a lot (now don't they?) by a record
# 234. Of Arthur Amy's having once been up
# 235. For Hog Reeve in March Meeting here in Warren.
# 236. I could have told them any time this twelvemonth
# 237. The Arthur Amy I was married to
# 238. Couldn't have been the one they say was up
# 239. In Warren at March Meeting for the reason
# 240. He wa'n't but fifteen at the time they say.
# 241. The Arthur Amy I was married to
# 242. voted the only times he ever voted,
# 243. Which wasn't many, in the town of Wentworth.
# 244. One of the times was when 'twas in the warrant
# 245. To see if the town wanted to take over
# 246. The tote road to our clearing where we lived.
# 247. I'll tell you who'd remember- Heman Lapish.
# 248. Their Arthur Amy was the father of mine.
# 249. So now they've dragged it through the law courts once
# 250. I guess they'd better drag it through again.
# 251. Wentworth and Warren's both good towns to live in,
# 252. Only I happen to prefer to live
# 253. In Wentworth from now on; and when all's said,
# 254. Right's right, and the temptation to do right
# 255. When I can hurt someone by doing it
# 256. Has always been too much for me, it has.
# 257. I know of some folks that'd be set up
# 258. At having in their town a noted witch:
# 259. But most would have to think of the expense
# 260. That even I would be. They ought to know
# 261. That as a witch I'd often milk a bat
# 262. And that'd be enough to last for days.
# 263. It'd make my position stronger, I think,
# 264. If I was to consent to give some sign
# 265. To make it surer that I was a witch?
# 266. It wa'n't no sign, I s'pose, when Mallice Huse
# 267. Said that I took him out in his old age
# 268. And rode all over everything on him
# 269. Until I'd had him worn to skin and bones,
# 270. And if I'd left him hitched unblanketed
# 271. In front of one Town Hall, I'd left him hitched
# 272. In front of every one in Grafton County.
# 273. Some cried shame on me not to blanket him,
# 274. The poor old man. It would have been all right
# 275. If some one hadn't said to gnaw the posts
# 276. He stood beside and leave his trade mark on them,
# 277. So they could recognize them. Not a post
# 278. That they could hear tell of was scarified.
# 279. They made him keep on gnawing till he whined.
# 280. Then that same smarty someone said to look-
# 281. He'd bet Huse was a cribber and had gnawed
# 282. The crib he slept in- and as sure's you're born
# 283. They found he'd gnawed the four posts of his bed,
# 284. All four of them to splinters. What did that prove?
# 285. Not that he hadn't gnawed the hitching posts
# 286. He said he had besides. Because a horse
# 287. Gnaws in the stable ain't no proof to me
# 288. He don't gnaw trees and posts and fences too.
# 289. But everybody took it for proof.
# 290. I was a strapping girl of twenty then.
# 291. The smarty someone who spoiled everything
# 292. Was Arthur Amy. You know who he was.
# 293. That was the way he started courting me.
# 294. He never said much after we were married,
# 295. But I mistrusted he was none too proud
# 296. Of having interfered in the Huse business.
# 297. I guess he found he got more out of me
# 298. By having me a witch. Or something happened
# 299. To turn him round. He got to saying things
# 300. To undo what he'd done and make it right,
# 301. Like, 'No, she ain't come back from kiting yet.
# 302. Last night was one of her nights out. She's kiting.
# 303. She thinks when the wind makes a night of it
# 304. She might as well herself.' But he liked best
# 305. To let on he was plagued to death with me:
# 306. If anyone had seen me coming home
# 307. Over the ridgepole, 'stride of a broomstick,
# 308. As often as he had in the tail of the night,
# 309. He guessed they'd know what he had to put up with.
# 310. Well, I showed Arthur Amy signs enough
# 311. Off from the house as far as we could keep
# 312. And from barn smells you can't wash out of ploughed ground
# 313. With all the rain and snow of seven years;
# 314. And I don't mean just skulls of Roger's Rangers
# 315. On Moosilauke, but woman signs to man,
# 316. Only bewitched so I would last him longer.
# 317. Up where the trees grow short, the mosses tall,
# 318. I made him gather me wet snow berries
# 319. On slippery rocks beside a waterfall.
# 320. I made him do it for me in the dark.
# 321. And he liked everything I made him do.
# 322. I hope if he is where he sees me now
# 323. He's so far off he can't see what I've come to.
# 324. You _can_ come down from everything to nothing.
# 325. All is, if I'd a-known when I was young
# 326. And full of it, that this would be the end,
# 327. It doesn't seem as if I'd had the courage
# 328. To make so free and kick up in folks' faces.
# 329. I might have, but it doesn't seem as if.
# 330. Old Davis owned a solid mica mountain
# 331. In Dalton that would someday make his fortune.
# 332. There'd been some Boston people out to see it:
# 333. And experts said that deep down in the mountain
# 334. The mica sheets were big as plate-glass windows.
# 335. He'd like to take me there and show it to me.
# 336. 'I'll tell you what you show me. You remember
# 337. You said you knew the place where once, on Kinsman,
# 338. The early Mormons made a settlement
# 339. And built a stone baptismal font outdoors-
# 340. But Smith, or someone, called them off the mountain
# 341. To go West to a worse fight with the desert.
# 342. You said you'd seen the stone baptismal font.
# 343. Well, take me there.'
# 344. Someday I will.'
# 345. 'Today.'
# 346. 'Huh, that old bathtub, what is that to see?
# 347. Let's talk about it.'
# 348. 'Let's go see the place.'
# 349. 'To shut you up I'll tell you what I'll do:
# 350. I'll find that fountain if it takes all summer,
# 351. And both of our united strengths, to do it.'
# 352. 'You've lost it, then?'
# 353. 'Not so but I can find it.
# 354. No doubt it's grown up some to woods around it.
# 355. The mountain may have shifted since I saw it
# 356. In eighty-five.'
# 357. 'As long ago as that?'
# 358. 'If I remember rightly, it had sprung
# 359. A leak and emptied then. And forty years
# 360. Can do a good deal to bad masonry.
# 361. You won't see any Mormon swimming in it.
# 362. But you have said it, and we're off to find it.
# 363. Old as I am, I'm going to let myself
# 364. Be dragged by you all over everywhere- '
# 365. 'I thought you were a guide.'
# 366. 'I am a guide,
# 367. And that's why I can't decently refuse you.'
# 368. We made a day of it out of the world,
# 369. Ascending to descend to reascend.
# 370. The old man seriously took his bearings,
# 371. And spoke his doubts in every open place.
# 372. We came out on a look-off where we faced
# 373. A cliff, and on the cliff a bottle painted,
# 374. Or stained by vegetation from above,
# 375. A likeness to surprise the thrilly tourist.
# 376. 'Well, if I haven't brought you to the fountain,
# 377. At least I've brought you to the famous Bottle.'
# 378. 'I won't accept the substitute. It's empty.'
# 379. 'So's everything.'
# 380. 'I want my fountain.'
# 381. 'I guess you'd find the fountain just as empty.
# 382. And anyway this tells me where I am.'
# 383. 'Hadn't you long suspected where you were?'
# 384. 'You mean miles from that Mormon settlement?
# 385. Look here, you treat your guide with due respect
# 386. If you don't want to spend the night outdoors.
# 387. I vow we must be near the place from where
# 388. The two converging slides, the avalanches,
# 389. On Marshall, look like donkey's ears.
# 390. We may as well see that and save the day.'
# 391. 'Don't donkey's ears suggest we shake our own?'
# 392. 'For God's sake, aren't you fond of viewing nature?
# 393. You don't like nature. All you like is books.
# 394. What signify a donkey's cars and bottle,
# 395. However natural? Give you your books!
# 396. Well then, right here is where I show you books.
# 397. Come straight down off this mountain just as fast
# 398. As we can fall and keep a-bouncing on our feet.
# 399. It's hell for knees unless done hell-for-leather.'
# 400. Be ready, I thought, for almost anything.
# 401. We struck a road I didn't recognize,
# 402. But welcomed for the chance to lave my shoes
# 403. In dust once more. We followed this a mile,
# 404. Perhaps, to where it ended at a house
# 405. I didn't know was there. It was the kind
# 406. To bring me to for broad-board paneling.
# 407. I never saw so good a house deserted.
# 408. 'Excuse me if I ask you in a window
# 409. That happens to be broken, Davis said.
# 410. 'The outside doors as yet have held against us.
# 411. I want to introduce you to the people
# 412. Who used to live here. They were Robinsons.
# 413. You must have heard of Clara Robinson,
# 414. The poetess who wrote the book of verses
# 415. And had it published. It was all about
# 416. The posies on her inner windowsill,
# 417. And the birds on her outer windowsill,
# 418. And how she tended both, or had them tended:
# 419. She never tended anything herself.
# 420. She was 'shut in' for life. She lived her whole
# 421. Life long in bed, and wrote her things in bed.
# 422. I'll show You how she had her sills extended
# 423. To entertain the birds and hold the flowers.
# 424. Our business first's up attic with her books.'
# 425. We trod uncomfortably on crunching glass
# 426. Through a house stripped of everything
# 427. Except, it seemed, the poetess's poems.
# 428. Books, I should say!- if books are what is needed.
# 429. A whole edition in a packing case
# 430. That, overflowing like a horn of plenty,
# 431. Or like the poetess's heart of love,
# 432. Had spilled them near the window, toward the light
# 433. Where driven rain had wet and swollen them.
# 434. Enough to stock a village library-
# 435. Unfortunately all of one kind, though.
# 436. They bad been brought home from some publisher
# 437. And taken thus into the family.
# 438. Boys and bad hunters had known what to do
# 439. With stone and lead to unprotected glass:
# 440. Shatter it inward on the unswept floors.
# 441. How had the tender verse escaped their outrage?
# 442. By being invisible for what it was,
# 443. Or else by some remoteness that defied them
# 444. To find out what to do to hurt a poem.
# 445. Yet oh! the tempting flatness of a book,
# 446. To send it sailing out the attic window
# 447. Till it caught wind and, opening out its covers,
# 448. Tried to improve on sailing like a tile
# 449. By flying like a bird (silent in flight,
# 450. But all the burden of its body song),
# 451. Only to tumble like a stricken bird,
# 452. And lie in stones and bushes unretrieved.
# 453. Books were not thrown irreverently about.
# 454. They simply lay where someone now and then,
# 455. Having tried one, had dropped it at his feet
# 456. And left it lying where it fell rejected.
# 457. Here were all those the poetess's life
# 458. Had been too short to sell or give away.
# 459. 'Take one,' Old Davis bade me graciously.
# 460. 'Why not take two or three?'
# 461. 'Take all you want.'
# 462. Good-looking books like that.' He picked one fresh
# 463. In virgin wrapper from deep in the box,
# 464. And stroked it with a horny-handed kindness.
# 465. He read in one and I read in another,
# 466. Both either looking for or finding something.
# 467. The attic wasps went missing by like bullets.
# 468. I was soon satisfied for the time being.
# 469. All the way home I kept remembering
# 470. The small book in my pocket. It was there.
# 471. The poetess had sighed, I knew, in heaven
# 472. At having eased her heart of one more copy-
# 473. Legitimately. My demand upon her,
# 474. Though slight, was a demand. She felt the tug.
# 475. In time she would be rid of all her books.
# 476. I stay;
# 477. But it isn't as if
# 478. There wasn't always Hudson's Bay
# 479. And the fur trade,
# 480. A small skiff
# 481. And a paddle blade.
# 482. I can just see my tent pegged,
# 483. And me on the floor,
# 484. Cross-legged,
# 485. And a trapper looking in at the door
# 486. With furs to sell.
# 487. His name's Joe,
# 488. Alias John,
# 489. And between what he doesn't know
# 490. And won't tell
# 491. About where Henry Hudson's gone,
# 492. I can't say he's much help;
# 493. But we get on.
# 494. The seal yelp
# 495. On an ice cake.
# 496. It's not men by some mistake?
# 497. No,
# 498. There's not a soul
# 499. For a windbreak
# 500. Between me and the North Pole—
# 501. Except always John-Joe,
# 502. My French Indian Esquimaux,
# 503. And he's off setting traps
# 504. In one himself perhaps.
# 505. Give a headshake
# 506. Over so much bay
# 507. Thrown away
# 508. In snow and mist
# 509. That doesn't exist,
# 510. I was going to say,
# 511. For God, man, or beast's sake,
# 512. Yet does perhaps for all three.
# 513. Don't ask Joe
# 514. What it is to him.
# 515. It's sometimes dim
# 516. What it is to me,
# 517. Unless it be
# 518. It's the old captain's dark fate
# 519. Who failed to find or force a strait
# 520. In its two-thousand-mile coast;
# 521. And his crew left him where be failed,
# 522. And nothing came of all be sailed.
# 523. It's to say, 'You and I—'
# 524. To such a ghost—
# 525. You and I
# 526. Off here
# 527. With the dead race of the Great Auk!'
# 528. And, 'Better defeat almost,
# 529. If seen clear,
# 530. Than life's victories of doubt
# 531. That need endless talk-talk
# 532. To make them out.'
# 533. I staid the night for shelter at a farm
# 534. Behind the mountains, with a mother and son,
# 535. Two old-believers. They did all the talking.
# 536. MOTHER Folks think a witch who has familiar spirits
# 537. She could call up to pass a winter evening,
# 538. But won't, should be burned at the stake or something.
# 539. Summoning spirits isn't 'Button, button,
# 540. Who's got the button,' I would have them know.
# 541. SON: Mother can make a common table rear
# 542. And kick with two legs like an army mule.
# 543. MOTHER: And when I've done it, what good have I
# 544. done?
# 545. Rather than tip a table for you, let me
# 546. Tell you what Ralle the Sioux Control once told me.
# 547. He said the dead had souls, but when I asked him
# 548. How could that be - I thought the dead were souls,
# 549. He broke my trance. Don't that make you suspicious
# 550. That there's something the dead are keeping back?
# 551. Yes, there's something the dead are keeping back.
# 552. SON: You wouldn't want to tell him what we have
# 553. Up attic, mother?
# 554. MOTHER: Bones - a skeleton.
# 555. SON: But the headboard of mother's bed is pushed
# 556. Against the' attic door: the door is nailed.
# 557. It's harmless. Mother hears it in the night
# 558. Halting perplexed behind the barrier
# 559. Of door and headboard. Where it wants to get
# 560. Is back into the cellar where it came from.
# 561. MOTHER: We'll never let them, will we, son! We'll
# 562. never !
# 563. SON: It left the cellar forty years ago
# 564. And carried itself like a pile of dishes
# 565. Up one flight from the cellar to the kitchen,
# 566. Another from the kitchen to the bedroom,
# 567. Another from the bedroom to the attic,
# 568. Right past both father and mother, and neither stopped
# 569. it.
# 570. Father had gone upstairs; mother was downstairs.
# 571. I was a baby: I don't know where I was.
# 572. MOTHER: The only fault my husband found with me -
# 573. I went to sleep before I went to bed,
# 574. Especially in winter when the bed
# 575. Might just as well be ice and the clothes snow.
# 576. The night the bones came up the cellar-stairs
# 577. Toffile had gone to bed alone and left me,
# 578. But left an open door to cool the room off
# 579. So as to sort of turn me out of it.
# 580. I was just coming to myself enough
# 581. To wonder where the cold was coming from,
# 582. When I heard Toffile upstairs in the bedroom
# 583. And thought I heard him downstairs in the cellar.
# 584. The board we had laid down to walk dry-shod on
# 585. When there was water in the cellar in spring
# 586. Struck the hard cellar bottom. And then someone
# 587. Began the stairs, two footsteps for each step,
# 588. The way a man with one leg and a crutch,
# 589. Or a little child, comes up. It wasn't Toffile:
# 590. It wasn't anyone who could be there.
# 591. The bulkhead double-doors were double-locked
# 592. And swollen tight and buried under snow.
# 593. The cellar windows were banked up with sawdust
# 594. And swollen tight and buried under snow.
# 595. It was the bones. I knew them - and good reason.
# 596. My first impulse was to get to the knob
# 597. And hold the door. But the bones didn't try
# 598. The door; they halted helpless on the landing,
# 599. Waiting for things to happen in their favour.'
# 600. The faintest restless rustling ran all through them.
# 601. I never could have done the thing I did
# 602. If the wish hadn't been too strong in me
# 603. To see how they were mounted for this walk.
# 604. I had a vision of them put together
# 605. Not like a man, but like a chandelier.
# 606. So suddenly I flung the door wide on him.
# 607. A moment he stood balancing with emotion,
# 608. And all but lost himself. (A tongue of fire
# 609. Flashed out and licked along his upper teeth.
# 610. Smoke rolled inside the sockets of his eyes.)
# 611. Then he came at me with one hand outstretched,
# 612. The way he did in life once; but this time
# 613. I struck the hand off brittle on the floor,
# 614. And fell back from him on the floor myself.
# 615. The finger-pieces slid in all directions.
# 616. (Where did I see one of those pieces lately?
# 617. Hand me my button-box- it must be there.)
# 618. I sat up on the floor and shouted, 'Toffile,
# 619. It's coming up to you.' It had its choice
# 620. Of the door to the cellar or the hall.
# 621. It took the hall door for the novelty,
# 622. And set off briskly for so slow a thing,
# 623. Stillgoing every which way in the joints, though,
# 624. So that it looked like lightning or a scribble,
# 625. >From the slap I had just now given its hand.
# 626. I listened till it almost climbed the stairs
# 627. >From the hall to the only finished bedroom,
# 628. Before I got up to do anything;
# 629. Then ran and shouted, 'Shut the bedroom door,
# 630. Toffile, for my sake!' 'Company?' he said,
# 631. 'Don't make me get up; I'm too warm in bed.'
# 632. So lying forward weakly on the handrail
# 633. I pushed myself upstairs, and in the light
# 634. (The kitchen had been dark) I had to own
# 635. I could see nothing. 'Toffile, I don't see it.
# 636. It's with us in the room though. It's the bones.'
# 637. 'What bones?' 'The cellar bones- out of the grave.'
# 638. That made him throw his bare legs out of bed
# 639. And sit up by me and take hold of me.
# 640. I wanted to put out the light and see
# 641. If I could see it, or else mow the room,
# 642. With our arms at the level of our knees,
# 643. And bring the chalk-pile down. 'I'll tell you what-
# 644. It's looking for another door to try.
# 645. The uncommonly deep snow has made him think
# 646. Of his old song, The Wild Colonial Boy,
# 647. He always used to sing along the tote-road.
# 648. He's after an open door to get out-doors.
# 649. Let's trap him with an open door up attic.'
# 650. Toffile agreed to that, and sure enough,
# 651. Almost the moment he was given an opening,
# 652. The steps began to climb the attic stairs.
# 653. I heard them. Toffile didn't seem to hear them.
# 654. 'Quick !' I slammed to the door and held the knob.
# 655. 'Toffile, get nails.' I made him nail the door shut,
# 656. And push the headboard of the bed against it.
# 657. Then we asked was there anything
# 658. Up attic that we'd ever want again.
# 659. The attic was less to us than the cellar.
# 660. If the bones liked the attic, let them have it.
# 661. Let them stay in the attic. When they sometimes
# 662. Come down the stairs at night and stand perplexed
# 663. Behind the door and headboard of the bed,
# 664. Brushing their chalky skull with chalky fingers,
# 665. With sounds like the dry rattling of a shutter,
# 666. That's what I sit up in the dark to say-
# 667. To no one any more since Toffile died.
# 668. 2o3 Let them stay in the attic since they went there.
# 669. I promised Toffile to be cruel to them
# 670. For helping them be cruel once to him.
# 671. SON: We think they had a grave down in the cellar.
# 672. MOTHER: We know they had a grave down in the cellar.
# 673. SON: We never could find out whose bones they were.
# 674. MOTHER: Yes, we could too, son. Tell the truth for once.
# 675. They were a man's his father killed for me.
# 676. I mean a man he killed instead of me.
# 677. The least I could do was to help dig their grave.
# 678. We were about it one night in the cellar.
# 679. Son knows the story: but 'twas not for him
# 680. To tell the truth, suppose the time had come.
# 681. Son looks surprised to see me end a lie
# 682. We'd kept all these years between ourselves
# 683. So as to have it ready for outsiders.
# 684. But to-night I don't care enough to lie-
# 685. I don't remember why I ever cared.
# 686. Toffile, if he were here, I don't believe
# 687. Could tell you why he ever cared himself-
# 688. She hadn't found the finger-bone she wanted
# 689. Among the buttons poured out in her lap.
# 690. I verified the name next morning: Toffile.
# 691. The rural letter-box said Toffile Lajway.
# 692. The west was getting out of gold,
# 693. The breath of air had died of cold,
# 694. When shoeing home across the white,
# 695. I thought I saw a bird alight.
# 696. In summer when I passed the place
# 697. I had to stop and lift my face;
# 698. A bird with an angelic gift
# 699. Was singing in it sweet and swift.
# 700. No bird was singing in it now.
# 701. A single leaf was on a bough,
# 702. And that was all there was to see
# 703. In going twice around the tree.
# 704. From my advantage on a hill
# 705. I judged that such a crystal chill
# 706. Was only adding frost to snow
# 707. As gilt to gold that wouldn't show.
# 708. A brush had left a crooked stroke
# 709. Of what was either cloud or smoke
# 710. From north to south across the blue;
# 711. A piercing little star was through.
# 712. A governor it was proclaimed this time,
# 713. When all who would come seeking in New Hampshire
# 714. Ancestral memories might come together.
# 715. And those of the name Stark gathered in Bow,
# 716. A rock-strewn town where farming has fallen off,
# 717. And sprout-lands flourish where the axe has gone.
# 718. Someone had literally run to earth
# 719. In an old cellar hole in a by-road
# 720. The origin of all the family there.
# 721. Thence they were sprung, so numerous a tribe
# 722. That now not all the houses left in town
# 723. Made shift to shelter them without the help
# 724. Of here and there a tent in grove and orchard.
# 725. They were at Bow, but that was not enough:
# 726. Nothing would do but they must fix a day
# 727. To stand together on the crater's verge
# 728. That turned them on the world, and try to fathom
# 729. The past and get some strangeness out of it.
# 730. But rain spoiled all. The day began uncertain,
# 731. With clouds low trailing and moments of rain that misted.
# 732. The young folk held some hope out to each other
# 733. Till well toward noon when the storm settled down
# 734. With a swish in the grass. 'What if the others
# 735. Are there,' they said. 'It isn't going to rain.'
# 736. Only one from a farm not far away
# 737. Strolled thither, not expecting he would find
# 738. Anyone else, but out of idleness.
# 739. One, and one other, yes, for there were two.
# 740. The second round the curving hillside road
# 741. Was a girl; and she halted some way off
# 742. To reconnoitre, and then made up her mind
# 743. At least to pass by and see who he was,
# 744. And perhaps hear some word about the weather.
# 745. This was some Stark she didn't know. He nodded.
# 746. 'No fête to-day,' he said.
# 747. 'It looks that way.'
# 748. She swept the heavens, turning on her heel.
# 749. 'I only idled down.'
# 750. 'I idled down.'
# 751. Provision there had been for just such meeting
# 752. Of stranger cousins, in a family tree
# 753. Drawn on a sort of passport with the branch
# 754. Of the one bearing it done in detail-
# 755. Some zealous one's laborious device.
# 756. She made a sudden movement toward her bodice,
# 757. As one who clasps her heart. They laughed together.
# 758. 'Stark?' he inquired. 'No matter for the proof.'
# 759. 'Yes, Stark. And you?'
# 760. 'I'm Stark.' He drew his passport.
# 761. 'You know we might not be and still be cousins:
# 762. The town is full of Chases, Lowes, and Baileys,
# 763. All claiming some priority in Starkness.
# 764. My mother was a Lane, yet might have married
# 765. Anyone upon earth and still her children
# 766. Would have been Starks, and doubtless here to-day.'
# 767. 'You riddle with your genealogy
# 768. Like a Viola. I don't follow you.'
# 769. 'I only mean my mother was a Stark
# 770. Several times over, and by marrying father
# 771. No more than brought us back into the name.'
# 772. 'One ought not to be thrown into confusion
# 773. By a plain statement of relationship,
# 774. But I own what you say makes my head spin.
# 775. You take my card- you seem so good at such things-
# 776. And see if you can reckon our cousinship.
# 777. Why not take seats here on the cellar wall
# 778. And dangle feet among the raspberry vines?'
# 779. 'Under the shelter of the family tree.'
# 780. 'Just so- that ought to be enough protection.'
# 781. 'Not from the rain. I think it's going to rain.'
# 782. 'It's raining.'
# 783. 'No, it's misting; let's be fair.
# 784. Does the rain seem to you to cool the eyes?'
# 785. The situation was like this: the road
# 786. Bowed outward on the mountain half-way up,
# 787. And disappeared and ended not far off.
# 788. No one went home that way. The only house
# 789. Beyond where they were was a shattered seedpod.
# 790. And below roared a brook hidden in trees,
# 791. The sound of which was silence for the place.
# 792. This he sat listening to till she gave judgment.
# 793. 'On father's side, it seems, we're- let me see- - '
# 794. 'Don't be too technical.- You have three cards.'
# 795. 'Four cards, one yours, three mine, one for each branch
# 796. Of the Stark family I'm a member of.'
# 797. 'D'you know a person so related to herself
# 798. Is supposed to be mad.'
# 799. 'I may be mad.'
# 800. 'You look so, sitting out here in the rain
# 801. Studying genealogy with me
# 802. You never saw before. What will we come to
# 803. With all this pride of ancestry, we Yankees?
# 804. I think we're all mad. Tell me why we're here
# 805. Drawn into town about this cellar hole
# 806. Like wild geese on a lake before a storm?
# 807. What do we see in such a hole, I wonder.'
# 808. 'The Indians had a myth of Chicamoztoc,
# 809. Which means The Seven Caves that We Came out of.
# 810. This is the pit from which we Starks were digged.'
# 811. 'You must be learned. That's what you see in it?'
# 812. 'And what do you see?'
# 813. 'Yes, what do I see?
# 814. First let me look. I see raspberry vines- - '
# 815. 'Oh, if you're going to use your eyes, just hear
# 816. What I see. It's a little, little boy,
# 817. As pale and dim as a match flame in the sun;
# 818. He's groping in the cellar after jam,
# 819. He thinks it's dark and it's flooded with daylight.'
# 820. 'He's nothing. Listen. When I lean like this
# 821. I can make out old Grandsir Stark distinctly,-
# 822. With his pipe in his mouth and his brown jug-
# 823. Bless you, it isn't Grandsir Stark, it's Granny,
# 824. But the pipe's there and smoking and the jug.
# 825. She's after cider, the old girl, she's thirsty;
# 826. Here's hoping she gets her drink and gets out safely.'
# 827. 'Tell me about her. Does she look like me?'
# 828. 'She should, shouldn't she, you're so many times
# 829. Over descended from her. I believe
# 830. She does look like you. Stay the way you are.
# 831. The nose is just the same, and so's the chin-
# 832. Making allowance, making due allowance.'
# 833. 'You poor, dear, great, great, great, great Granny!'
# 834. 'See that you get her greatness right. Don't stint her.'
# 835. 'Yes, it's important, though you think it isn't.
# 836. I won't be teased. But see how wet I am.'
# 837. 'Yes, you must go; we can't stay here for ever.
# 838. But wait until I give you a hand up.
# 839. A bead of silver water more or less
# 840. Strung on your hair won't hurt your summer looks.
# 841. I wanted to try something with the noise
# 842. That the brook raises in the empty valley.
# 843. We have seen visions- now consult the voices.
# 844. Something I must have learned riding in trains
# 845. When I was young. I used the roar
# 846. To set the voices speaking out of it,
# 847. Speaking or singing, and the band-music playing.
# 848. Perhaps you have the art of what I mean.
# 849. I've never listened in among the sounds
# 850. That a brook makes in such a wild descent.
# 851. It ought to give a purer oracle.'
# 852. 'It's as you throw a picture on a screen:
# 853. The meaning of it all is out of you;
# 854. The voices give you what you wish to hear.'
# 855. 'Strangely, it's anything they wish to give.'
# 856. 'Then I don't know. It must be strange enough.
# 857. I wonder if it's not your make-believe.
# 858. What do you think you're like to hear to-day?'
# 859. 'From the sense of our having been together-
# 860. But why take time for what I'm like to hear?
# 861. I'll tell you what the voices really say.
# 862. You will do very well right where you are
# 863. A little longer. I mustn't feel too hurried,
# 864. Or I can't give myself to hear the voices.'
# 865. 'Is this some trance you are withdrawing into?'
# 866. 'You must be very still; you mustn't talk.'
# 867. 'I'll hardly breathe.'
# 868. 'The voices seem to say- - '
# 869. 'I'm waiting.'
# 870. 'Don't! The voices seem to say:
# 871. Call her Nausicaa, the unafraid
# 872. Of an acquaintance made adventurously.'
# 873. 'I let you say that- on consideration.'
# 874. 'I don't see very well how you can help it.
# 875. You want the truth. I speak but by the voices.
# 876. You see they know I haven't had your name,
# 877. Though what a name should matter between us- - '
# 878. 'I shall suspect- - '
# 879. 'Be good. The voices say:
# 880. Call her Nausicaa, and take a timber
# 881. That you shall find lies in the cellar charred
# 882. Among the raspberries, and hew and shape it
# 883. For a door-sill or other corner piece
# 884. In a new cottage on the ancient spot.
# 885. The life is not yet all gone out of it.
# 886. And come and make your summer dwelling here,
# 887. And perhaps she will come, still unafraid,
# 888. And sit before you in the open door
# 889. With flowers in her lap until they fade,
# 890. But not come in across the sacred sill- - '
# 891. 'I wonder where your oracle is tending.
# 892. You can see that there's something wrong with it,
# 893. Or it would speak in dialect. Whose voice
# 894. Does it purport to speak in? Not old Grandsir's
# 895. Nor Granny's, surely. Call up one of them.
# 896. They have best right to be heard in this place.'
# 897. 'You seem so partial to our great-grandmother
# 898. (Nine times removed. Correct me if I err.)
# 899. You will be likely to regard as sacred
# 900. Anything she may say. But let me warn you,
# 901. Folks in her day were given to plain speaking.
# 902. You think you'd best tempt her at such a time?'
# 903. 'It rests with us always to cut her off.'
# 904. 'Well then, it's Granny speaking: 'I dunnow!
# 905. Mebbe I'm wrong to take it as I do.
# 906. There ain't no names quite like the old ones though,
# 907. Nor never will be to my way of thinking.
# 908. One mustn't bear too hard on the new comers,
# 909. But there's a dite too many of them for comfort.
# 910. I should feel easier if I could see
# 911. More of the salt wherewith they're to be salted.
# 912. Son, you do as you're told! You take the timber-
# 913. It's as sound as the day when it was cut-
# 914. And begin over- - ' There, she'd better stop.
# 915. You can see what is troubling Granny, though.
# 916. But don't you think we sometimes make too much
# 917. Of the old stock? What counts is the ideals,
# 918. And those will bear some keeping still about.'
# 919. 'I can see we are going to be good friends.'
# 920. 'I like your 'going to be.' You said just now
# 921. It's going to rain.'
# 922. 'I know, and it was raining.
# 923. I let you say all that. But I must go now.'
# 924. 'You let me say it? on consideration?
# 925. How shall we say good-bye in such a case?'
# 926. 'How shall we?'
# 927. 'Will you leave the way to me?'
# 928. 'No, I don't trust your eyes. You've said enough.
# 929. Now give me your hand up.- Pick me that flower.'
# 930. 'Where shall we meet again?'
# 931. 'Nowhere but here
# 932. Once more before we meet elsewhere.'
# 933. 'In rain?'
# 934. 'It ought to be in rain. Sometime in rain.
# 935. In rain to-morrow, shall we, if it rains?
# 936. But if we must, in sunshine.' So she went.
# 937. Builder, in building the little house,
# 938. In every way you may please yourself;
# 939. But please please me in the kitchen chimney:
# 940. Don't build me a chimney upon a shelf.
# 941. However far you must go for bricks,
# 942. Whatever they cost a-piece or a pound,
# 943. But me enough for a full-length chimney,
# 944. And build the chimney clear from the ground.
# 945. It's not that I'm greatly afraid of fire,
# 946. But I never heard of a house that throve
# 947. (And I know of one that didn't thrive)
# 948. Where the chimney started above the stove.
# 949. And I dread the ominous stain of tar
# 950. That there always is on the papered walls,
# 951. And the smell of fire drowned in rain
# 952. That there always is when the chimney's false.
# 953. A shelf's for a clock or vase or picture,
# 954. But I don't see why it should have to bear
# 955. A chimney that only would serve to remind me
# 956. Of castles I used to build in air.
# 957. I had for my winter evening walk-
# 958. No one at all with whom to talk,
# 959. But I had the cottages in a row
# 960. Up to their shining eyes in snow.
# 961. And I thought I had the folk within:
# 962. I had the sound of a violin;
# 963. I had a glimpse through curtain laces
# 964. Of youthful forms and youthful faces.
# 965. I had such company outward bound.
# 966. I went till there were no cottages found.
# 967. I turned and repented, but coming back
# 968. I saw no window but that was black.
# 969. Over the snow my creaking feet
# 970. Disturbed the slumbering village street
# 971. Like profanation, by your leave,
# 972. At ten o'clock of a winter eve.
# 973. Inscription for a Garden Wall
# 974. Winds blow the open grassy places bleak;
# 975. But where this old wall burns a sunny cheek,
# 976. They eddy over it too toppling weak
# 977. To blow the earth or anything self-clear;
# 978. Moisture and color and odor thicken here.
# 979. The hours of daylight gather atmosphere.
# 980. To Ridgely Torrence
# 981. On Last Looking into His 'Hesperides'
# 982. I often see flowers from a passing car
# 983. That are gone before I can tell what they are.
# 984. I want to get out of the train and go back
# 985. To see what they were beside the track.
# 986. I name all the flowers I am sure they weren't;
# 987. Not fireweed loving where woods have burnt-
# 988. Not bluebells gracing a tunnel mouth-
# 989. Not lupine living on sand and drouth.
# 990. Was something brushed across my mind
# 991. That no one on earth will ever find?
# 992. Heaven gives it glimpses only to those
# 993. Not in position to look too close.
# 994. Back out of all this now too much for us,
# 995. Back in a time made simple by the loss
# 996. Of detail, burned, dissolved, and broken off
# 997. Like graveyard marble sculpture in the weather,
# 998. There is a house that is no more a house
# 999. Upon a farm that is no more a farm
# 1000. And in a town that is no more a town.
# 1001. The road there, if you'll let a guide direct you
# 1002. Who only has at heart your getting lost,
# 1003. May seem as if it should have been a quarry -
# 1004. Great monolithic knees the former town
# 1005. Long since gave up pretense of keeping covered.
# 1006. And there's a story in a book about it:
# 1007. Besides the wear of iron wagon wheels
# 1008. The ledges show lines ruled southeast-northwest,
# 1009. The chisel work of an enormous Glacier
# 1010. That braced his feet against the Arctic Pole.
# 1011. You must not mind a certain coolness from him
# 1012. Still said to haunt this side of Panther Mountain.
# 1013. Nor need you mind the serial ordeal
# 1014. Of being watched from forty cellar holes
# 1015. As if by eye pairs out of forty firkins.
# 1016. As for the woods' excitement over you
# 1017. That sends light rustle rushes to their leaves,
# 1018. Charge that to upstart inexperience.
# 1019. Where were they all not twenty years ago?
# 1020. They think too much of having shaded out
# 1021. A few old pecker-fretted apple trees.
# 1022. Make yourself up a cheering song of how
# 1023. Someone's road home from work this once was,
# 1024. Who may be just ahead of you on foot
# 1025. Or creaking with a buggy load of grain.
# 1026. The height of the adventure is the height
# 1027. Of country where two village cultures faded
# 1028. Into each other. Both of them are lost.
# 1029. And if you're lost enough to find yourself
# 1030. By now, pull in your ladder road behind you
# 1031. And put a sign up CLOSED to all but me.
# 1032. Then make yourself at home. The only field
# 1033. Now left's no bigger than a harness gall.
# 1034. First there's the children's house of make-believe,
# 1035. Some shattered dishes underneath a pine,
# 1036. The playthings in the playhouse of the children.
# 1037. Weep for what little things could make them glad.
# 1038. Then for the house that is no more a house,
# 1039. But only a belilaced cellar hole,
# 1040. Now slowly closing like a dent in dough.
# 1041. This was no playhouse but a house in earnest.
# 1042. Your destination and your destiny's
# 1043. A brook that was the water of the house,
# 1044. Cold as a spring as yet so near its source,
# 1045. Too lofty and original to rage.
# 1046. (We know the valley streams that when aroused
# 1047. Will leave their tatters hung on barb and thorn.)
# 1048. I have kept hidden in the instep arch
# 1049. Of an old cedar at the waterside
# 1050. A broken drinking goblet like the Grail
# 1051. Under a spell so the wrong ones can't find it,
# 1052. So can't get saved, as Saint Mark says they mustn't.
# 1053. (I stole the goblet from the children's playhouse.)
# 1054. Here are your waters and your watering place.
# 1055. Drink and be whole again beyond confusion.
# 1056. I WALKED down alone Sunday after church
# 1057. To the place where John has been cutting trees
# 1058. To see for myself about the birch
# 1059. He said I could have to bush my peas.
# 1060. The sun in the new-cut narrow gap
# 1061. Was hot enough for the first of May,
# 1062. And stifling hot with the odor of sap
# 1063. From stumps still bleeding their life away.
# 1064. The frogs that were peeping a thousand shrill
# 1065. Wherever the ground was low and wet,
# 1066. The minute they heard my step went still
# 1067. To watch me and see what I came to get.
# 1068. Birch boughs enough piled everywhere!—
# 1069. All fresh and sound from the recent axe.
# 1070. Time someone came with cart and pair
# 1071. And got them off the wild flower's backs.
# 1072. They might be good for garden things
# 1073. To curl a little finger round,
# 1074. The same as you seize cat's-cradle strings,
# 1075. And lift themselves up off the ground.
# 1076. Small good to anything growing wild,
# 1077. They were crooking many a trillium
# 1078. That had budded before the boughs were piled
# 1079. And since it was coming up had to come.
# 1080. Over back where they speak of life as staying
# 1081. ('You couldn't call it living, for it ain't'),
# 1082. There was an old, old house renewed with paint,
# 1083. And in it a piano loudly playing.
# 1084. Out in the plowed ground in the cold a digger,
# 1085. Among unearthed potatoes standing still,
# 1086. Was counting winter dinners, one a hill,
# 1087. With half an ear to the piano's vigor.
# 1088. All that piano and new paint back there,
# 1089. Was it some money suddenly come into?
# 1090. Or some extravagance young love had been to?
# 1091. Or old love on an impulse not to care-
# 1092. Not to sink under being man and wife,
# 1093. But get some color and music out of life?
# 1094. It was long I lay
# 1095. Awake that night
# 1096. Wishing that night
# 1097. Would name the hour
# 1098. And tell me whether
# 1099. To call it day
# 1100. (Though not yet light)
# 1101. And give up sleep.
# 1102. The snow fell deep
# 1103. With the hiss of spray;
# 1104. Two winds would meet,
# 1105. One down one street,
# 1106. One down another,
# 1107. And fight in a smother
# 1108. Of dust and feather.
# 1109. I could not say,
# 1110. But feared the cold
# 1111. Had checked the pace
# 1112. Of the tower clock
# 1113. By tying together
# 1114. Its hands of gold
# 1115. Before its face.
# 1116. Then cane one knock!
# 1117. A note unruffled
# 1118. Of earthly weather,
# 1119. Though strange and muffled.
# 1120. The tower said, 'One!'
# 1121. And then a steeple.
# 1122. They spoke to themselves
# 1123. And such few people
# 1124. As winds might rouse
# 1125. From sleeping warm
# 1126. (But not unhouse).
# 1127. They left the storm
# 1128. That struck en masse
# 1129. My window glass
# 1130. Like a beaded fur.
# 1131. In that grave One
# 1132. They spoke of the sun
# 1133. And moon and stars,
# 1134. Saturn and Mars
# 1135. And Jupiter.
# 1136. Still more unfettered,
# 1137. They left the named
# 1138. And spoke of the lettered,
# 1139. The sigmas and taus
# 1140. Of constellations.
# 1141. They filled their throats
# 1142. With the furthest bodies
# 1143. To which man sends his
# 1144. Speculation,
# 1145. Beyond which God is;
# 1146. The cosmic motes
# 1147. Of yawning lenses.
# 1148. Their solemn peals
# 1149. Were not their own:
# 1150. They spoke for the clock
# 1151. With whose vast wheels
# 1152. Theirs interlock.
# 1153. In that grave word
# 1154. Uttered alone
# 1155. The utmost star
# 1156. Trembled and stirred,
# 1157. Though set so far
# 1158. Its whirling frenzies
# 1159. Appear like standing
# 1160. in one self station.
# 1161. It has not ranged,
# 1162. And save for the wonder
# 1163. Of once expanding
# 1164. To be a nova,
# 1165. It has not changed
# 1166. To the eye of man
# 1167. On planets over
# 1168. Around and under
# 1169. It in creation
# 1170. Since man began
# 1171. To drag down man
# 1172. And nation nation.
# 1173. The surest thing there is is we are riders,
# 1174. And though none too successful at it, guiders,
# 1175. Through everything presented, land and tide
# 1176. And now the very air, of what we ride.
# 1177. What is this talked-of mystery of birth
# 1178. But being mounted bareback on the earth?
# 1179. We can just see the infant up astride,
# 1180. His small fist buried in the bushy hide.
# 1181. There is our wildest mount- a headless horse.
# 1182. But though it runs unbridled off its course,
# 1183. And all our blandishments would seem defied,
# 1184. We have ideas yet that we haven't tried.
# 1185. I let myself in at the kitchen door.
# 1186. 'It's you,' she said. 'I can't get up. Forgive me
# 1187. Not answering your knock. I can no more
# 1188. Let people in than I can keep them out.
# 1189. I'm getting too old for my size, I tell them.
# 1190. My fingers are about all I've the use of
# 1191. So's to take any comfort. I can sew:
# 1192. I help out with this beadwork what I can.'
# 1193. 'That's a smart pair of pumps you're beading there.
# 1194. Who are they for?'
# 1195. 'You mean?- oh, for some miss.
# 1196. I can't keep track of other people's daughters.
# 1197. Lord, if I were to dream of everyone
# 1198. Whose shoes I primped to dance in!'
# 1199. 'And where's John?'
# 1200. 'Haven't you seen him? Strange what set you off
# 1201. To come to his house when he's gone to yours.
# 1202. You can't have passed each other. I know what:
# 1203. He must have changed his mind and gone to Garlands.
# 1204. He won't be long in that case. You can wait.
# 1205. Though what good you can be, or anyone-
# 1206. It's gone so far. You've heard? Estelle's run off.'
# 1207. 'Yes, what's it all about? When did she go?'
# 1208. 'Two weeks since.'
# 1209. 'She's in earnest, it appears.'
# 1210. 'I'm sure she won't come back. She's hiding somewhere.
# 1211. I don't know where myself. John thinks I do.
# 1212. He thinks I only have to say the word,
# 1213. And she'll come back. But, bless you, I'm her mother-
# 1214. I can't talk to her, and, Lord, if I could!'
# 1215. 'It will go hard with John. What will he do?
# 1216. He can't find anyone to take her place.'
# 1217. 'Oh, if you ask me that, what will he do?
# 1218. He gets some sort of bakeshop meals together,
# 1219. With me to sit and tell him everything,
# 1220. What's wanted and how much and where it is.
# 1221. But when I'm gone- of course I can't stay here:
# 1222. Estelle's to take me when she's settled down.
# 1223. He and I only hinder one another.
# 1224. I tell them they can't get me through the door, though:
# 1225. I've been built in here like a big church organ.
# 1226. We've been here fifteen years.'
# 1227. 'That's a long time
# 1228. To live together and then pull apart.
# 1229. How do you see him living when you're gone?
# 1230. Two of you out will leave an empty house.'
# 1231. 'I don't just see him living many years,
# 1232. Left here with nothing but the furniture.
# 1233. I hate to think of the old place when we're gone,
# 1234. With the brook going by below the yard,
# 1235. And no one here but hens blowing about.
# 1236. If he could sell the place, but then, he can't:
# 1237. No one will ever live on it again.
# 1238. It's too run down. This is the last of it.
# 1239. What I think he will do, is let things smash.
# 1240. He'll sort of swear the time away. He's awful!
# 1241. I never saw a man let family troubles
# 1242. Make so much difference in his man's affairs.
# 1243. He's just dropped everything. He's like a child.
# 1244. I blame his being brought up by his mother.
# 1245. He's got hay down that's been rained on three times.
# 1246. He hoed a little yesterday for me:
# 1247. I thought the growing things would do him good.
# 1248. Something went wrong. I saw him throw the hoe
# 1249. Sky-high with both hands. I can see it now-
# 1250. Come here- I'll show you- in that apple tree.
# 1251. That's no way for a man to do at his age:
# 1252. He's fifty-five, you know, if he's a day.'
# 1253. 'Aren't you afraid of him? What's that gun for?'
# 1254. 'Oh, that's been there for hawks since chicken-time.
# 1255. John Hall touch me! Not if he knows his friends.
# 1256. I'll say that for him, John's no threatener
# 1257. Like some men folk. No one's afraid of him;
# 1258. All is, he's made up his mind not to stand
# 1259. What he has got to stand.'
# 1260. 'Where is Estelle?
# 1261. Couldn't one talk to her? What does she say?
# 1262. You say you don't know where she is.'
# 1263. 'Nor want to!
# 1264. She thinks if it was bad to live with him,
# 1265. It must be right to leave him.'
# 1266. 'Which is wrong!'
# 1267. 'Yes, but he should have married her.'
# 1268. 'I know.'
# 1269. 'The strain's been too much for her all these years:
# 1270. I can't explain it any other way.
# 1271. It's different with a man, at least with John:
# 1272. He knows he's kinder than the run of men.
# 1273. Better than married ought to be as good
# 1274. As married- that's what he has always said.
# 1275. I know the way he's felt- but all the same!'
# 1276. 'I wonder why he doesn't marry her
# 1277. And end it.'
# 1278. 'Too late now: she wouldn't have him.
# 1279. He's given her time to think of something else.
# 1280. That's his mistake. The dear knows my interest
# 1281. Has been to keep the thing from breaking up.
# 1282. This is a good home: I don't ask for better.
# 1283. But when I've said, 'Why shouldn't they be married,'
# 1284. He'd say, 'Why should they?' no more words than that.'
# 1285. 'And after all why should they? John's been fair
# 1286. I take it. What was his was always hers.
# 1287. There was no quarrel about property.'
# 1288. 'Reason enough, there was no property.
# 1289. A friend or two as good as own the farm,
# 1290. Such as it is. It isn't worth the mortgage.'
# 1291. 'I mean Estelle has always held the purse.'
# 1292. 'The rights of that are harder to get at.
# 1293. I guess Estelle and I have filled the purse.
# 1294. 'Twas we let him have money, not he us.
# 1295. John's a bad farmer. I'm not blaming him.
# 1296. Take it year in, year out, he doesn't make much.
# 1297. We came here for a home for me, you know,
# 1298. Estelle to do the housework for the board
# 1299. Of both of us. But look how it turns out:
# 1300. She seems to have the housework, and besides,
# 1301. Half of the outdoor work, though as for that,
# 1302. He'd say she does it more because she likes it.
# 1303. You see our pretty things are all outdoors.
# 1304. Our hens and cows and pigs are always better
# 1305. Than folks like us have any business with.
# 1306. Farmers around twice as well off as we
# 1307. Haven't as good. They don't go with the farm.
# 1308. One thing you can't help liking about John,
# 1309. He's fond of nice things- too fond, some would say.
# 1310. But Estelle don't complain: she's like him there.
# 1311. She wants our hens to be the best there are.
# 1312. You never saw this room before a show,
# 1313. Full of lank, shivery, half-drowned birds
# 1314. In separate coops, having their plumage done.
# 1315. The smell of the wet feathers in the heat!
# 1316. You spoke of John's not being safe to stay with.
# 1317. You don't know what a gentle lot we are:
# 1318. We wouldn't hurt a hen! You ought to see us
# 1319. Moving a flock of hens from place to place.
# 1320. We're not allowed to take them upside down,
# 1321. All we can hold together by the legs.
# 1322. Two at a time's the rule, one on each arm,
# 1323. No matter how far and how many times
# 1324. We have to go.'
# 1325. 'You mean that's John's idea.'
# 1326. 'And we live up to it; or I don't know
# 1327. What childishness he wouldn't give way to.
# 1328. He manages to keep the upper hand
# 1329. On his own farm. He's boss. But as to hens:
# 1330. We fence our flowers in and the hens range.
# 1331. Nothing's too good for them. We say it pays.
# 1332. John likes to tell the offers he has had,
# 1333. Twenty for this cock, twenty-five for that.
# 1334. He never takes the money. If they're worth
# 1335. That much to sell, they're worth as much to keep.
# 1336. Bless you, it's all expense, though. Reach me down
# 1337. The little tin box on the cupboard shelf,
# 1338. The upper shelf, the tin box. That's the one.
# 1339. I'll show you. Here you are.'
# 1340. 'What's this?'
# 1341. 'A bill-
# 1342. For fifty dollars for one Langshang cock-
# 1343. Receipted. And the cock is in the yard.'
# 1344. 'Not in a glass case, then?'
# 1345. 'He'd need a tall one:
# 1346. He can eat off a barrel from the ground.
# 1347. He's been in a glass case, as you may say,
# 1348. The Crystal Palace, London. He's imported.
# 1349. John bought him, and we paid the bill with beads-
# 1350. Wampum, I call it. Mind, we don't complain.
# 1351. But you see, don't you, we take care of him.'
# 1352. 'And like it, too. It makes it all the worse.'
# 1353. 'It seems as if. And that's not all: he's helpless
# 1354. In ways that I can hardly tell you of.
# 1355. Sometimes he gets possessed to keep accounts
# 1356. To see where all the money goes so fast.
# 1357. You know how men will be ridiculous.
# 1358. But it's just fun the way he gets bedeviled-
# 1359. If he's untidy now, what will he be- - ?
# 1360. 'It makes it all the worse. You must be blind.'
# 1361. 'Estelle's the one. You needn't talk to me.'
# 1362. 'Can't you and I get to the root of it?
# 1363. What's the real trouble? What will satisfy her?'
# 1364. 'It's as I say: she's turned from him, that's all.'
# 1365. 'But why, when she's well off? Is it the neighbours,
# 1366. Being cut off from friends?'
# 1367. 'We have our friends.
# 1368. That isn't it. Folks aren't afraid of us.'
# 1369. 'She's let it worry her. You stood the strain,
# 1370. And you're her mother.'
# 1371. 'But I didn't always.
# 1372. I didn't relish it along at first.
# 1373. But I got wonted to it. And besides-
# 1374. John said I was too old to have grandchildren.
# 1375. But what's the use of talking when it's done?
# 1376. She won't come back- it's worse than that- she can't.'
# 1377. 'Why do you speak like that? What do you know?
# 1378. What do you mean?- she's done harm to herself?'
# 1379. 'I mean she's married- married someone else.'
# 1380. 'Oho, oho!'
# 1381. 'You don't believe me.'
# 1382. 'Yes, I do,
# 1383. Only too well. I knew there must be something!
# 1384. So that was what was back. She's bad, that's all!'
# 1385. 'Bad to get married when she had the chance?'
# 1386. 'Nonsense! See what's she done! But who, who- - '
# 1387. 'Who'd marry her straight out of such a mess?
# 1388. Say it right out- no matter for her mother.
# 1389. The man was found. I'd better name no names.
# 1390. John himself won't imagine who he is.'
# 1391. 'Then it's all up. I think I'll get away.
# 1392. You'll be expecting John. I pity Estelle;
# 1393. I suppose she deserves some pity, too.
# 1394. You ought to have the kitchen to yourself
# 1395. To break it to him. You may have the job.'
# 1396. 'You needn't think you're going to get away.
# 1397. John's almost here. I've had my eye on someone
# 1398. Coming down Ryan's Hill. I thought 'twas him.
# 1399. Here he is now. This box! Put it away.
# 1400. And this bill.'
# 1401. 'What's the hurry? He'll unhitch.'
# 1402. 'No, he won't, either. He'll just drop the reins
# 1403. And turn Doll out to pasture, rig and all.
# 1404. She won't get far before the wheels hang up
# 1405. On something- there's no harm. See, there he is!
# 1406. My, but he looks as if he must have heard!'
# 1407. John threw the door wide but he didn't enter.
# 1408. 'How are you, neighbour? Just the man I'm after.
# 1409. Isn't it Hell,' he said. 'I want to know.
# 1410. Come out here if you want to hear me talk.
# 1411. I'll talk to you, old woman, afterward.
# 1412. I've got some news that maybe isn't news.
# 1413. What are they trying to do to me, these two?'
# 1414. 'Do go along with him and stop his shouting.'
# 1415. She raised her voice against the closing door:
# 1416. 'Who wants to hear your news, you- dreadful fool?'
# 1417. A winter garden in an alder swamp,
# 1418. Where conies now come out to sun and romp,
# 1419. As near a paradise as it can be
# 1420. And not melt snow or start a dormant tree.
# 1421. It lifts existence on a plane of snow
# 1422. One level higher than the earth below,
# 1423. One level nearer heaven overhead,
# 1424. And last year's berries shining scarlet red.
# 1425. It lifts a gaunt luxuriating beast
# 1426. Where he can stretch and hold his highest feat
# 1427. On some wild apple tree's young tender bark,
# 1428. What well may prove the year's high girdle mark.
# 1429. So near to paradise all pairing ends:
# 1430. Here loveless birds now flock as winter friends,
# 1431. Content with bud-inspecting. They presume
# 1432. To say which buds are leaf and which are bloom.
# 1433. A feather-hammer gives a double knock.
# 1434. This Eden day is done at two o'clock.
# 1435. An hour of winter day might seem too short
# 1436. To make it worth life's while to wake and sport.

# %%
# Process each line: remove punctuation, convert to lowercase, split into words
processed_lines = []

for line in lines:
    # Remove punctuation and convert to lowercase
    line_clean = re.sub(r'[^a-zA-Z\s]', '', line)
    line_clean = line_clean.lower()
    # Split into words
    words = line_clean.split()
    # Add END token at the end of each line
    words.append('END')
    processed_lines.append(words)

print("\nProcessed lines (with END tokens):")
print("="*50)
for i, words in enumerate(processed_lines, 1):
    print(f"{i}. {words}")
# Out:
# Processed lines (with END tokens):
# ==================================================
# 1. ['two', 'roads', 'diverged', 'in', 'a', 'yellow', 'wood', 'END']
# 2. ['and', 'sorry', 'i', 'could', 'not', 'travel', 'both', 'END']
# 3. ['and', 'be', 'one', 'traveler', 'long', 'i', 'stood', 'END']
# 4. ['and', 'looked', 'down', 'one', 'as', 'far', 'as', 'i', 'could', 'END']
# 5. ['to', 'where', 'it', 'bent', 'in', 'the', 'undergrowth', 'END']
# 6. ['then', 'took', 'the', 'other', 'as', 'just', 'as', 'fair', 'END']
# 7. ['and', 'having', 'perhaps', 'the', 'better', 'claim', 'END']
# 8. ['because', 'it', 'was', 'grassy', 'and', 'wanted', 'wear', 'END']
# 9. ['though', 'as', 'for', 'that', 'the', 'passing', 'there', 'END']
# 10. ['had', 'worn', 'them', 'really', 'about', 'the', 'same', 'END']
# 11. ['and', 'both', 'that', 'morning', 'equally', 'lay', 'END']
# 12. ['in', 'leaves', 'no', 'step', 'had', 'trodden', 'black', 'END']
# 13. ['oh', 'i', 'kept', 'the', 'first', 'for', 'another', 'day', 'END']
# 14. ['yet', 'knowing', 'how', 'way', 'leads', 'on', 'to', 'way', 'END']
# 15. ['i', 'doubted', 'if', 'i', 'should', 'ever', 'come', 'back', 'END']
# 16. ['i', 'shall', 'be', 'telling', 'this', 'with', 'a', 'sigh', 'END']
# 17. ['somewhere', 'ages', 'and', 'ages', 'hence', 'END']
# 18. ['two', 'roads', 'diverged', 'in', 'a', 'wood', 'and', 'i', 'END']
# 19. ['i', 'took', 'the', 'one', 'less', 'traveled', 'by', 'END']
# 20. ['and', 'that', 'has', 'made', 'all', 'the', 'difference', 'END']
# 21. ['whose', 'woods', 'these', 'are', 'i', 'think', 'i', 'know', 'END']
# 22. ['his', 'house', 'is', 'in', 'the', 'village', 'though', 'END']
# 23. ['he', 'will', 'not', 'see', 'me', 'stopping', 'here', 'END']
# 24. ['to', 'watch', 'his', 'woods', 'fill', 'up', 'with', 'snow', 'END']
# 25. ['my', 'little', 'horse', 'must', 'think', 'it', 'queer', 'END']
# 26. ['to', 'stop', 'without', 'a', 'farmhouse', 'near', 'END']
# 27. ['between', 'the', 'woods', 'and', 'frozen', 'lake', 'END']
# 28. ['the', 'darkest', 'evening', 'of', 'the', 'year', 'END']
# 29. ['he', 'gives', 'his', 'harness', 'bells', 'a', 'shake', 'END']
# 30. ['to', 'ask', 'if', 'there', 'is', 'some', 'mistake', 'END']
# 31. ['the', 'only', 'other', 'sounds', 'the', 'sweep', 'END']
# 32. ['of', 'easy', 'wind', 'and', 'downy', 'flake', 'END']
# 33. ['the', 'woods', 'are', 'lovely', 'dark', 'and', 'deep', 'END']
# 34. ['but', 'i', 'have', 'promises', 'to', 'keep', 'END']
# 35. ['and', 'miles', 'to', 'go', 'before', 'i', 'sleep', 'END']
# 36. ['and', 'miles', 'to', 'go', 'before', 'i', 'sleep', 'END']
# 37. ['some', 'say', 'the', 'world', 'will', 'end', 'in', 'fire', 'END']
# 38. ['some', 'say', 'in', 'ice', 'END']
# 39. ['from', 'what', 'ive', 'tasted', 'of', 'desire', 'END']
# 40. ['i', 'hold', 'with', 'those', 'who', 'favor', 'fire', 'END']
# 41. ['but', 'if', 'it', 'had', 'to', 'perish', 'twice', 'END']
# 42. ['i', 'think', 'i', 'know', 'enough', 'of', 'hate', 'END']
# 43. ['to', 'say', 'that', 'for', 'destruction', 'ice', 'END']
# 44. ['is', 'also', 'great', 'END']
# 45. ['and', 'would', 'suffice', 'END']
# 46. ['natures', 'first', 'green', 'is', 'gold', 'END']
# 47. ['her', 'hardest', 'hue', 'to', 'hold', 'END']
# 48. ['her', 'early', 'leafs', 'a', 'flower', 'END']
# 49. ['but', 'only', 'so', 'an', 'hour', 'END']
# 50. ['then', 'leaf', 'subsides', 'to', 'leaf', 'END']
# 51. ['so', 'eden', 'sank', 'to', 'grief', 'END']
# 52. ['so', 'dawn', 'goes', 'down', 'to', 'day', 'END']
# 53. ['nothing', 'gold', 'can', 'stay', 'END']
# 54. ['i', 'have', 'been', 'one', 'acquainted', 'with', 'the', 'night', 'END']
# 55. ['i', 'have', 'walked', 'out', 'in', 'rain', 'and', 'back', 'in', 'rain', 'END']
# 56. ['i', 'have', 'outwalked', 'the', 'furthest', 'city', 'light', 'END']
# 57. ['i', 'have', 'looked', 'down', 'the', 'saddest', 'city', 'lane', 'END']
# 58. ['i', 'have', 'passed', 'by', 'the', 'watchman', 'on', 'his', 'beat', 'END']
# 59. ['and', 'dropped', 'my', 'eyes', 'unwilling', 'to', 'explain', 'END']
# 60. ['i', 'have', 'stood', 'still', 'and', 'stopped', 'the', 'sound', 'of', 'feet', 'END']
# 61. ['when', 'far', 'away', 'an', 'interrupted', 'cry', 'END']
# 62. ['came', 'over', 'houses', 'from', 'another', 'street', 'END']
# 63. ['but', 'not', 'to', 'call', 'me', 'back', 'or', 'say', 'goodbye', 'END']
# 64. ['and', 'further', 'still', 'at', 'an', 'unearthly', 'height', 'END']
# 65. ['one', 'luminary', 'clock', 'against', 'the', 'sky', 'END']
# 66. ['proclaimed', 'the', 'time', 'was', 'neither', 'wrong', 'nor', 'right', 'END']
# 67. ['i', 'have', 'been', 'one', 'acquainted', 'with', 'the', 'night', 'END']
# 68. ['when', 'i', 'go', 'up', 'through', 'the', 'mowing', 'field', 'END']
# 69. ['the', 'headless', 'aftermath', 'END']
# 70. ['smoothlaid', 'like', 'thatch', 'with', 'the', 'heavy', 'dew', 'END']
# 71. ['half', 'closes', 'the', 'garden', 'path', 'END']
# 72. ['and', 'when', 'i', 'come', 'to', 'the', 'garden', 'ground', 'END']
# 73. ['the', 'whir', 'of', 'sober', 'birds', 'END']
# 74. ['up', 'from', 'the', 'tangle', 'of', 'withered', 'weeds', 'END']
# 75. ['is', 'sadder', 'than', 'any', 'words', 'END']
# 76. ['a', 'tree', 'beside', 'the', 'wall', 'stands', 'bare', 'END']
# 77. ['but', 'a', 'leaf', 'that', 'lingered', 'brown', 'END']
# 78. ['disturbed', 'i', 'doubt', 'not', 'by', 'my', 'thought', 'END']
# 79. ['comes', 'softly', 'rattling', 'down', 'END']
# 80. ['i', 'end', 'not', 'far', 'from', 'my', 'going', 'forth', 'END']
# 81. ['by', 'picking', 'the', 'faded', 'blue', 'END']
# 82. ['of', 'the', 'last', 'remaining', 'aster', 'flower', 'END']
# 83. ['to', 'carry', 'again', 'to', 'you', 'END']
# 84. ['a', 'voice', 'said', 'look', 'me', 'in', 'the', 'stars', 'END']
# 85. ['and', 'tell', 'me', 'truly', 'men', 'of', 'earth', 'END']
# 86. ['if', 'all', 'the', 'soulandbody', 'scars', 'END']
# 87. ['were', 'not', 'too', 'much', 'to', 'pay', 'for', 'birth', 'END']
# 88. ['to', 'think', 'to', 'know', 'the', 'country', 'and', 'now', 'know', 'END']
# 89. ['the', 'hillside', 'on', 'the', 'day', 'the', 'sun', 'lets', 'go', 'END']
# 90. ['ten', 'million', 'silver', 'lizards', 'out', 'of', 'snow', 'END']
# 91. ['as', 'often', 'as', 'ive', 'seen', 'it', 'done', 'before', 'END']
# 92. ['i', 'cant', 'pretend', 'to', 'tell', 'the', 'way', 'its', 'done', 'END']
# 93. ['it', 'looks', 'as', 'if', 'some', 'magic', 'of', 'the', 'sun', 'END']
# 94. ['lifted', 'the', 'rug', 'that', 'bred', 'them', 'on', 'the', 'floor', 'END']
# 95. ['and', 'the', 'light', 'breaking', 'on', 'them', 'made', 'them', 'run', 'END']
# 96. ['but', 'if', 'i', 'though', 'to', 'stop', 'the', 'wet', 'stampede', 'END']
# 97. ['and', 'caught', 'one', 'silver', 'lizard', 'by', 'the', 'tail', 'END']
# 98. ['and', 'put', 'my', 'foot', 'on', 'one', 'without', 'avail', 'END']
# 99. ['and', 'threw', 'myself', 'wetelbowed', 'and', 'wetkneed', 'END']
# 100. ['in', 'front', 'of', 'twenty', 'others', 'wriggling', 'speed', 'END']
# 101. ['in', 'the', 'confusion', 'of', 'them', 'all', 'aglitter', 'END']
# 102. ['and', 'birds', 'that', 'joined', 'in', 'the', 'excited', 'fun', 'END']
# 103. ['by', 'doubling', 'and', 'redoubling', 'song', 'and', 'twitter', 'END']
# 104. ['i', 'have', 'no', 'doubt', 'id', 'end', 'by', 'holding', 'none', 'END']
# 105. ['it', 'takes', 'the', 'moon', 'for', 'this', 'the', 'suns', 'a', 'wizard', 'END']
# 106. ['by', 'all', 'i', 'tell', 'but', 'sos', 'the', 'moon', 'a', 'witch', 'END']
# 107. ['from', 'the', 'high', 'west', 'she', 'makes', 'a', 'gentle', 'cast', 'END']
# 108. ['and', 'suddenly', 'without', 'a', 'jerk', 'or', 'twitch', 'END']
# 109. ['she', 'has', 'her', 'speel', 'on', 'every', 'single', 'lizard', 'END']
# 110. ['i', 'fancied', 'when', 'i', 'looked', 'at', 'six', 'oclock', 'END']
# 111. ['the', 'swarm', 'still', 'ran', 'and', 'scuttled', 'just', 'as', 'fast', 'END']
# 112. ['the', 'moon', 'was', 'waiting', 'for', 'her', 'chill', 'effect', 'END']
# 113. ['i', 'looked', 'at', 'nine', 'the', 'swarm', 'was', 'turned', 'to', 'rock', 'END']
# 114. ['in', 'every', 'lifelike', 'posture', 'of', 'the', 'swarm', 'END']
# 115. ['transfixed', 'on', 'mountain', 'slopes', 'almost', 'erect', 'END']
# 116. ['across', 'each', 'other', 'and', 'side', 'by', 'side', 'they', 'lay', 'END']
# 117. ['the', 'spell', 'that', 'so', 'could', 'hold', 'them', 'as', 'they', 'were', 'END']
# 118. ['was', 'wrought', 'through', 'trees', 'without', 'a', 'breath', 'of', 'storm', 'END']
# 119. ['to', 'make', 'a', 'leaf', 'if', 'there', 'had', 'been', 'one', 'stir', 'END']
# 120. ['one', 'lizard', 'at', 'the', 'end', 'of', 'every', 'ray', 'END']
# 121. ['the', 'thought', 'of', 'my', 'attempting', 'such', 'a', 'stray', 'END']
# 122. ['once', 'on', 'the', 'kind', 'of', 'day', 'called', 'weather', 'breeder', 'END']
# 123. ['when', 'the', 'heat', 'slowly', 'hazes', 'and', 'the', 'sun', 'END']
# 124. ['by', 'its', 'own', 'power', 'seems', 'to', 'be', 'undone', 'END']
# 125. ['i', 'was', 'half', 'boring', 'through', 'half', 'climbing', 'through', 'END']
# 126. ['a', 'swamp', 'of', 'cedar', 'choked', 'with', 'oil', 'of', 'cedar', 'END']
# 127. ['and', 'scurf', 'of', 'plants', 'and', 'weary', 'and', 'overheated', 'END']
# 128. ['and', 'sorry', 'i', 'ever', 'left', 'the', 'road', 'i', 'knew', 'END']
# 129. ['i', 'paused', 'and', 'rested', 'on', 'a', 'sort', 'of', 'hook', 'END']
# 130. ['that', 'had', 'me', 'by', 'the', 'coat', 'as', 'good', 'as', 'seated', 'END']
# 131. ['and', 'since', 'there', 'was', 'no', 'other', 'way', 'to', 'look', 'END']
# 132. ['looked', 'up', 'toward', 'heaven', 'and', 'there', 'against', 'the', 'blue', 'END']
# 133. ['stood', 'over', 'me', 'a', 'resurrected', 'tree', 'END']
# 134. ['a', 'tree', 'that', 'had', 'been', 'down', 'and', 'raised', 'again', 'END']
# 135. ['a', 'barkless', 'spectre', 'he', 'had', 'halted', 'too', 'END']
# 136. ['as', 'if', 'for', 'fear', 'of', 'treading', 'upon', 'me', 'END']
# 137. ['i', 'saw', 'the', 'strange', 'position', 'of', 'his', 'hands', 'END']
# 138. ['up', 'at', 'his', 'shoulders', 'dragging', 'yellow', 'strands', 'END']
# 139. ['of', 'wire', 'with', 'something', 'in', 'it', 'from', 'men', 'to', 'men', 'END']
# 140. ['you', 'here', 'i', 'said', 'where', 'arent', 'you', 'nowadays', 'END']
# 141. ['and', 'whats', 'the', 'news', 'you', 'carryif', 'you', 'know', 'END']
# 142. ['and', 'tell', 'me', 'where', 'youre', 'off', 'formontreal', 'END']
# 143. ['me', 'im', 'not', 'off', 'for', 'anywhere', 'at', 'all', 'END']
# 144. ['sometimes', 'i', 'wander', 'out', 'of', 'beaten', 'ways', 'END']
# 145. ['half', 'looking', 'for', 'the', 'orchid', 'calypso', 'END']
# 146. ['brown', 'lived', 'at', 'such', 'a', 'lofty', 'farm', 'END']
# 147. ['that', 'everyone', 'for', 'miles', 'could', 'see', 'END']
# 148. ['his', 'lantern', 'when', 'he', 'did', 'his', 'chores', 'END']
# 149. ['in', 'winter', 'after', 'halfpast', 'three', 'END']
# 150. ['and', 'many', 'must', 'have', 'seen', 'him', 'make', 'END']
# 151. ['his', 'wild', 'descent', 'from', 'there', 'one', 'night', 'END']
# 152. ['cross', 'lots', 'cross', 'walls', 'cross', 'everything', 'END']
# 153. ['describing', 'rings', 'of', 'lantern', 'light', 'END']
# 154. ['between', 'the', 'house', 'and', 'barn', 'the', 'gale', 'END']
# 155. ['got', 'him', 'by', 'something', 'he', 'had', 'on', 'END']
# 156. ['and', 'blew', 'him', 'out', 'on', 'the', 'icy', 'crust', 'END']
# 157. ['that', 'cased', 'the', 'world', 'and', 'he', 'was', 'gone', 'END']
# 158. ['walls', 'were', 'all', 'buried', 'trees', 'were', 'few', 'END']
# 159. ['he', 'saw', 'no', 'stay', 'unless', 'he', 'stove', 'END']
# 160. ['a', 'hole', 'in', 'somewhere', 'with', 'his', 'heel', 'END']
# 161. ['but', 'though', 'repeatedly', 'he', 'strove', 'END']
# 162. ['and', 'stamped', 'and', 'said', 'things', 'to', 'himself', 'END']
# 163. ['and', 'sometimes', 'something', 'seemed', 'to', 'yield', 'END']
# 164. ['he', 'gained', 'no', 'foothold', 'but', 'pursued', 'END']
# 165. ['his', 'journey', 'down', 'from', 'field', 'to', 'field', 'END']
# 166. ['sometimes', 'he', 'came', 'with', 'arms', 'outspread', 'END']
# 167. ['like', 'wings', 'revolving', 'in', 'the', 'scene', 'END']
# 168. ['upon', 'his', 'longer', 'axis', 'and', 'END']
# 169. ['with', 'no', 'small', 'dignity', 'of', 'mien', 'END']
# 170. ['faster', 'or', 'slower', 'as', 'he', 'chanced', 'END']
# 171. ['sitting', 'or', 'standing', 'as', 'he', 'chose', 'END']
# 172. ['according', 'as', 'he', 'feared', 'to', 'risk', 'END']
# 173. ['his', 'neck', 'or', 'thought', 'to', 'spare', 'his', 'clothes', 'END']
# 174. ['he', 'never', 'let', 'the', 'lantern', 'drop', 'END']
# 175. ['and', 'some', 'exclaimed', 'who', 'saw', 'afar', 'END']
# 176. ['the', 'figures', 'he', 'described', 'with', 'it', 'END']
# 177. ['i', 'wonder', 'what', 'those', 'signals', 'are', 'END']
# 178. ['brown', 'makes', 'at', 'such', 'an', 'hour', 'of', 'night', 'END']
# 179. ['hes', 'celebrating', 'something', 'strange', 'END']
# 180. ['i', 'wonder', 'if', 'hes', 'sold', 'his', 'farm', 'END']
# 181. ['or', 'been', 'made', 'master', 'of', 'the', 'grange', 'END']
# 182. ['he', 'reeled', 'he', 'lurched', 'he', 'bobbed', 'he', 'checked', 'END']
# 183. ['he', 'fell', 'and', 'made', 'the', 'lantern', 'rattle', 'END']
# 184. ['but', 'saved', 'the', 'light', 'from', 'going', 'out', 'END']
# 185. ['so', 'halfway', 'down', 'he', 'fought', 'the', 'battle', 'END']
# 186. ['incredulous', 'of', 'his', 'own', 'bad', 'luck', 'END']
# 187. ['and', 'then', 'becoming', 'reconciled', 'END']
# 188. ['to', 'everything', 'he', 'gave', 'it', 'up', 'END']
# 189. ['and', 'came', 'down', 'like', 'a', 'coasting', 'child', 'END']
# 190. ['wellibe', 'that', 'was', 'all', 'he', 'said', 'END']
# 191. ['as', 'standing', 'in', 'the', 'river', 'road', 'END']
# 192. ['he', 'looked', 'back', 'up', 'the', 'slippery', 'slope', 'END']
# 193. ['two', 'miles', 'it', 'was', 'to', 'his', 'abode', 'END']
# 194. ['sometimes', 'as', 'an', 'authority', 'END']
# 195. ['on', 'motorcars', 'im', 'asked', 'if', 'i', 'END']
# 196. ['should', 'say', 'our', 'stock', 'was', 'petered', 'out', 'END']
# 197. ['and', 'this', 'is', 'my', 'sincere', 'reply', 'END']
# 198. ['yankees', 'are', 'what', 'they', 'always', 'were', 'END']
# 199. ['dont', 'think', 'brown', 'ever', 'gave', 'up', 'hope', 'END']
# 200. ['of', 'getting', 'home', 'again', 'because', 'END']
# 201. ['he', 'couldnt', 'climb', 'that', 'slippery', 'slope', 'END']
# 202. ['or', 'even', 'thought', 'of', 'standing', 'there', 'END']
# 203. ['until', 'the', 'january', 'thaw', 'END']
# 204. ['should', 'take', 'the', 'polish', 'off', 'the', 'crust', 'END']
# 205. ['he', 'bowed', 'with', 'grace', 'to', 'natural', 'law', 'END']
# 206. ['and', 'then', 'went', 'round', 'it', 'on', 'his', 'feet', 'END']
# 207. ['after', 'the', 'manner', 'of', 'our', 'stock', 'END']
# 208. ['not', 'much', 'concerned', 'for', 'those', 'to', 'whom', 'END']
# 209. ['at', 'that', 'particular', 'time', 'oclock', 'END']
# 210. ['it', 'must', 'have', 'looked', 'as', 'if', 'the', 'course', 'END']
# 211. ['he', 'steered', 'was', 'really', 'straight', 'away', 'END']
# 212. ['from', 'that', 'which', 'he', 'was', 'headed', 'for', 'END']
# 213. ['not', 'much', 'concerned', 'for', 'them', 'i', 'say', 'END']
# 214. ['no', 'more', 'so', 'than', 'became', 'a', 'man', 'END']
# 215. ['and', 'politician', 'at', 'odd', 'seasons', 'END']
# 216. ['ive', 'kept', 'brown', 'standing', 'in', 'the', 'cold', 'END']
# 217. ['while', 'i', 'invested', 'him', 'with', 'reasons', 'END']
# 218. ['but', 'now', 'he', 'snapped', 'his', 'eyes', 'three', 'times', 'END']
# 219. ['then', 'shook', 'his', 'lantern', 'saying', 'iles', 'END']
# 220. ['bout', 'out', 'and', 'took', 'the', 'long', 'way', 'home', 'END']
# 221. ['by', 'road', 'a', 'matter', 'of', 'several', 'miles', 'END']
# 222. ['now', 'that', 'theyve', 'got', 'it', 'settled', 'whose', 'i', 'be', 'END']
# 223. ['im', 'going', 'to', 'tell', 'them', 'something', 'they', 'wont', 'like', 'END']
# 224. ['theyve', 'got', 'it', 'settled', 'wrong', 'and', 'i', 'can', 'prove', 'it', 'END']
# 225. ['flattered', 'i', 'must', 'be', 'to', 'have', 'two', 'towns', 'fighting', 'END']
# 226. ['to', 'make', 'a', 'present', 'of', 'me', 'to', 'each', 'other', 'END']
# 227. ['they', 'dont', 'dispose', 'me', 'either', 'one', 'of', 'them', 'END']
# 228. ['to', 'spare', 'them', 'any', 'trouble', 'double', 'troubles', 'END']
# 229. ['always', 'the', 'witchs', 'motto', 'anyway', 'END']
# 230. ['ill', 'double', 'theirs', 'for', 'both', 'of', 'them', 'you', 'watch', 'me', 'END']
# 231. ['theyll', 'find', 'theyve', 'got', 'the', 'whole', 'thing', 'to', 'do', 'over', 'END']
# 232. ['that', 'is', 'if', 'facts', 'is', 'what', 'they', 'want', 'to', 'go', 'by', 'END']
# 233. ['they', 'set', 'a', 'lot', 'now', 'dont', 'they', 'by', 'a', 'record', 'END']
# 234. ['of', 'arthur', 'amys', 'having', 'once', 'been', 'up', 'END']
# 235. ['for', 'hog', 'reeve', 'in', 'march', 'meeting', 'here', 'in', 'warren', 'END']
# 236. ['i', 'could', 'have', 'told', 'them', 'any', 'time', 'this', 'twelvemonth', 'END']
# 237. ['the', 'arthur', 'amy', 'i', 'was', 'married', 'to', 'END']
# 238. ['couldnt', 'have', 'been', 'the', 'one', 'they', 'say', 'was', 'up', 'END']
# 239. ['in', 'warren', 'at', 'march', 'meeting', 'for', 'the', 'reason', 'END']
# 240. ['he', 'want', 'but', 'fifteen', 'at', 'the', 'time', 'they', 'say', 'END']
# 241. ['the', 'arthur', 'amy', 'i', 'was', 'married', 'to', 'END']
# 242. ['voted', 'the', 'only', 'times', 'he', 'ever', 'voted', 'END']
# 243. ['which', 'wasnt', 'many', 'in', 'the', 'town', 'of', 'wentworth', 'END']
# 244. ['one', 'of', 'the', 'times', 'was', 'when', 'twas', 'in', 'the', 'warrant', 'END']
# 245. ['to', 'see', 'if', 'the', 'town', 'wanted', 'to', 'take', 'over', 'END']
# 246. ['the', 'tote', 'road', 'to', 'our', 'clearing', 'where', 'we', 'lived', 'END']
# 247. ['ill', 'tell', 'you', 'whod', 'remember', 'heman', 'lapish', 'END']
# 248. ['their', 'arthur', 'amy', 'was', 'the', 'father', 'of', 'mine', 'END']
# 249. ['so', 'now', 'theyve', 'dragged', 'it', 'through', 'the', 'law', 'courts', 'once', 'END']
# 250. ['i', 'guess', 'theyd', 'better', 'drag', 'it', 'through', 'again', 'END']
# 251. ['wentworth', 'and', 'warrens', 'both', 'good', 'towns', 'to', 'live', 'in', 'END']
# 252. ['only', 'i', 'happen', 'to', 'prefer', 'to', 'live', 'END']
# 253. ['in', 'wentworth', 'from', 'now', 'on', 'and', 'when', 'alls', 'said', 'END']
# 254. ['rights', 'right', 'and', 'the', 'temptation', 'to', 'do', 'right', 'END']
# 255. ['when', 'i', 'can', 'hurt', 'someone', 'by', 'doing', 'it', 'END']
# 256. ['has', 'always', 'been', 'too', 'much', 'for', 'me', 'it', 'has', 'END']
# 257. ['i', 'know', 'of', 'some', 'folks', 'thatd', 'be', 'set', 'up', 'END']
# 258. ['at', 'having', 'in', 'their', 'town', 'a', 'noted', 'witch', 'END']
# 259. ['but', 'most', 'would', 'have', 'to', 'think', 'of', 'the', 'expense', 'END']
# 260. ['that', 'even', 'i', 'would', 'be', 'they', 'ought', 'to', 'know', 'END']
# 261. ['that', 'as', 'a', 'witch', 'id', 'often', 'milk', 'a', 'bat', 'END']
# 262. ['and', 'thatd', 'be', 'enough', 'to', 'last', 'for', 'days', 'END']
# 263. ['itd', 'make', 'my', 'position', 'stronger', 'i', 'think', 'END']
# 264. ['if', 'i', 'was', 'to', 'consent', 'to', 'give', 'some', 'sign', 'END']
# 265. ['to', 'make', 'it', 'surer', 'that', 'i', 'was', 'a', 'witch', 'END']
# 266. ['it', 'want', 'no', 'sign', 'i', 'spose', 'when', 'mallice', 'huse', 'END']
# 267. ['said', 'that', 'i', 'took', 'him', 'out', 'in', 'his', 'old', 'age', 'END']
# 268. ['and', 'rode', 'all', 'over', 'everything', 'on', 'him', 'END']
# 269. ['until', 'id', 'had', 'him', 'worn', 'to', 'skin', 'and', 'bones', 'END']
# 270. ['and', 'if', 'id', 'left', 'him', 'hitched', 'unblanketed', 'END']
# 271. ['in', 'front', 'of', 'one', 'town', 'hall', 'id', 'left', 'him', 'hitched', 'END']
# 272. ['in', 'front', 'of', 'every', 'one', 'in', 'grafton', 'county', 'END']
# 273. ['some', 'cried', 'shame', 'on', 'me', 'not', 'to', 'blanket', 'him', 'END']
# 274. ['the', 'poor', 'old', 'man', 'it', 'would', 'have', 'been', 'all', 'right', 'END']
# 275. ['if', 'some', 'one', 'hadnt', 'said', 'to', 'gnaw', 'the', 'posts', 'END']
# 276. ['he', 'stood', 'beside', 'and', 'leave', 'his', 'trade', 'mark', 'on', 'them', 'END']
# 277. ['so', 'they', 'could', 'recognize', 'them', 'not', 'a', 'post', 'END']
# 278. ['that', 'they', 'could', 'hear', 'tell', 'of', 'was', 'scarified', 'END']
# 279. ['they', 'made', 'him', 'keep', 'on', 'gnawing', 'till', 'he', 'whined', 'END']
# 280. ['then', 'that', 'same', 'smarty', 'someone', 'said', 'to', 'look', 'END']
# 281. ['hed', 'bet', 'huse', 'was', 'a', 'cribber', 'and', 'had', 'gnawed', 'END']
# 282. ['the', 'crib', 'he', 'slept', 'in', 'and', 'as', 'sures', 'youre', 'born', 'END']
# 283. ['they', 'found', 'hed', 'gnawed', 'the', 'four', 'posts', 'of', 'his', 'bed', 'END']
# 284. ['all', 'four', 'of', 'them', 'to', 'splinters', 'what', 'did', 'that', 'prove', 'END']
# 285. ['not', 'that', 'he', 'hadnt', 'gnawed', 'the', 'hitching', 'posts', 'END']
# 286. ['he', 'said', 'he', 'had', 'besides', 'because', 'a', 'horse', 'END']
# 287. ['gnaws', 'in', 'the', 'stable', 'aint', 'no', 'proof', 'to', 'me', 'END']
# 288. ['he', 'dont', 'gnaw', 'trees', 'and', 'posts', 'and', 'fences', 'too', 'END']
# 289. ['but', 'everybody', 'took', 'it', 'for', 'proof', 'END']
# 290. ['i', 'was', 'a', 'strapping', 'girl', 'of', 'twenty', 'then', 'END']
# 291. ['the', 'smarty', 'someone', 'who', 'spoiled', 'everything', 'END']
# 292. ['was', 'arthur', 'amy', 'you', 'know', 'who', 'he', 'was', 'END']
# 293. ['that', 'was', 'the', 'way', 'he', 'started', 'courting', 'me', 'END']
# 294. ['he', 'never', 'said', 'much', 'after', 'we', 'were', 'married', 'END']
# 295. ['but', 'i', 'mistrusted', 'he', 'was', 'none', 'too', 'proud', 'END']
# 296. ['of', 'having', 'interfered', 'in', 'the', 'huse', 'business', 'END']
# 297. ['i', 'guess', 'he', 'found', 'he', 'got', 'more', 'out', 'of', 'me', 'END']
# 298. ['by', 'having', 'me', 'a', 'witch', 'or', 'something', 'happened', 'END']
# 299. ['to', 'turn', 'him', 'round', 'he', 'got', 'to', 'saying', 'things', 'END']
# 300. ['to', 'undo', 'what', 'hed', 'done', 'and', 'make', 'it', 'right', 'END']
# 301. ['like', 'no', 'she', 'aint', 'come', 'back', 'from', 'kiting', 'yet', 'END']
# 302. ['last', 'night', 'was', 'one', 'of', 'her', 'nights', 'out', 'shes', 'kiting', 'END']
# 303. ['she', 'thinks', 'when', 'the', 'wind', 'makes', 'a', 'night', 'of', 'it', 'END']
# 304. ['she', 'might', 'as', 'well', 'herself', 'but', 'he', 'liked', 'best', 'END']
# 305. ['to', 'let', 'on', 'he', 'was', 'plagued', 'to', 'death', 'with', 'me', 'END']
# 306. ['if', 'anyone', 'had', 'seen', 'me', 'coming', 'home', 'END']
# 307. ['over', 'the', 'ridgepole', 'stride', 'of', 'a', 'broomstick', 'END']
# 308. ['as', 'often', 'as', 'he', 'had', 'in', 'the', 'tail', 'of', 'the', 'night', 'END']
# 309. ['he', 'guessed', 'theyd', 'know', 'what', 'he', 'had', 'to', 'put', 'up', 'with', 'END']
# 310. ['well', 'i', 'showed', 'arthur', 'amy', 'signs', 'enough', 'END']
# 311. ['off', 'from', 'the', 'house', 'as', 'far', 'as', 'we', 'could', 'keep', 'END']
# 312. ['and', 'from', 'barn', 'smells', 'you', 'cant', 'wash', 'out', 'of', 'ploughed', 'ground', 'END']
# 313. ['with', 'all', 'the', 'rain', 'and', 'snow', 'of', 'seven', 'years', 'END']
# 314. ['and', 'i', 'dont', 'mean', 'just', 'skulls', 'of', 'rogers', 'rangers', 'END']
# 315. ['on', 'moosilauke', 'but', 'woman', 'signs', 'to', 'man', 'END']
# 316. ['only', 'bewitched', 'so', 'i', 'would', 'last', 'him', 'longer', 'END']
# 317. ['up', 'where', 'the', 'trees', 'grow', 'short', 'the', 'mosses', 'tall', 'END']
# 318. ['i', 'made', 'him', 'gather', 'me', 'wet', 'snow', 'berries', 'END']
# 319. ['on', 'slippery', 'rocks', 'beside', 'a', 'waterfall', 'END']
# 320. ['i', 'made', 'him', 'do', 'it', 'for', 'me', 'in', 'the', 'dark', 'END']
# 321. ['and', 'he', 'liked', 'everything', 'i', 'made', 'him', 'do', 'END']
# 322. ['i', 'hope', 'if', 'he', 'is', 'where', 'he', 'sees', 'me', 'now', 'END']
# 323. ['hes', 'so', 'far', 'off', 'he', 'cant', 'see', 'what', 'ive', 'come', 'to', 'END']
# 324. ['you', 'can', 'come', 'down', 'from', 'everything', 'to', 'nothing', 'END']
# 325. ['all', 'is', 'if', 'id', 'aknown', 'when', 'i', 'was', 'young', 'END']
# 326. ['and', 'full', 'of', 'it', 'that', 'this', 'would', 'be', 'the', 'end', 'END']
# 327. ['it', 'doesnt', 'seem', 'as', 'if', 'id', 'had', 'the', 'courage', 'END']
# 328. ['to', 'make', 'so', 'free', 'and', 'kick', 'up', 'in', 'folks', 'faces', 'END']
# 329. ['i', 'might', 'have', 'but', 'it', 'doesnt', 'seem', 'as', 'if', 'END']
# 330. ['old', 'davis', 'owned', 'a', 'solid', 'mica', 'mountain', 'END']
# 331. ['in', 'dalton', 'that', 'would', 'someday', 'make', 'his', 'fortune', 'END']
# 332. ['thered', 'been', 'some', 'boston', 'people', 'out', 'to', 'see', 'it', 'END']
# 333. ['and', 'experts', 'said', 'that', 'deep', 'down', 'in', 'the', 'mountain', 'END']
# 334. ['the', 'mica', 'sheets', 'were', 'big', 'as', 'plateglass', 'windows', 'END']
# 335. ['hed', 'like', 'to', 'take', 'me', 'there', 'and', 'show', 'it', 'to', 'me', 'END']
# 336. ['ill', 'tell', 'you', 'what', 'you', 'show', 'me', 'you', 'remember', 'END']
# 337. ['you', 'said', 'you', 'knew', 'the', 'place', 'where', 'once', 'on', 'kinsman', 'END']
# 338. ['the', 'early', 'mormons', 'made', 'a', 'settlement', 'END']
# 339. ['and', 'built', 'a', 'stone', 'baptismal', 'font', 'outdoors', 'END']
# 340. ['but', 'smith', 'or', 'someone', 'called', 'them', 'off', 'the', 'mountain', 'END']
# 341. ['to', 'go', 'west', 'to', 'a', 'worse', 'fight', 'with', 'the', 'desert', 'END']
# 342. ['you', 'said', 'youd', 'seen', 'the', 'stone', 'baptismal', 'font', 'END']
# 343. ['well', 'take', 'me', 'there', 'END']
# 344. ['someday', 'i', 'will', 'END']
# 345. ['today', 'END']
# 346. ['huh', 'that', 'old', 'bathtub', 'what', 'is', 'that', 'to', 'see', 'END']
# 347. ['lets', 'talk', 'about', 'it', 'END']
# 348. ['lets', 'go', 'see', 'the', 'place', 'END']
# 349. ['to', 'shut', 'you', 'up', 'ill', 'tell', 'you', 'what', 'ill', 'do', 'END']
# 350. ['ill', 'find', 'that', 'fountain', 'if', 'it', 'takes', 'all', 'summer', 'END']
# 351. ['and', 'both', 'of', 'our', 'united', 'strengths', 'to', 'do', 'it', 'END']
# 352. ['youve', 'lost', 'it', 'then', 'END']
# 353. ['not', 'so', 'but', 'i', 'can', 'find', 'it', 'END']
# 354. ['no', 'doubt', 'its', 'grown', 'up', 'some', 'to', 'woods', 'around', 'it', 'END']
# 355. ['the', 'mountain', 'may', 'have', 'shifted', 'since', 'i', 'saw', 'it', 'END']
# 356. ['in', 'eightyfive', 'END']
# 357. ['as', 'long', 'ago', 'as', 'that', 'END']
# 358. ['if', 'i', 'remember', 'rightly', 'it', 'had', 'sprung', 'END']
# 359. ['a', 'leak', 'and', 'emptied', 'then', 'and', 'forty', 'years', 'END']
# 360. ['can', 'do', 'a', 'good', 'deal', 'to', 'bad', 'masonry', 'END']
# 361. ['you', 'wont', 'see', 'any', 'mormon', 'swimming', 'in', 'it', 'END']
# 362. ['but', 'you', 'have', 'said', 'it', 'and', 'were', 'off', 'to', 'find', 'it', 'END']
# 363. ['old', 'as', 'i', 'am', 'im', 'going', 'to', 'let', 'myself', 'END']
# 364. ['be', 'dragged', 'by', 'you', 'all', 'over', 'everywhere', 'END']
# 365. ['i', 'thought', 'you', 'were', 'a', 'guide', 'END']
# 366. ['i', 'am', 'a', 'guide', 'END']
# 367. ['and', 'thats', 'why', 'i', 'cant', 'decently', 'refuse', 'you', 'END']
# 368. ['we', 'made', 'a', 'day', 'of', 'it', 'out', 'of', 'the', 'world', 'END']
# 369. ['ascending', 'to', 'descend', 'to', 'reascend', 'END']
# 370. ['the', 'old', 'man', 'seriously', 'took', 'his', 'bearings', 'END']
# 371. ['and', 'spoke', 'his', 'doubts', 'in', 'every', 'open', 'place', 'END']
# 372. ['we', 'came', 'out', 'on', 'a', 'lookoff', 'where', 'we', 'faced', 'END']
# 373. ['a', 'cliff', 'and', 'on', 'the', 'cliff', 'a', 'bottle', 'painted', 'END']
# 374. ['or', 'stained', 'by', 'vegetation', 'from', 'above', 'END']
# 375. ['a', 'likeness', 'to', 'surprise', 'the', 'thrilly', 'tourist', 'END']
# 376. ['well', 'if', 'i', 'havent', 'brought', 'you', 'to', 'the', 'fountain', 'END']
# 377. ['at', 'least', 'ive', 'brought', 'you', 'to', 'the', 'famous', 'bottle', 'END']
# 378. ['i', 'wont', 'accept', 'the', 'substitute', 'its', 'empty', 'END']
# 379. ['sos', 'everything', 'END']
# 380. ['i', 'want', 'my', 'fountain', 'END']
# 381. ['i', 'guess', 'youd', 'find', 'the', 'fountain', 'just', 'as', 'empty', 'END']
# 382. ['and', 'anyway', 'this', 'tells', 'me', 'where', 'i', 'am', 'END']
# 383. ['hadnt', 'you', 'long', 'suspected', 'where', 'you', 'were', 'END']
# 384. ['you', 'mean', 'miles', 'from', 'that', 'mormon', 'settlement', 'END']
# 385. ['look', 'here', 'you', 'treat', 'your', 'guide', 'with', 'due', 'respect', 'END']
# 386. ['if', 'you', 'dont', 'want', 'to', 'spend', 'the', 'night', 'outdoors', 'END']
# 387. ['i', 'vow', 'we', 'must', 'be', 'near', 'the', 'place', 'from', 'where', 'END']
# 388. ['the', 'two', 'converging', 'slides', 'the', 'avalanches', 'END']
# 389. ['on', 'marshall', 'look', 'like', 'donkeys', 'ears', 'END']
# 390. ['we', 'may', 'as', 'well', 'see', 'that', 'and', 'save', 'the', 'day', 'END']
# 391. ['dont', 'donkeys', 'ears', 'suggest', 'we', 'shake', 'our', 'own', 'END']
# 392. ['for', 'gods', 'sake', 'arent', 'you', 'fond', 'of', 'viewing', 'nature', 'END']
# 393. ['you', 'dont', 'like', 'nature', 'all', 'you', 'like', 'is', 'books', 'END']
# 394. ['what', 'signify', 'a', 'donkeys', 'cars', 'and', 'bottle', 'END']
# 395. ['however', 'natural', 'give', 'you', 'your', 'books', 'END']
# 396. ['well', 'then', 'right', 'here', 'is', 'where', 'i', 'show', 'you', 'books', 'END']
# 397. ['come', 'straight', 'down', 'off', 'this', 'mountain', 'just', 'as', 'fast', 'END']
# 398. ['as', 'we', 'can', 'fall', 'and', 'keep', 'abouncing', 'on', 'our', 'feet', 'END']
# 399. ['its', 'hell', 'for', 'knees', 'unless', 'done', 'hellforleather', 'END']
# 400. ['be', 'ready', 'i', 'thought', 'for', 'almost', 'anything', 'END']
# 401. ['we', 'struck', 'a', 'road', 'i', 'didnt', 'recognize', 'END']
# 402. ['but', 'welcomed', 'for', 'the', 'chance', 'to', 'lave', 'my', 'shoes', 'END']
# 403. ['in', 'dust', 'once', 'more', 'we', 'followed', 'this', 'a', 'mile', 'END']
# 404. ['perhaps', 'to', 'where', 'it', 'ended', 'at', 'a', 'house', 'END']
# 405. ['i', 'didnt', 'know', 'was', 'there', 'it', 'was', 'the', 'kind', 'END']
# 406. ['to', 'bring', 'me', 'to', 'for', 'broadboard', 'paneling', 'END']
# 407. ['i', 'never', 'saw', 'so', 'good', 'a', 'house', 'deserted', 'END']
# 408. ['excuse', 'me', 'if', 'i', 'ask', 'you', 'in', 'a', 'window', 'END']
# 409. ['that', 'happens', 'to', 'be', 'broken', 'davis', 'said', 'END']
# 410. ['the', 'outside', 'doors', 'as', 'yet', 'have', 'held', 'against', 'us', 'END']
# 411. ['i', 'want', 'to', 'introduce', 'you', 'to', 'the', 'people', 'END']
# 412. ['who', 'used', 'to', 'live', 'here', 'they', 'were', 'robinsons', 'END']
# 413. ['you', 'must', 'have', 'heard', 'of', 'clara', 'robinson', 'END']
# 414. ['the', 'poetess', 'who', 'wrote', 'the', 'book', 'of', 'verses', 'END']
# 415. ['and', 'had', 'it', 'published', 'it', 'was', 'all', 'about', 'END']
# 416. ['the', 'posies', 'on', 'her', 'inner', 'windowsill', 'END']
# 417. ['and', 'the', 'birds', 'on', 'her', 'outer', 'windowsill', 'END']
# 418. ['and', 'how', 'she', 'tended', 'both', 'or', 'had', 'them', 'tended', 'END']
# 419. ['she', 'never', 'tended', 'anything', 'herself', 'END']
# 420. ['she', 'was', 'shut', 'in', 'for', 'life', 'she', 'lived', 'her', 'whole', 'END']
# 421. ['life', 'long', 'in', 'bed', 'and', 'wrote', 'her', 'things', 'in', 'bed', 'END']
# 422. ['ill', 'show', 'you', 'how', 'she', 'had', 'her', 'sills', 'extended', 'END']
# 423. ['to', 'entertain', 'the', 'birds', 'and', 'hold', 'the', 'flowers', 'END']
# 424. ['our', 'business', 'firsts', 'up', 'attic', 'with', 'her', 'books', 'END']
# 425. ['we', 'trod', 'uncomfortably', 'on', 'crunching', 'glass', 'END']
# 426. ['through', 'a', 'house', 'stripped', 'of', 'everything', 'END']
# 427. ['except', 'it', 'seemed', 'the', 'poetesss', 'poems', 'END']
# 428. ['books', 'i', 'should', 'say', 'if', 'books', 'are', 'what', 'is', 'needed', 'END']
# 429. ['a', 'whole', 'edition', 'in', 'a', 'packing', 'case', 'END']
# 430. ['that', 'overflowing', 'like', 'a', 'horn', 'of', 'plenty', 'END']
# 431. ['or', 'like', 'the', 'poetesss', 'heart', 'of', 'love', 'END']
# 432. ['had', 'spilled', 'them', 'near', 'the', 'window', 'toward', 'the', 'light', 'END']
# 433. ['where', 'driven', 'rain', 'had', 'wet', 'and', 'swollen', 'them', 'END']
# 434. ['enough', 'to', 'stock', 'a', 'village', 'library', 'END']
# 435. ['unfortunately', 'all', 'of', 'one', 'kind', 'though', 'END']
# 436. ['they', 'bad', 'been', 'brought', 'home', 'from', 'some', 'publisher', 'END']
# 437. ['and', 'taken', 'thus', 'into', 'the', 'family', 'END']
# 438. ['boys', 'and', 'bad', 'hunters', 'had', 'known', 'what', 'to', 'do', 'END']
# 439. ['with', 'stone', 'and', 'lead', 'to', 'unprotected', 'glass', 'END']
# 440. ['shatter', 'it', 'inward', 'on', 'the', 'unswept', 'floors', 'END']
# 441. ['how', 'had', 'the', 'tender', 'verse', 'escaped', 'their', 'outrage', 'END']
# 442. ['by', 'being', 'invisible', 'for', 'what', 'it', 'was', 'END']
# 443. ['or', 'else', 'by', 'some', 'remoteness', 'that', 'defied', 'them', 'END']
# 444. ['to', 'find', 'out', 'what', 'to', 'do', 'to', 'hurt', 'a', 'poem', 'END']
# 445. ['yet', 'oh', 'the', 'tempting', 'flatness', 'of', 'a', 'book', 'END']
# 446. ['to', 'send', 'it', 'sailing', 'out', 'the', 'attic', 'window', 'END']
# 447. ['till', 'it', 'caught', 'wind', 'and', 'opening', 'out', 'its', 'covers', 'END']
# 448. ['tried', 'to', 'improve', 'on', 'sailing', 'like', 'a', 'tile', 'END']
# 449. ['by', 'flying', 'like', 'a', 'bird', 'silent', 'in', 'flight', 'END']
# 450. ['but', 'all', 'the', 'burden', 'of', 'its', 'body', 'song', 'END']
# 451. ['only', 'to', 'tumble', 'like', 'a', 'stricken', 'bird', 'END']
# 452. ['and', 'lie', 'in', 'stones', 'and', 'bushes', 'unretrieved', 'END']
# 453. ['books', 'were', 'not', 'thrown', 'irreverently', 'about', 'END']
# 454. ['they', 'simply', 'lay', 'where', 'someone', 'now', 'and', 'then', 'END']
# 455. ['having', 'tried', 'one', 'had', 'dropped', 'it', 'at', 'his', 'feet', 'END']
# 456. ['and', 'left', 'it', 'lying', 'where', 'it', 'fell', 'rejected', 'END']
# 457. ['here', 'were', 'all', 'those', 'the', 'poetesss', 'life', 'END']
# 458. ['had', 'been', 'too', 'short', 'to', 'sell', 'or', 'give', 'away', 'END']
# 459. ['take', 'one', 'old', 'davis', 'bade', 'me', 'graciously', 'END']
# 460. ['why', 'not', 'take', 'two', 'or', 'three', 'END']
# 461. ['take', 'all', 'you', 'want', 'END']
# 462. ['goodlooking', 'books', 'like', 'that', 'he', 'picked', 'one', 'fresh', 'END']
# 463. ['in', 'virgin', 'wrapper', 'from', 'deep', 'in', 'the', 'box', 'END']
# 464. ['and', 'stroked', 'it', 'with', 'a', 'hornyhanded', 'kindness', 'END']
# 465. ['he', 'read', 'in', 'one', 'and', 'i', 'read', 'in', 'another', 'END']
# 466. ['both', 'either', 'looking', 'for', 'or', 'finding', 'something', 'END']
# 467. ['the', 'attic', 'wasps', 'went', 'missing', 'by', 'like', 'bullets', 'END']
# 468. ['i', 'was', 'soon', 'satisfied', 'for', 'the', 'time', 'being', 'END']
# 469. ['all', 'the', 'way', 'home', 'i', 'kept', 'remembering', 'END']
# 470. ['the', 'small', 'book', 'in', 'my', 'pocket', 'it', 'was', 'there', 'END']
# 471. ['the', 'poetess', 'had', 'sighed', 'i', 'knew', 'in', 'heaven', 'END']
# 472. ['at', 'having', 'eased', 'her', 'heart', 'of', 'one', 'more', 'copy', 'END']
# 473. ['legitimately', 'my', 'demand', 'upon', 'her', 'END']
# 474. ['though', 'slight', 'was', 'a', 'demand', 'she', 'felt', 'the', 'tug', 'END']
# 475. ['in', 'time', 'she', 'would', 'be', 'rid', 'of', 'all', 'her', 'books', 'END']
# 476. ['i', 'stay', 'END']
# 477. ['but', 'it', 'isnt', 'as', 'if', 'END']
# 478. ['there', 'wasnt', 'always', 'hudsons', 'bay', 'END']
# 479. ['and', 'the', 'fur', 'trade', 'END']
# 480. ['a', 'small', 'skiff', 'END']
# 481. ['and', 'a', 'paddle', 'blade', 'END']
# 482. ['i', 'can', 'just', 'see', 'my', 'tent', 'pegged', 'END']
# 483. ['and', 'me', 'on', 'the', 'floor', 'END']
# 484. ['crosslegged', 'END']
# 485. ['and', 'a', 'trapper', 'looking', 'in', 'at', 'the', 'door', 'END']
# 486. ['with', 'furs', 'to', 'sell', 'END']
# 487. ['his', 'names', 'joe', 'END']
# 488. ['alias', 'john', 'END']
# 489. ['and', 'between', 'what', 'he', 'doesnt', 'know', 'END']
# 490. ['and', 'wont', 'tell', 'END']
# 491. ['about', 'where', 'henry', 'hudsons', 'gone', 'END']
# 492. ['i', 'cant', 'say', 'hes', 'much', 'help', 'END']
# 493. ['but', 'we', 'get', 'on', 'END']
# 494. ['the', 'seal', 'yelp', 'END']
# 495. ['on', 'an', 'ice', 'cake', 'END']
# 496. ['its', 'not', 'men', 'by', 'some', 'mistake', 'END']
# 497. ['no', 'END']
# 498. ['theres', 'not', 'a', 'soul', 'END']
# 499. ['for', 'a', 'windbreak', 'END']
# 500. ['between', 'me', 'and', 'the', 'north', 'pole', 'END']
# 501. ['except', 'always', 'johnjoe', 'END']
# 502. ['my', 'french', 'indian', 'esquimaux', 'END']
# 503. ['and', 'hes', 'off', 'setting', 'traps', 'END']
# 504. ['in', 'one', 'himself', 'perhaps', 'END']
# 505. ['give', 'a', 'headshake', 'END']
# 506. ['over', 'so', 'much', 'bay', 'END']
# 507. ['thrown', 'away', 'END']
# 508. ['in', 'snow', 'and', 'mist', 'END']
# 509. ['that', 'doesnt', 'exist', 'END']
# 510. ['i', 'was', 'going', 'to', 'say', 'END']
# 511. ['for', 'god', 'man', 'or', 'beasts', 'sake', 'END']
# 512. ['yet', 'does', 'perhaps', 'for', 'all', 'three', 'END']
# 513. ['dont', 'ask', 'joe', 'END']
# 514. ['what', 'it', 'is', 'to', 'him', 'END']
# 515. ['its', 'sometimes', 'dim', 'END']
# 516. ['what', 'it', 'is', 'to', 'me', 'END']
# 517. ['unless', 'it', 'be', 'END']
# 518. ['its', 'the', 'old', 'captains', 'dark', 'fate', 'END']
# 519. ['who', 'failed', 'to', 'find', 'or', 'force', 'a', 'strait', 'END']
# 520. ['in', 'its', 'twothousandmile', 'coast', 'END']
# 521. ['and', 'his', 'crew', 'left', 'him', 'where', 'be', 'failed', 'END']
# 522. ['and', 'nothing', 'came', 'of', 'all', 'be', 'sailed', 'END']
# 523. ['its', 'to', 'say', 'you', 'and', 'i', 'END']
# 524. ['to', 'such', 'a', 'ghost', 'END']
# 525. ['you', 'and', 'i', 'END']
# 526. ['off', 'here', 'END']
# 527. ['with', 'the', 'dead', 'race', 'of', 'the', 'great', 'auk', 'END']
# 528. ['and', 'better', 'defeat', 'almost', 'END']
# 529. ['if', 'seen', 'clear', 'END']
# 530. ['than', 'lifes', 'victories', 'of', 'doubt', 'END']
# 531. ['that', 'need', 'endless', 'talktalk', 'END']
# 532. ['to', 'make', 'them', 'out', 'END']
# 533. ['i', 'staid', 'the', 'night', 'for', 'shelter', 'at', 'a', 'farm', 'END']
# 534. ['behind', 'the', 'mountains', 'with', 'a', 'mother', 'and', 'son', 'END']
# 535. ['two', 'oldbelievers', 'they', 'did', 'all', 'the', 'talking', 'END']
# 536. ['mother', 'folks', 'think', 'a', 'witch', 'who', 'has', 'familiar', 'spirits', 'END']
# 537. ['she', 'could', 'call', 'up', 'to', 'pass', 'a', 'winter', 'evening', 'END']
# 538. ['but', 'wont', 'should', 'be', 'burned', 'at', 'the', 'stake', 'or', 'something', 'END']
# 539. ['summoning', 'spirits', 'isnt', 'button', 'button', 'END']
# 540. ['whos', 'got', 'the', 'button', 'i', 'would', 'have', 'them', 'know', 'END']
# 541. ['son', 'mother', 'can', 'make', 'a', 'common', 'table', 'rear', 'END']
# 542. ['and', 'kick', 'with', 'two', 'legs', 'like', 'an', 'army', 'mule', 'END']
# 543. ['mother', 'and', 'when', 'ive', 'done', 'it', 'what', 'good', 'have', 'i', 'END']
# 544. ['done', 'END']
# 545. ['rather', 'than', 'tip', 'a', 'table', 'for', 'you', 'let', 'me', 'END']
# 546. ['tell', 'you', 'what', 'ralle', 'the', 'sioux', 'control', 'once', 'told', 'me', 'END']
# 547. ['he', 'said', 'the', 'dead', 'had', 'souls', 'but', 'when', 'i', 'asked', 'him', 'END']
# 548. ['how', 'could', 'that', 'be', 'i', 'thought', 'the', 'dead', 'were', 'souls', 'END']
# 549. ['he', 'broke', 'my', 'trance', 'dont', 'that', 'make', 'you', 'suspicious', 'END']
# 550. ['that', 'theres', 'something', 'the', 'dead', 'are', 'keeping', 'back', 'END']
# 551. ['yes', 'theres', 'something', 'the', 'dead', 'are', 'keeping', 'back', 'END']
# 552. ['son', 'you', 'wouldnt', 'want', 'to', 'tell', 'him', 'what', 'we', 'have', 'END']
# 553. ['up', 'attic', 'mother', 'END']
# 554. ['mother', 'bones', 'a', 'skeleton', 'END']
# 555. ['son', 'but', 'the', 'headboard', 'of', 'mothers', 'bed', 'is', 'pushed', 'END']
# 556. ['against', 'the', 'attic', 'door', 'the', 'door', 'is', 'nailed', 'END']
# 557. ['its', 'harmless', 'mother', 'hears', 'it', 'in', 'the', 'night', 'END']
# 558. ['halting', 'perplexed', 'behind', 'the', 'barrier', 'END']
# 559. ['of', 'door', 'and', 'headboard', 'where', 'it', 'wants', 'to', 'get', 'END']
# 560. ['is', 'back', 'into', 'the', 'cellar', 'where', 'it', 'came', 'from', 'END']
# 561. ['mother', 'well', 'never', 'let', 'them', 'will', 'we', 'son', 'well', 'END']
# 562. ['never', 'END']
# 563. ['son', 'it', 'left', 'the', 'cellar', 'forty', 'years', 'ago', 'END']
# 564. ['and', 'carried', 'itself', 'like', 'a', 'pile', 'of', 'dishes', 'END']
# 565. ['up', 'one', 'flight', 'from', 'the', 'cellar', 'to', 'the', 'kitchen', 'END']
# 566. ['another', 'from', 'the', 'kitchen', 'to', 'the', 'bedroom', 'END']
# 567. ['another', 'from', 'the', 'bedroom', 'to', 'the', 'attic', 'END']
# 568. ['right', 'past', 'both', 'father', 'and', 'mother', 'and', 'neither', 'stopped', 'END']
# 569. ['it', 'END']
# 570. ['father', 'had', 'gone', 'upstairs', 'mother', 'was', 'downstairs', 'END']
# 571. ['i', 'was', 'a', 'baby', 'i', 'dont', 'know', 'where', 'i', 'was', 'END']
# 572. ['mother', 'the', 'only', 'fault', 'my', 'husband', 'found', 'with', 'me', 'END']
# 573. ['i', 'went', 'to', 'sleep', 'before', 'i', 'went', 'to', 'bed', 'END']
# 574. ['especially', 'in', 'winter', 'when', 'the', 'bed', 'END']
# 575. ['might', 'just', 'as', 'well', 'be', 'ice', 'and', 'the', 'clothes', 'snow', 'END']
# 576. ['the', 'night', 'the', 'bones', 'came', 'up', 'the', 'cellarstairs', 'END']
# 577. ['toffile', 'had', 'gone', 'to', 'bed', 'alone', 'and', 'left', 'me', 'END']
# 578. ['but', 'left', 'an', 'open', 'door', 'to', 'cool', 'the', 'room', 'off', 'END']
# 579. ['so', 'as', 'to', 'sort', 'of', 'turn', 'me', 'out', 'of', 'it', 'END']
# 580. ['i', 'was', 'just', 'coming', 'to', 'myself', 'enough', 'END']
# 581. ['to', 'wonder', 'where', 'the', 'cold', 'was', 'coming', 'from', 'END']
# 582. ['when', 'i', 'heard', 'toffile', 'upstairs', 'in', 'the', 'bedroom', 'END']
# 583. ['and', 'thought', 'i', 'heard', 'him', 'downstairs', 'in', 'the', 'cellar', 'END']
# 584. ['the', 'board', 'we', 'had', 'laid', 'down', 'to', 'walk', 'dryshod', 'on', 'END']
# 585. ['when', 'there', 'was', 'water', 'in', 'the', 'cellar', 'in', 'spring', 'END']
# 586. ['struck', 'the', 'hard', 'cellar', 'bottom', 'and', 'then', 'someone', 'END']
# 587. ['began', 'the', 'stairs', 'two', 'footsteps', 'for', 'each', 'step', 'END']
# 588. ['the', 'way', 'a', 'man', 'with', 'one', 'leg', 'and', 'a', 'crutch', 'END']
# 589. ['or', 'a', 'little', 'child', 'comes', 'up', 'it', 'wasnt', 'toffile', 'END']
# 590. ['it', 'wasnt', 'anyone', 'who', 'could', 'be', 'there', 'END']
# 591. ['the', 'bulkhead', 'doubledoors', 'were', 'doublelocked', 'END']
# 592. ['and', 'swollen', 'tight', 'and', 'buried', 'under', 'snow', 'END']
# 593. ['the', 'cellar', 'windows', 'were', 'banked', 'up', 'with', 'sawdust', 'END']
# 594. ['and', 'swollen', 'tight', 'and', 'buried', 'under', 'snow', 'END']
# 595. ['it', 'was', 'the', 'bones', 'i', 'knew', 'them', 'and', 'good', 'reason', 'END']
# 596. ['my', 'first', 'impulse', 'was', 'to', 'get', 'to', 'the', 'knob', 'END']
# 597. ['and', 'hold', 'the', 'door', 'but', 'the', 'bones', 'didnt', 'try', 'END']
# 598. ['the', 'door', 'they', 'halted', 'helpless', 'on', 'the', 'landing', 'END']
# 599. ['waiting', 'for', 'things', 'to', 'happen', 'in', 'their', 'favour', 'END']
# 600. ['the', 'faintest', 'restless', 'rustling', 'ran', 'all', 'through', 'them', 'END']
# 601. ['i', 'never', 'could', 'have', 'done', 'the', 'thing', 'i', 'did', 'END']
# 602. ['if', 'the', 'wish', 'hadnt', 'been', 'too', 'strong', 'in', 'me', 'END']
# 603. ['to', 'see', 'how', 'they', 'were', 'mounted', 'for', 'this', 'walk', 'END']
# 604. ['i', 'had', 'a', 'vision', 'of', 'them', 'put', 'together', 'END']
# 605. ['not', 'like', 'a', 'man', 'but', 'like', 'a', 'chandelier', 'END']
# 606. ['so', 'suddenly', 'i', 'flung', 'the', 'door', 'wide', 'on', 'him', 'END']
# 607. ['a', 'moment', 'he', 'stood', 'balancing', 'with', 'emotion', 'END']
# 608. ['and', 'all', 'but', 'lost', 'himself', 'a', 'tongue', 'of', 'fire', 'END']
# 609. ['flashed', 'out', 'and', 'licked', 'along', 'his', 'upper', 'teeth', 'END']
# 610. ['smoke', 'rolled', 'inside', 'the', 'sockets', 'of', 'his', 'eyes', 'END']
# 611. ['then', 'he', 'came', 'at', 'me', 'with', 'one', 'hand', 'outstretched', 'END']
# 612. ['the', 'way', 'he', 'did', 'in', 'life', 'once', 'but', 'this', 'time', 'END']
# 613. ['i', 'struck', 'the', 'hand', 'off', 'brittle', 'on', 'the', 'floor', 'END']
# 614. ['and', 'fell', 'back', 'from', 'him', 'on', 'the', 'floor', 'myself', 'END']
# 615. ['the', 'fingerpieces', 'slid', 'in', 'all', 'directions', 'END']
# 616. ['where', 'did', 'i', 'see', 'one', 'of', 'those', 'pieces', 'lately', 'END']
# 617. ['hand', 'me', 'my', 'buttonbox', 'it', 'must', 'be', 'there', 'END']
# 618. ['i', 'sat', 'up', 'on', 'the', 'floor', 'and', 'shouted', 'toffile', 'END']
# 619. ['its', 'coming', 'up', 'to', 'you', 'it', 'had', 'its', 'choice', 'END']
# 620. ['of', 'the', 'door', 'to', 'the', 'cellar', 'or', 'the', 'hall', 'END']
# 621. ['it', 'took', 'the', 'hall', 'door', 'for', 'the', 'novelty', 'END']
# 622. ['and', 'set', 'off', 'briskly', 'for', 'so', 'slow', 'a', 'thing', 'END']
# 623. ['stillgoing', 'every', 'which', 'way', 'in', 'the', 'joints', 'though', 'END']
# 624. ['so', 'that', 'it', 'looked', 'like', 'lightning', 'or', 'a', 'scribble', 'END']
# 625. ['from', 'the', 'slap', 'i', 'had', 'just', 'now', 'given', 'its', 'hand', 'END']
# 626. ['i', 'listened', 'till', 'it', 'almost', 'climbed', 'the', 'stairs', 'END']
# 627. ['from', 'the', 'hall', 'to', 'the', 'only', 'finished', 'bedroom', 'END']
# 628. ['before', 'i', 'got', 'up', 'to', 'do', 'anything', 'END']
# 629. ['then', 'ran', 'and', 'shouted', 'shut', 'the', 'bedroom', 'door', 'END']
# 630. ['toffile', 'for', 'my', 'sake', 'company', 'he', 'said', 'END']
# 631. ['dont', 'make', 'me', 'get', 'up', 'im', 'too', 'warm', 'in', 'bed', 'END']
# 632. ['so', 'lying', 'forward', 'weakly', 'on', 'the', 'handrail', 'END']
# 633. ['i', 'pushed', 'myself', 'upstairs', 'and', 'in', 'the', 'light', 'END']
# 634. ['the', 'kitchen', 'had', 'been', 'dark', 'i', 'had', 'to', 'own', 'END']
# 635. ['i', 'could', 'see', 'nothing', 'toffile', 'i', 'dont', 'see', 'it', 'END']
# 636. ['its', 'with', 'us', 'in', 'the', 'room', 'though', 'its', 'the', 'bones', 'END']
# 637. ['what', 'bones', 'the', 'cellar', 'bones', 'out', 'of', 'the', 'grave', 'END']
# 638. ['that', 'made', 'him', 'throw', 'his', 'bare', 'legs', 'out', 'of', 'bed', 'END']
# 639. ['and', 'sit', 'up', 'by', 'me', 'and', 'take', 'hold', 'of', 'me', 'END']
# 640. ['i', 'wanted', 'to', 'put', 'out', 'the', 'light', 'and', 'see', 'END']
# 641. ['if', 'i', 'could', 'see', 'it', 'or', 'else', 'mow', 'the', 'room', 'END']
# 642. ['with', 'our', 'arms', 'at', 'the', 'level', 'of', 'our', 'knees', 'END']
# 643. ['and', 'bring', 'the', 'chalkpile', 'down', 'ill', 'tell', 'you', 'what', 'END']
# 644. ['its', 'looking', 'for', 'another', 'door', 'to', 'try', 'END']
# 645. ['the', 'uncommonly', 'deep', 'snow', 'has', 'made', 'him', 'think', 'END']
# 646. ['of', 'his', 'old', 'song', 'the', 'wild', 'colonial', 'boy', 'END']
# 647. ['he', 'always', 'used', 'to', 'sing', 'along', 'the', 'toteroad', 'END']
# 648. ['hes', 'after', 'an', 'open', 'door', 'to', 'get', 'outdoors', 'END']
# 649. ['lets', 'trap', 'him', 'with', 'an', 'open', 'door', 'up', 'attic', 'END']
# 650. ['toffile', 'agreed', 'to', 'that', 'and', 'sure', 'enough', 'END']
# 651. ['almost', 'the', 'moment', 'he', 'was', 'given', 'an', 'opening', 'END']
# 652. ['the', 'steps', 'began', 'to', 'climb', 'the', 'attic', 'stairs', 'END']
# 653. ['i', 'heard', 'them', 'toffile', 'didnt', 'seem', 'to', 'hear', 'them', 'END']
# 654. ['quick', 'i', 'slammed', 'to', 'the', 'door', 'and', 'held', 'the', 'knob', 'END']
# 655. ['toffile', 'get', 'nails', 'i', 'made', 'him', 'nail', 'the', 'door', 'shut', 'END']
# 656. ['and', 'push', 'the', 'headboard', 'of', 'the', 'bed', 'against', 'it', 'END']
# 657. ['then', 'we', 'asked', 'was', 'there', 'anything', 'END']
# 658. ['up', 'attic', 'that', 'wed', 'ever', 'want', 'again', 'END']
# 659. ['the', 'attic', 'was', 'less', 'to', 'us', 'than', 'the', 'cellar', 'END']
# 660. ['if', 'the', 'bones', 'liked', 'the', 'attic', 'let', 'them', 'have', 'it', 'END']
# 661. ['let', 'them', 'stay', 'in', 'the', 'attic', 'when', 'they', 'sometimes', 'END']
# 662. ['come', 'down', 'the', 'stairs', 'at', 'night', 'and', 'stand', 'perplexed', 'END']
# 663. ['behind', 'the', 'door', 'and', 'headboard', 'of', 'the', 'bed', 'END']
# 664. ['brushing', 'their', 'chalky', 'skull', 'with', 'chalky', 'fingers', 'END']
# ...
# 1230. ['two', 'of', 'you', 'out', 'will', 'leave', 'an', 'empty', 'house', 'END']
# 1231. ['i', 'dont', 'just', 'see', 'him', 'living', 'many', 'years', 'END']
# 1232. ['left', 'here', 'with', 'nothing', 'but', 'the', 'furniture', 'END']
# 1233. ['i', 'hate', 'to', 'think', 'of', 'the', 'old', 'place', 'when', 'were', 'gone', 'END']
# 1234. ['with', 'the', 'brook', 'going', 'by', 'below', 'the', 'yard', 'END']
# 1235. ['and', 'no', 'one', 'here', 'but', 'hens', 'blowing', 'about', 'END']
# 1236. ['if', 'he', 'could', 'sell', 'the', 'place', 'but', 'then', 'he', 'cant', 'END']
# 1237. ['no', 'one', 'will', 'ever', 'live', 'on', 'it', 'again', 'END']
# 1238. ['its', 'too', 'run', 'down', 'this', 'is', 'the', 'last', 'of', 'it', 'END']
# 1239. ['what', 'i', 'think', 'he', 'will', 'do', 'is', 'let', 'things', 'smash', 'END']
# 1240. ['hell', 'sort', 'of', 'swear', 'the', 'time', 'away', 'hes', 'awful', 'END']
# 1241. ['i', 'never', 'saw', 'a', 'man', 'let', 'family', 'troubles', 'END']
# 1242. ['make', 'so', 'much', 'difference', 'in', 'his', 'mans', 'affairs', 'END']
# 1243. ['hes', 'just', 'dropped', 'everything', 'hes', 'like', 'a', 'child', 'END']
# 1244. ['i', 'blame', 'his', 'being', 'brought', 'up', 'by', 'his', 'mother', 'END']
# 1245. ['hes', 'got', 'hay', 'down', 'thats', 'been', 'rained', 'on', 'three', 'times', 'END']
# 1246. ['he', 'hoed', 'a', 'little', 'yesterday', 'for', 'me', 'END']
# 1247. ['i', 'thought', 'the', 'growing', 'things', 'would', 'do', 'him', 'good', 'END']
# 1248. ['something', 'went', 'wrong', 'i', 'saw', 'him', 'throw', 'the', 'hoe', 'END']
# 1249. ['skyhigh', 'with', 'both', 'hands', 'i', 'can', 'see', 'it', 'now', 'END']
# 1250. ['come', 'here', 'ill', 'show', 'you', 'in', 'that', 'apple', 'tree', 'END']
# 1251. ['thats', 'no', 'way', 'for', 'a', 'man', 'to', 'do', 'at', 'his', 'age', 'END']
# 1252. ['hes', 'fiftyfive', 'you', 'know', 'if', 'hes', 'a', 'day', 'END']
# 1253. ['arent', 'you', 'afraid', 'of', 'him', 'whats', 'that', 'gun', 'for', 'END']
# 1254. ['oh', 'thats', 'been', 'there', 'for', 'hawks', 'since', 'chickentime', 'END']
# 1255. ['john', 'hall', 'touch', 'me', 'not', 'if', 'he', 'knows', 'his', 'friends', 'END']
# 1256. ['ill', 'say', 'that', 'for', 'him', 'johns', 'no', 'threatener', 'END']
# 1257. ['like', 'some', 'men', 'folk', 'no', 'ones', 'afraid', 'of', 'him', 'END']
# 1258. ['all', 'is', 'hes', 'made', 'up', 'his', 'mind', 'not', 'to', 'stand', 'END']
# 1259. ['what', 'he', 'has', 'got', 'to', 'stand', 'END']
# 1260. ['where', 'is', 'estelle', 'END']
# 1261. ['couldnt', 'one', 'talk', 'to', 'her', 'what', 'does', 'she', 'say', 'END']
# 1262. ['you', 'say', 'you', 'dont', 'know', 'where', 'she', 'is', 'END']
# 1263. ['nor', 'want', 'to', 'END']
# 1264. ['she', 'thinks', 'if', 'it', 'was', 'bad', 'to', 'live', 'with', 'him', 'END']
# 1265. ['it', 'must', 'be', 'right', 'to', 'leave', 'him', 'END']
# 1266. ['which', 'is', 'wrong', 'END']
# 1267. ['yes', 'but', 'he', 'should', 'have', 'married', 'her', 'END']
# 1268. ['i', 'know', 'END']
# 1269. ['the', 'strains', 'been', 'too', 'much', 'for', 'her', 'all', 'these', 'years', 'END']
# 1270. ['i', 'cant', 'explain', 'it', 'any', 'other', 'way', 'END']
# 1271. ['its', 'different', 'with', 'a', 'man', 'at', 'least', 'with', 'john', 'END']
# 1272. ['he', 'knows', 'hes', 'kinder', 'than', 'the', 'run', 'of', 'men', 'END']
# 1273. ['better', 'than', 'married', 'ought', 'to', 'be', 'as', 'good', 'END']
# 1274. ['as', 'married', 'thats', 'what', 'he', 'has', 'always', 'said', 'END']
# 1275. ['i', 'know', 'the', 'way', 'hes', 'felt', 'but', 'all', 'the', 'same', 'END']
# 1276. ['i', 'wonder', 'why', 'he', 'doesnt', 'marry', 'her', 'END']
# 1277. ['and', 'end', 'it', 'END']
# 1278. ['too', 'late', 'now', 'she', 'wouldnt', 'have', 'him', 'END']
# 1279. ['hes', 'given', 'her', 'time', 'to', 'think', 'of', 'something', 'else', 'END']
# 1280. ['thats', 'his', 'mistake', 'the', 'dear', 'knows', 'my', 'interest', 'END']
# 1281. ['has', 'been', 'to', 'keep', 'the', 'thing', 'from', 'breaking', 'up', 'END']
# 1282. ['this', 'is', 'a', 'good', 'home', 'i', 'dont', 'ask', 'for', 'better', 'END']
# 1283. ['but', 'when', 'ive', 'said', 'why', 'shouldnt', 'they', 'be', 'married', 'END']
# 1284. ['hed', 'say', 'why', 'should', 'they', 'no', 'more', 'words', 'than', 'that', 'END']
# 1285. ['and', 'after', 'all', 'why', 'should', 'they', 'johns', 'been', 'fair', 'END']
# 1286. ['i', 'take', 'it', 'what', 'was', 'his', 'was', 'always', 'hers', 'END']
# 1287. ['there', 'was', 'no', 'quarrel', 'about', 'property', 'END']
# 1288. ['reason', 'enough', 'there', 'was', 'no', 'property', 'END']
# 1289. ['a', 'friend', 'or', 'two', 'as', 'good', 'as', 'own', 'the', 'farm', 'END']
# 1290. ['such', 'as', 'it', 'is', 'it', 'isnt', 'worth', 'the', 'mortgage', 'END']
# 1291. ['i', 'mean', 'estelle', 'has', 'always', 'held', 'the', 'purse', 'END']
# 1292. ['the', 'rights', 'of', 'that', 'are', 'harder', 'to', 'get', 'at', 'END']
# 1293. ['i', 'guess', 'estelle', 'and', 'i', 'have', 'filled', 'the', 'purse', 'END']
# 1294. ['twas', 'we', 'let', 'him', 'have', 'money', 'not', 'he', 'us', 'END']
# 1295. ['johns', 'a', 'bad', 'farmer', 'im', 'not', 'blaming', 'him', 'END']
# 1296. ['take', 'it', 'year', 'in', 'year', 'out', 'he', 'doesnt', 'make', 'much', 'END']
# 1297. ['we', 'came', 'here', 'for', 'a', 'home', 'for', 'me', 'you', 'know', 'END']
# 1298. ['estelle', 'to', 'do', 'the', 'housework', 'for', 'the', 'board', 'END']
# 1299. ['of', 'both', 'of', 'us', 'but', 'look', 'how', 'it', 'turns', 'out', 'END']
# 1300. ['she', 'seems', 'to', 'have', 'the', 'housework', 'and', 'besides', 'END']
# 1301. ['half', 'of', 'the', 'outdoor', 'work', 'though', 'as', 'for', 'that', 'END']
# 1302. ['hed', 'say', 'she', 'does', 'it', 'more', 'because', 'she', 'likes', 'it', 'END']
# 1303. ['you', 'see', 'our', 'pretty', 'things', 'are', 'all', 'outdoors', 'END']
# 1304. ['our', 'hens', 'and', 'cows', 'and', 'pigs', 'are', 'always', 'better', 'END']
# 1305. ['than', 'folks', 'like', 'us', 'have', 'any', 'business', 'with', 'END']
# 1306. ['farmers', 'around', 'twice', 'as', 'well', 'off', 'as', 'we', 'END']
# 1307. ['havent', 'as', 'good', 'they', 'dont', 'go', 'with', 'the', 'farm', 'END']
# 1308. ['one', 'thing', 'you', 'cant', 'help', 'liking', 'about', 'john', 'END']
# 1309. ['hes', 'fond', 'of', 'nice', 'things', 'too', 'fond', 'some', 'would', 'say', 'END']
# 1310. ['but', 'estelle', 'dont', 'complain', 'shes', 'like', 'him', 'there', 'END']
# 1311. ['she', 'wants', 'our', 'hens', 'to', 'be', 'the', 'best', 'there', 'are', 'END']
# 1312. ['you', 'never', 'saw', 'this', 'room', 'before', 'a', 'show', 'END']
# 1313. ['full', 'of', 'lank', 'shivery', 'halfdrowned', 'birds', 'END']
# 1314. ['in', 'separate', 'coops', 'having', 'their', 'plumage', 'done', 'END']
# 1315. ['the', 'smell', 'of', 'the', 'wet', 'feathers', 'in', 'the', 'heat', 'END']
# 1316. ['you', 'spoke', 'of', 'johns', 'not', 'being', 'safe', 'to', 'stay', 'with', 'END']
# 1317. ['you', 'dont', 'know', 'what', 'a', 'gentle', 'lot', 'we', 'are', 'END']
# 1318. ['we', 'wouldnt', 'hurt', 'a', 'hen', 'you', 'ought', 'to', 'see', 'us', 'END']
# 1319. ['moving', 'a', 'flock', 'of', 'hens', 'from', 'place', 'to', 'place', 'END']
# 1320. ['were', 'not', 'allowed', 'to', 'take', 'them', 'upside', 'down', 'END']
# 1321. ['all', 'we', 'can', 'hold', 'together', 'by', 'the', 'legs', 'END']
# 1322. ['two', 'at', 'a', 'times', 'the', 'rule', 'one', 'on', 'each', 'arm', 'END']
# 1323. ['no', 'matter', 'how', 'far', 'and', 'how', 'many', 'times', 'END']
# 1324. ['we', 'have', 'to', 'go', 'END']
# 1325. ['you', 'mean', 'thats', 'johns', 'idea', 'END']
# 1326. ['and', 'we', 'live', 'up', 'to', 'it', 'or', 'i', 'dont', 'know', 'END']
# 1327. ['what', 'childishness', 'he', 'wouldnt', 'give', 'way', 'to', 'END']
# 1328. ['he', 'manages', 'to', 'keep', 'the', 'upper', 'hand', 'END']
# 1329. ['on', 'his', 'own', 'farm', 'hes', 'boss', 'but', 'as', 'to', 'hens', 'END']
# 1330. ['we', 'fence', 'our', 'flowers', 'in', 'and', 'the', 'hens', 'range', 'END']
# 1331. ['nothings', 'too', 'good', 'for', 'them', 'we', 'say', 'it', 'pays', 'END']
# 1332. ['john', 'likes', 'to', 'tell', 'the', 'offers', 'he', 'has', 'had', 'END']
# 1333. ['twenty', 'for', 'this', 'cock', 'twentyfive', 'for', 'that', 'END']
# 1334. ['he', 'never', 'takes', 'the', 'money', 'if', 'theyre', 'worth', 'END']
# 1335. ['that', 'much', 'to', 'sell', 'theyre', 'worth', 'as', 'much', 'to', 'keep', 'END']
# 1336. ['bless', 'you', 'its', 'all', 'expense', 'though', 'reach', 'me', 'down', 'END']
# 1337. ['the', 'little', 'tin', 'box', 'on', 'the', 'cupboard', 'shelf', 'END']
# 1338. ['the', 'upper', 'shelf', 'the', 'tin', 'box', 'thats', 'the', 'one', 'END']
# 1339. ['ill', 'show', 'you', 'here', 'you', 'are', 'END']
# 1340. ['whats', 'this', 'END']
# 1341. ['a', 'bill', 'END']
# 1342. ['for', 'fifty', 'dollars', 'for', 'one', 'langshang', 'cock', 'END']
# 1343. ['receipted', 'and', 'the', 'cock', 'is', 'in', 'the', 'yard', 'END']
# 1344. ['not', 'in', 'a', 'glass', 'case', 'then', 'END']
# 1345. ['hed', 'need', 'a', 'tall', 'one', 'END']
# 1346. ['he', 'can', 'eat', 'off', 'a', 'barrel', 'from', 'the', 'ground', 'END']
# 1347. ['hes', 'been', 'in', 'a', 'glass', 'case', 'as', 'you', 'may', 'say', 'END']
# 1348. ['the', 'crystal', 'palace', 'london', 'hes', 'imported', 'END']
# 1349. ['john', 'bought', 'him', 'and', 'we', 'paid', 'the', 'bill', 'with', 'beads', 'END']
# 1350. ['wampum', 'i', 'call', 'it', 'mind', 'we', 'dont', 'complain', 'END']
# 1351. ['but', 'you', 'see', 'dont', 'you', 'we', 'take', 'care', 'of', 'him', 'END']
# 1352. ['and', 'like', 'it', 'too', 'it', 'makes', 'it', 'all', 'the', 'worse', 'END']
# 1353. ['it', 'seems', 'as', 'if', 'and', 'thats', 'not', 'all', 'hes', 'helpless', 'END']
# 1354. ['in', 'ways', 'that', 'i', 'can', 'hardly', 'tell', 'you', 'of', 'END']
# 1355. ['sometimes', 'he', 'gets', 'possessed', 'to', 'keep', 'accounts', 'END']
# 1356. ['to', 'see', 'where', 'all', 'the', 'money', 'goes', 'so', 'fast', 'END']
# 1357. ['you', 'know', 'how', 'men', 'will', 'be', 'ridiculous', 'END']
# 1358. ['but', 'its', 'just', 'fun', 'the', 'way', 'he', 'gets', 'bedeviled', 'END']
# 1359. ['if', 'hes', 'untidy', 'now', 'what', 'will', 'he', 'be', 'END']
# 1360. ['it', 'makes', 'it', 'all', 'the', 'worse', 'you', 'must', 'be', 'blind', 'END']
# 1361. ['estelles', 'the', 'one', 'you', 'neednt', 'talk', 'to', 'me', 'END']
# 1362. ['cant', 'you', 'and', 'i', 'get', 'to', 'the', 'root', 'of', 'it', 'END']
# 1363. ['whats', 'the', 'real', 'trouble', 'what', 'will', 'satisfy', 'her', 'END']
# 1364. ['its', 'as', 'i', 'say', 'shes', 'turned', 'from', 'him', 'thats', 'all', 'END']
# 1365. ['but', 'why', 'when', 'shes', 'well', 'off', 'is', 'it', 'the', 'neighbours', 'END']
# 1366. ['being', 'cut', 'off', 'from', 'friends', 'END']
# 1367. ['we', 'have', 'our', 'friends', 'END']
# 1368. ['that', 'isnt', 'it', 'folks', 'arent', 'afraid', 'of', 'us', 'END']
# 1369. ['shes', 'let', 'it', 'worry', 'her', 'you', 'stood', 'the', 'strain', 'END']
# 1370. ['and', 'youre', 'her', 'mother', 'END']
# 1371. ['but', 'i', 'didnt', 'always', 'END']
# 1372. ['i', 'didnt', 'relish', 'it', 'along', 'at', 'first', 'END']
# 1373. ['but', 'i', 'got', 'wonted', 'to', 'it', 'and', 'besides', 'END']
# 1374. ['john', 'said', 'i', 'was', 'too', 'old', 'to', 'have', 'grandchildren', 'END']
# 1375. ['but', 'whats', 'the', 'use', 'of', 'talking', 'when', 'its', 'done', 'END']
# 1376. ['she', 'wont', 'come', 'back', 'its', 'worse', 'than', 'that', 'she', 'cant', 'END']
# 1377. ['why', 'do', 'you', 'speak', 'like', 'that', 'what', 'do', 'you', 'know', 'END']
# 1378. ['what', 'do', 'you', 'mean', 'shes', 'done', 'harm', 'to', 'herself', 'END']
# 1379. ['i', 'mean', 'shes', 'married', 'married', 'someone', 'else', 'END']
# 1380. ['oho', 'oho', 'END']
# 1381. ['you', 'dont', 'believe', 'me', 'END']
# 1382. ['yes', 'i', 'do', 'END']
# 1383. ['only', 'too', 'well', 'i', 'knew', 'there', 'must', 'be', 'something', 'END']
# 1384. ['so', 'that', 'was', 'what', 'was', 'back', 'shes', 'bad', 'thats', 'all', 'END']
# 1385. ['bad', 'to', 'get', 'married', 'when', 'she', 'had', 'the', 'chance', 'END']
# 1386. ['nonsense', 'see', 'whats', 'she', 'done', 'but', 'who', 'who', 'END']
# 1387. ['whod', 'marry', 'her', 'straight', 'out', 'of', 'such', 'a', 'mess', 'END']
# 1388. ['say', 'it', 'right', 'out', 'no', 'matter', 'for', 'her', 'mother', 'END']
# 1389. ['the', 'man', 'was', 'found', 'id', 'better', 'name', 'no', 'names', 'END']
# 1390. ['john', 'himself', 'wont', 'imagine', 'who', 'he', 'is', 'END']
# 1391. ['then', 'its', 'all', 'up', 'i', 'think', 'ill', 'get', 'away', 'END']
# 1392. ['youll', 'be', 'expecting', 'john', 'i', 'pity', 'estelle', 'END']
# 1393. ['i', 'suppose', 'she', 'deserves', 'some', 'pity', 'too', 'END']
# 1394. ['you', 'ought', 'to', 'have', 'the', 'kitchen', 'to', 'yourself', 'END']
# 1395. ['to', 'break', 'it', 'to', 'him', 'you', 'may', 'have', 'the', 'job', 'END']
# 1396. ['you', 'neednt', 'think', 'youre', 'going', 'to', 'get', 'away', 'END']
# 1397. ['johns', 'almost', 'here', 'ive', 'had', 'my', 'eye', 'on', 'someone', 'END']
# 1398. ['coming', 'down', 'ryans', 'hill', 'i', 'thought', 'twas', 'him', 'END']
# 1399. ['here', 'he', 'is', 'now', 'this', 'box', 'put', 'it', 'away', 'END']
# 1400. ['and', 'this', 'bill', 'END']
# 1401. ['whats', 'the', 'hurry', 'hell', 'unhitch', 'END']
# 1402. ['no', 'he', 'wont', 'either', 'hell', 'just', 'drop', 'the', 'reins', 'END']
# 1403. ['and', 'turn', 'doll', 'out', 'to', 'pasture', 'rig', 'and', 'all', 'END']
# 1404. ['she', 'wont', 'get', 'far', 'before', 'the', 'wheels', 'hang', 'up', 'END']
# 1405. ['on', 'something', 'theres', 'no', 'harm', 'see', 'there', 'he', 'is', 'END']
# 1406. ['my', 'but', 'he', 'looks', 'as', 'if', 'he', 'must', 'have', 'heard', 'END']
# 1407. ['john', 'threw', 'the', 'door', 'wide', 'but', 'he', 'didnt', 'enter', 'END']
# 1408. ['how', 'are', 'you', 'neighbour', 'just', 'the', 'man', 'im', 'after', 'END']
# 1409. ['isnt', 'it', 'hell', 'he', 'said', 'i', 'want', 'to', 'know', 'END']
# 1410. ['come', 'out', 'here', 'if', 'you', 'want', 'to', 'hear', 'me', 'talk', 'END']
# 1411. ['ill', 'talk', 'to', 'you', 'old', 'woman', 'afterward', 'END']
# 1412. ['ive', 'got', 'some', 'news', 'that', 'maybe', 'isnt', 'news', 'END']
# 1413. ['what', 'are', 'they', 'trying', 'to', 'do', 'to', 'me', 'these', 'two', 'END']
# 1414. ['do', 'go', 'along', 'with', 'him', 'and', 'stop', 'his', 'shouting', 'END']
# 1415. ['she', 'raised', 'her', 'voice', 'against', 'the', 'closing', 'door', 'END']
# 1416. ['who', 'wants', 'to', 'hear', 'your', 'news', 'you', 'dreadful', 'fool', 'END']
# 1417. ['a', 'winter', 'garden', 'in', 'an', 'alder', 'swamp', 'END']
# 1418. ['where', 'conies', 'now', 'come', 'out', 'to', 'sun', 'and', 'romp', 'END']
# 1419. ['as', 'near', 'a', 'paradise', 'as', 'it', 'can', 'be', 'END']
# 1420. ['and', 'not', 'melt', 'snow', 'or', 'start', 'a', 'dormant', 'tree', 'END']
# 1421. ['it', 'lifts', 'existence', 'on', 'a', 'plane', 'of', 'snow', 'END']
# 1422. ['one', 'level', 'higher', 'than', 'the', 'earth', 'below', 'END']
# 1423. ['one', 'level', 'nearer', 'heaven', 'overhead', 'END']
# 1424. ['and', 'last', 'years', 'berries', 'shining', 'scarlet', 'red', 'END']
# 1425. ['it', 'lifts', 'a', 'gaunt', 'luxuriating', 'beast', 'END']
# 1426. ['where', 'he', 'can', 'stretch', 'and', 'hold', 'his', 'highest', 'feat', 'END']
# 1427. ['on', 'some', 'wild', 'apple', 'trees', 'young', 'tender', 'bark', 'END']
# 1428. ['what', 'well', 'may', 'prove', 'the', 'years', 'high', 'girdle', 'mark', 'END']
# 1429. ['so', 'near', 'to', 'paradise', 'all', 'pairing', 'ends', 'END']
# 1430. ['here', 'loveless', 'birds', 'now', 'flock', 'as', 'winter', 'friends', 'END']
# 1431. ['content', 'with', 'budinspecting', 'they', 'presume', 'END']
# 1432. ['to', 'say', 'which', 'buds', 'are', 'leaf', 'and', 'which', 'are', 'bloom', 'END']
# 1433. ['a', 'featherhammer', 'gives', 'a', 'double', 'knock', 'END']
# 1434. ['this', 'eden', 'day', 'is', 'done', 'at', 'two', 'oclock', 'END']
# 1435. ['an', 'hour', 'of', 'winter', 'day', 'might', 'seem', 'too', 'short', 'END']
# 1436. ['to', 'make', 'it', 'worth', 'lifes', 'while', 'to', 'wake', 'and', 'sport', 'END']

# %% [markdown]
# ## Step 2: Building Data Structures
# ### A. Initial Word Probabilities

# %%
# Dictionary to store initial word counts and probabilities
initial_word_count = defaultdict(int)

# Count first words of each line
for words in processed_lines:
    first_word = words[0]
    initial_word_count[first_word] += 1

# Calculate probabilities
total_lines = len(processed_lines)
initial_word_prob = {}

for word, count in initial_word_count.items():
    initial_word_prob[word] = count / total_lines

print("Initial Word Probabilities:")
print("="*50)
print(f"Formula: P(w₁) = count(w₁ as first word) / total lines")
print(f"Total lines: {total_lines}")
print("="*50)
for word, prob in sorted(initial_word_prob.items(), key=lambda x: x[1], reverse=True):
    count = initial_word_count[word]
    print(f"P('{word}') = {count}/{total_lines} = {prob:.4f} ({prob*100:.2f}%)")
# Out:
# Initial Word Probabilities:
# ==================================================
# Formula: P(w₁) = count(w₁ as first word) / total lines
# Total lines: 1436
# ==================================================
# P('and') = 129/1436 = 0.0898 (8.98%)
# P('i') = 118/1436 = 0.0822 (8.22%)
# P('the') = 82/1436 = 0.0571 (5.71%)
# P('but') = 51/1436 = 0.0355 (3.55%)
# P('to') = 50/1436 = 0.0348 (3.48%)
# P('you') = 40/1436 = 0.0279 (2.79%)
# P('he') = 34/1436 = 0.0237 (2.37%)
# P('a') = 30/1436 = 0.0209 (2.09%)
# P('in') = 29/1436 = 0.0202 (2.02%)
# P('of') = 29/1436 = 0.0202 (2.02%)
# P('that') = 29/1436 = 0.0202 (2.02%)
# P('it') = 23/1436 = 0.0160 (1.60%)
# P('its') = 21/1436 = 0.0146 (1.46%)
# P('they') = 19/1436 = 0.0132 (1.32%)
# P('with') = 18/1436 = 0.0125 (1.25%)
# P('she') = 17/1436 = 0.0118 (1.18%)
# P('we') = 15/1436 = 0.0104 (1.04%)
# P('as') = 14/1436 = 0.0097 (0.97%)
# P('what') = 14/1436 = 0.0097 (0.97%)
# P('so') = 13/1436 = 0.0091 (0.91%)
# P('not') = 13/1436 = 0.0091 (0.91%)
# P('no') = 13/1436 = 0.0091 (0.91%)
# P('then') = 12/1436 = 0.0084 (0.84%)
# P('if') = 12/1436 = 0.0084 (0.84%)
# P('one') = 11/1436 = 0.0077 (0.77%)
# P('by') = 11/1436 = 0.0077 (0.77%)
# P('hes') = 11/1436 = 0.0077 (0.77%)
# P('or') = 11/1436 = 0.0077 (0.77%)
# P('on') = 11/1436 = 0.0077 (0.77%)
# P('from') = 10/1436 = 0.0070 (0.70%)
# P('ill') = 10/1436 = 0.0070 (0.70%)
# P('when') = 9/1436 = 0.0063 (0.63%)
# P('was') = 9/1436 = 0.0063 (0.63%)
# P('son') = 9/1436 = 0.0063 (0.63%)
# P('two') = 8/1436 = 0.0056 (0.56%)
# P('like') = 8/1436 = 0.0056 (0.56%)
# P('all') = 8/1436 = 0.0056 (0.56%)
# P('where') = 8/1436 = 0.0056 (0.56%)
# P('yes') = 8/1436 = 0.0056 (0.56%)
# P('though') = 7/1436 = 0.0049 (0.49%)
# P('his') = 7/1436 = 0.0049 (0.49%)
# P('my') = 7/1436 = 0.0049 (0.49%)
# P('up') = 7/1436 = 0.0049 (0.49%)
# P('dont') = 7/1436 = 0.0049 (0.49%)
# P('for') = 7/1436 = 0.0049 (0.49%)
# P('mother') = 7/1436 = 0.0049 (0.49%)
# P('at') = 6/1436 = 0.0042 (0.42%)
# P('who') = 6/1436 = 0.0042 (0.42%)
# P('how') = 6/1436 = 0.0042 (0.42%)
# P('there') = 6/1436 = 0.0042 (0.42%)
# P('this') = 6/1436 = 0.0042 (0.42%)
# P('john') = 6/1436 = 0.0042 (0.42%)
# P('some') = 5/1436 = 0.0035 (0.35%)
# P('is') = 5/1436 = 0.0035 (0.35%)
# P('im') = 5/1436 = 0.0035 (0.35%)
# P('only') = 5/1436 = 0.0035 (0.35%)
# P('hed') = 5/1436 = 0.0035 (0.35%)
# P('over') = 5/1436 = 0.0035 (0.35%)
# P('well') = 5/1436 = 0.0035 (0.35%)
# P('toffile') = 5/1436 = 0.0035 (0.35%)
# P('thats') = 5/1436 = 0.0035 (0.35%)
# P('had') = 4/1436 = 0.0028 (0.28%)
# P('oh') = 4/1436 = 0.0028 (0.28%)
# P('sometimes') = 4/1436 = 0.0028 (0.28%)
# P('ive') = 4/1436 = 0.0028 (0.28%)
# P('now') = 4/1436 = 0.0028 (0.28%)
# P('come') = 4/1436 = 0.0028 (0.28%)
# P('here') = 4/1436 = 0.0028 (0.28%)
# P('nor') = 4/1436 = 0.0028 (0.28%)
# P('whats') = 4/1436 = 0.0028 (0.28%)
# P('yet') = 3/1436 = 0.0021 (0.21%)
# P('between') = 3/1436 = 0.0021 (0.21%)
# P('half') = 3/1436 = 0.0021 (0.21%)
# P('were') = 3/1436 = 0.0021 (0.21%)
# P('which') = 3/1436 = 0.0021 (0.21%)
# P('lets') = 3/1436 = 0.0021 (0.21%)
# P('be') = 3/1436 = 0.0021 (0.21%)
# P('take') = 3/1436 = 0.0021 (0.21%)
# P('why') = 3/1436 = 0.0021 (0.21%)
# P('among') = 3/1436 = 0.0021 (0.21%)
# P('shes') = 3/1436 = 0.0021 (0.21%)
# P('whose') = 2/1436 = 0.0014 (0.14%)
# P('her') = 2/1436 = 0.0014 (0.14%)
# P('nothing') = 2/1436 = 0.0014 (0.14%)
# P('disturbed') = 2/1436 = 0.0014 (0.14%)
# P('once') = 2/1436 = 0.0014 (0.14%)
# P('brown') = 2/1436 = 0.0014 (0.14%)
# P('upon') = 2/1436 = 0.0014 (0.14%)
# P('should') = 2/1436 = 0.0014 (0.14%)
# P('until') = 2/1436 = 0.0014 (0.14%)
# P('couldnt') = 2/1436 = 0.0014 (0.14%)
# P('their') = 2/1436 = 0.0014 (0.14%)
# P('has') = 2/1436 = 0.0014 (0.14%)
# P('off') = 2/1436 = 0.0014 (0.14%)
# P('old') = 2/1436 = 0.0014 (0.14%)
# P('sos') = 2/1436 = 0.0014 (0.14%)
# P('however') = 2/1436 = 0.0014 (0.14%)
# P('perhaps') = 2/1436 = 0.0014 (0.14%)
# P('our') = 2/1436 = 0.0014 (0.14%)
# P('through') = 2/1436 = 0.0014 (0.14%)
# P('except') = 2/1436 = 0.0014 (0.14%)
# P('books') = 2/1436 = 0.0014 (0.14%)
# P('till') = 2/1436 = 0.0014 (0.14%)
# P('than') = 2/1436 = 0.0014 (0.14%)
# P('behind') = 2/1436 = 0.0014 (0.14%)
# P('tell') = 2/1436 = 0.0014 (0.14%)
# P('another') = 2/1436 = 0.0014 (0.14%)
# P('before') = 2/1436 = 0.0014 (0.14%)
# P('let') = 2/1436 = 0.0014 (0.14%)
# P('anyone') = 2/1436 = 0.0014 (0.14%)
# P('drawn') = 2/1436 = 0.0014 (0.14%)
# P('would') = 2/1436 = 0.0014 (0.14%)
# P('under') = 2/1436 = 0.0014 (0.14%)
# P('does') = 2/1436 = 0.0014 (0.14%)
# P('beyond') = 2/1436 = 0.0014 (0.14%)
# P('first') = 2/1436 = 0.0014 (0.14%)
# P('bless') = 2/1436 = 0.0014 (0.14%)
# P('something') = 2/1436 = 0.0014 (0.14%)
# P('call') = 2/1436 = 0.0014 (0.14%)
# P('will') = 2/1436 = 0.0014 (0.14%)
# P('back') = 2/1436 = 0.0014 (0.14%)
# P('still') = 2/1436 = 0.0014 (0.14%)
# P('make') = 2/1436 = 0.0014 (0.14%)
# P('too') = 2/1436 = 0.0014 (0.14%)
# P('havent') = 2/1436 = 0.0014 (0.14%)
# P('estelles') = 2/1436 = 0.0014 (0.14%)
# P('johns') = 2/1436 = 0.0014 (0.14%)
# P('because') = 1/1436 = 0.0007 (0.07%)
# P('somewhere') = 1/1436 = 0.0007 (0.07%)
# P('natures') = 1/1436 = 0.0007 (0.07%)
# P('came') = 1/1436 = 0.0007 (0.07%)
# P('proclaimed') = 1/1436 = 0.0007 (0.07%)
# P('smoothlaid') = 1/1436 = 0.0007 (0.07%)
# P('comes') = 1/1436 = 0.0007 (0.07%)
# P('ten') = 1/1436 = 0.0007 (0.07%)
# P('lifted') = 1/1436 = 0.0007 (0.07%)
# P('transfixed') = 1/1436 = 0.0007 (0.07%)
# P('across') = 1/1436 = 0.0007 (0.07%)
# P('looked') = 1/1436 = 0.0007 (0.07%)
# P('stood') = 1/1436 = 0.0007 (0.07%)
# P('me') = 1/1436 = 0.0007 (0.07%)
# P('cross') = 1/1436 = 0.0007 (0.07%)
# P('describing') = 1/1436 = 0.0007 (0.07%)
# P('got') = 1/1436 = 0.0007 (0.07%)
# P('walls') = 1/1436 = 0.0007 (0.07%)
# P('faster') = 1/1436 = 0.0007 (0.07%)
# P('sitting') = 1/1436 = 0.0007 (0.07%)
# P('according') = 1/1436 = 0.0007 (0.07%)
# P('incredulous') = 1/1436 = 0.0007 (0.07%)
# P('wellibe') = 1/1436 = 0.0007 (0.07%)
# P('yankees') = 1/1436 = 0.0007 (0.07%)
# P('after') = 1/1436 = 0.0007 (0.07%)
# P('while') = 1/1436 = 0.0007 (0.07%)
# P('bout') = 1/1436 = 0.0007 (0.07%)
# P('theyve') = 1/1436 = 0.0007 (0.07%)
# P('flattered') = 1/1436 = 0.0007 (0.07%)
# P('always') = 1/1436 = 0.0007 (0.07%)
# P('theyll') = 1/1436 = 0.0007 (0.07%)
# P('voted') = 1/1436 = 0.0007 (0.07%)
# P('wentworth') = 1/1436 = 0.0007 (0.07%)
# P('rights') = 1/1436 = 0.0007 (0.07%)
# P('itd') = 1/1436 = 0.0007 (0.07%)
# P('said') = 1/1436 = 0.0007 (0.07%)
# P('gnaws') = 1/1436 = 0.0007 (0.07%)
# P('last') = 1/1436 = 0.0007 (0.07%)
# P('thered') = 1/1436 = 0.0007 (0.07%)
# P('someday') = 1/1436 = 0.0007 (0.07%)
# P('today') = 1/1436 = 0.0007 (0.07%)
# P('huh') = 1/1436 = 0.0007 (0.07%)
# P('youve') = 1/1436 = 0.0007 (0.07%)
# P('can') = 1/1436 = 0.0007 (0.07%)
# P('ascending') = 1/1436 = 0.0007 (0.07%)
# P('hadnt') = 1/1436 = 0.0007 (0.07%)
# P('look') = 1/1436 = 0.0007 (0.07%)
# P('excuse') = 1/1436 = 0.0007 (0.07%)
# P('life') = 1/1436 = 0.0007 (0.07%)
# P('enough') = 1/1436 = 0.0007 (0.07%)
# P('unfortunately') = 1/1436 = 0.0007 (0.07%)
# P('boys') = 1/1436 = 0.0007 (0.07%)
# P('shatter') = 1/1436 = 0.0007 (0.07%)
# P('tried') = 1/1436 = 0.0007 (0.07%)
# P('having') = 1/1436 = 0.0007 (0.07%)
# P('goodlooking') = 1/1436 = 0.0007 (0.07%)
# P('both') = 1/1436 = 0.0007 (0.07%)
# P('legitimately') = 1/1436 = 0.0007 (0.07%)
# P('crosslegged') = 1/1436 = 0.0007 (0.07%)
# P('alias') = 1/1436 = 0.0007 (0.07%)
# P('about') = 1/1436 = 0.0007 (0.07%)
# P('theres') = 1/1436 = 0.0007 (0.07%)
# P('give') = 1/1436 = 0.0007 (0.07%)
# P('thrown') = 1/1436 = 0.0007 (0.07%)
# P('unless') = 1/1436 = 0.0007 (0.07%)
# P('summoning') = 1/1436 = 0.0007 (0.07%)
# P('whos') = 1/1436 = 0.0007 (0.07%)
# P('done') = 1/1436 = 0.0007 (0.07%)
# P('rather') = 1/1436 = 0.0007 (0.07%)
# P('against') = 1/1436 = 0.0007 (0.07%)
# P('halting') = 1/1436 = 0.0007 (0.07%)
# P('never') = 1/1436 = 0.0007 (0.07%)
# P('right') = 1/1436 = 0.0007 (0.07%)
# P('father') = 1/1436 = 0.0007 (0.07%)
# P('especially') = 1/1436 = 0.0007 (0.07%)
# P('might') = 1/1436 = 0.0007 (0.07%)
# P('struck') = 1/1436 = 0.0007 (0.07%)
# P('began') = 1/1436 = 0.0007 (0.07%)
# P('waiting') = 1/1436 = 0.0007 (0.07%)
# P('flashed') = 1/1436 = 0.0007 (0.07%)
# P('smoke') = 1/1436 = 0.0007 (0.07%)
# P('hand') = 1/1436 = 0.0007 (0.07%)
# P('stillgoing') = 1/1436 = 0.0007 (0.07%)
# P('almost') = 1/1436 = 0.0007 (0.07%)
# P('quick') = 1/1436 = 0.0007 (0.07%)
# P('brushing') = 1/1436 = 0.0007 (0.07%)
# P('o') = 1/1436 = 0.0007 (0.07%)
# P('wed') = 1/1436 = 0.0007 (0.07%)
# P('could') = 1/1436 = 0.0007 (0.07%)
# P('ancestral') = 1/1436 = 0.0007 (0.07%)
# P('someone') = 1/1436 = 0.0007 (0.07%)
# P('thence') = 1/1436 = 0.0007 (0.07%)
# P('made') = 1/1436 = 0.0007 (0.07%)
# P('are') = 1/1436 = 0.0007 (0.07%)
# P('strolled') = 1/1436 = 0.0007 (0.07%)
# P('provision') = 1/1436 = 0.0007 (0.07%)
# P('stark') = 1/1436 = 0.0007 (0.07%)
# P('several') = 1/1436 = 0.0007 (0.07%)
# P('just') = 1/1436 = 0.0007 (0.07%)
# P('bowed') = 1/1436 = 0.0007 (0.07%)
# P('four') = 1/1436 = 0.0007 (0.07%)
# P('dyou') = 1/1436 = 0.0007 (0.07%)
# P('studying') = 1/1436 = 0.0007 (0.07%)
# P('heres') = 1/1436 = 0.0007 (0.07%)
# P('making') = 1/1436 = 0.0007 (0.07%)
# P('see') = 1/1436 = 0.0007 (0.07%)
# P('strung') = 1/1436 = 0.0007 (0.07%)
# P('speaking') = 1/1436 = 0.0007 (0.07%)
# P('strangely') = 1/1436 = 0.0007 (0.07%)
# P('nine') = 1/1436 = 0.0007 (0.07%)
# P('anything') = 1/1436 = 0.0007 (0.07%)
# P('folks') = 1/1436 = 0.0007 (0.07%)
# P('mebbe') = 1/1436 = 0.0007 (0.07%)
# P('more') = 1/1436 = 0.0007 (0.07%)
# P('nowhere') = 1/1436 = 0.0007 (0.07%)
# P('builder') = 1/1436 = 0.0007 (0.07%)
# P('whatever') = 1/1436 = 0.0007 (0.07%)
# P('inscription') = 1/1436 = 0.0007 (0.07%)
# P('winds') = 1/1436 = 0.0007 (0.07%)
# P('moisture') = 1/1436 = 0.0007 (0.07%)
# P('heaven') = 1/1436 = 0.0007 (0.07%)
# P('may') = 1/1436 = 0.0007 (0.07%)
# P('great') = 1/1436 = 0.0007 (0.07%)
# P('long') = 1/1436 = 0.0007 (0.07%)
# P('besides') = 1/1436 = 0.0007 (0.07%)
# P('charge') = 1/1436 = 0.0007 (0.07%)
# P('someones') = 1/1436 = 0.0007 (0.07%)
# P('into') = 1/1436 = 0.0007 (0.07%)
# P('weep') = 1/1436 = 0.0007 (0.07%)
# P('your') = 1/1436 = 0.0007 (0.07%)
# P('cold') = 1/1436 = 0.0007 (0.07%)
# P('drink') = 1/1436 = 0.0007 (0.07%)
# P('wherever') = 1/1436 = 0.0007 (0.07%)
# P('birch') = 1/1436 = 0.0007 (0.07%)
# P('time') = 1/1436 = 0.0007 (0.07%)
# P('small') = 1/1436 = 0.0007 (0.07%)
# P('out') = 1/1436 = 0.0007 (0.07%)
# P('awake') = 1/1436 = 0.0007 (0.07%)
# P('wishing') = 1/1436 = 0.0007 (0.07%)
# P('saturn') = 1/1436 = 0.0007 (0.07%)
# P('speculation') = 1/1436 = 0.0007 (0.07%)
# P('theirs') = 1/1436 = 0.0007 (0.07%)
# P('uttered') = 1/1436 = 0.0007 (0.07%)
# P('trembled') = 1/1436 = 0.0007 (0.07%)
# P('appear') = 1/1436 = 0.0007 (0.07%)
# P('around') = 1/1436 = 0.0007 (0.07%)
# P('since') = 1/1436 = 0.0007 (0.07%)
# P('lord') = 1/1436 = 0.0007 (0.07%)
# P('weve') = 1/1436 = 0.0007 (0.07%)
# P('left') = 1/1436 = 0.0007 (0.07%)
# P('hell') = 1/1436 = 0.0007 (0.07%)
# P('skyhigh') = 1/1436 = 0.0007 (0.07%)
# P('arent') = 1/1436 = 0.0007 (0.07%)
# P('better') = 1/1436 = 0.0007 (0.07%)
# P('reason') = 1/1436 = 0.0007 (0.07%)
# P('such') = 1/1436 = 0.0007 (0.07%)
# P('twas') = 1/1436 = 0.0007 (0.07%)
# P('estelle') = 1/1436 = 0.0007 (0.07%)
# P('farmers') = 1/1436 = 0.0007 (0.07%)
# P('full') = 1/1436 = 0.0007 (0.07%)
# P('moving') = 1/1436 = 0.0007 (0.07%)
# P('nothings') = 1/1436 = 0.0007 (0.07%)
# P('twenty') = 1/1436 = 0.0007 (0.07%)
# P('receipted') = 1/1436 = 0.0007 (0.07%)
# P('wampum') = 1/1436 = 0.0007 (0.07%)
# P('cant') = 1/1436 = 0.0007 (0.07%)
# P('being') = 1/1436 = 0.0007 (0.07%)
# P('oho') = 1/1436 = 0.0007 (0.07%)
# P('bad') = 1/1436 = 0.0007 (0.07%)
# P('nonsense') = 1/1436 = 0.0007 (0.07%)
# P('whod') = 1/1436 = 0.0007 (0.07%)
# P('say') = 1/1436 = 0.0007 (0.07%)
# P('youll') = 1/1436 = 0.0007 (0.07%)
# P('coming') = 1/1436 = 0.0007 (0.07%)
# P('isnt') = 1/1436 = 0.0007 (0.07%)
# P('do') = 1/1436 = 0.0007 (0.07%)
# P('content') = 1/1436 = 0.0007 (0.07%)
# P('an') = 1/1436 = 0.0007 (0.07%)

# %% [markdown]
# ### B. First-order Transitions

# %%
# Dictionary to store first-order transition counts
first_order_count = defaultdict(lambda: defaultdict(int))
single_word_count = defaultdict(int)

# Count transitions
for words in processed_lines:
    for i in range(len(words) - 1):
        current_word = words[i]
        next_word = words[i + 1]
        first_order_count[current_word][next_word] += 1
        single_word_count[current_word] += 1

# Calculate probabilities
first_order_prob = defaultdict(dict)

for current_word, next_words in first_order_count.items():
    total_count = single_word_count[current_word]
    for next_word, count in next_words.items():
        first_order_prob[current_word][next_word] = count / total_count

print("First-order Transition Probabilities:")
print("="*70)
print(f"Formula: P(wₜ|wₜ₋₁) = count(wₜ₋₁, wₜ) / count(wₜ₋₁)")
print("="*70)

# Display some examples
example_count = 0
for current_word in sorted(first_order_prob.keys()):
    if example_count < 10:  # Show first 10 examples
        print(f"\nAfter '{current_word}' (total count: {single_word_count[current_word]}):")
        for next_word, prob in sorted(first_order_prob[current_word].items(), key=lambda x: x[1], reverse=True):
            count = first_order_count[current_word][next_word]
            print(f"  P('{next_word}'|'{current_word}') = {count}/{single_word_count[current_word]} = {prob:.4f} ({prob*100:.2f}%)")
        example_count += 1

print(f"\n... and {len(first_order_prob) - 10} more word transitions")
# Out:
# First-order Transition Probabilities:
# ======================================================================
# Formula: P(wₜ|wₜ₋₁) = count(wₜ₋₁, wₜ) / count(wₜ₋₁)
# ======================================================================
#
# After 'a' (total count: 240):
#   P('house'|'a') = 8/240 = 0.0333 (3.33%)
#   P('man'|'a') = 7/240 = 0.0292 (2.92%)
#   P('witch'|'a') = 5/240 = 0.0208 (2.08%)
#   P('little'|'a') = 5/240 = 0.0208 (2.08%)
#   P('farm'|'a') = 4/240 = 0.0167 (1.67%)
#   P('guide'|'a') = 3/240 = 0.0125 (1.25%)
#   P('day'|'a') = 3/240 = 0.0125 (1.25%)
#   P('bird'|'a') = 3/240 = 0.0125 (1.25%)
#   P('winter'|'a') = 3/240 = 0.0125 (1.25%)
#   P('brook'|'a') = 3/240 = 0.0125 (1.25%)
#   P('tree'|'a') = 2/240 = 0.0083 (0.83%)
#   P('leaf'|'a') = 2/240 = 0.0083 (0.83%)
#   P('gentle'|'a') = 2/240 = 0.0083 (0.83%)
#   P('sort'|'a') = 2/240 = 0.0083 (0.83%)
#   P('hole'|'a') = 2/240 = 0.0083 (0.83%)
#   P('good'|'a') = 2/240 = 0.0083 (0.83%)
#   P('book'|'a') = 2/240 = 0.0083 (0.83%)
#   P('grave'|'a') = 2/240 = 0.0083 (0.83%)
#   P('hill'|'a') = 2/240 = 0.0083 (0.83%)
#   P('time'|'a') = 2/240 = 0.0083 (0.83%)
#   P('chimney'|'a') = 2/240 = 0.0083 (0.83%)
#   P('town'|'a') = 2/240 = 0.0083 (0.83%)
#   P('glass'|'a') = 2/240 = 0.0083 (0.83%)
#   P('yellow'|'a') = 1/240 = 0.0042 (0.42%)
#   P('sigh'|'a') = 1/240 = 0.0042 (0.42%)
#   P('wood'|'a') = 1/240 = 0.0042 (0.42%)
#   P('farmhouse'|'a') = 1/240 = 0.0042 (0.42%)
#   P('shake'|'a') = 1/240 = 0.0042 (0.42%)
#   P('flower'|'a') = 1/240 = 0.0042 (0.42%)
#   P('voice'|'a') = 1/240 = 0.0042 (0.42%)
#   P('wizard'|'a') = 1/240 = 0.0042 (0.42%)
#   P('jerk'|'a') = 1/240 = 0.0042 (0.42%)
#   P('breath'|'a') = 1/240 = 0.0042 (0.42%)
#   P('stray'|'a') = 1/240 = 0.0042 (0.42%)
#   P('swamp'|'a') = 1/240 = 0.0042 (0.42%)
#   P('resurrected'|'a') = 1/240 = 0.0042 (0.42%)
#   P('barkless'|'a') = 1/240 = 0.0042 (0.42%)
#   P('lofty'|'a') = 1/240 = 0.0042 (0.42%)
#   P('coasting'|'a') = 1/240 = 0.0042 (0.42%)
#   P('matter'|'a') = 1/240 = 0.0042 (0.42%)
#   P('present'|'a') = 1/240 = 0.0042 (0.42%)
#   P('lot'|'a') = 1/240 = 0.0042 (0.42%)
#   P('record'|'a') = 1/240 = 0.0042 (0.42%)
#   P('noted'|'a') = 1/240 = 0.0042 (0.42%)
#   P('bat'|'a') = 1/240 = 0.0042 (0.42%)
#   P('post'|'a') = 1/240 = 0.0042 (0.42%)
#   P('cribber'|'a') = 1/240 = 0.0042 (0.42%)
#   P('horse'|'a') = 1/240 = 0.0042 (0.42%)
#   P('strapping'|'a') = 1/240 = 0.0042 (0.42%)
#   P('night'|'a') = 1/240 = 0.0042 (0.42%)
#   P('broomstick'|'a') = 1/240 = 0.0042 (0.42%)
#   P('waterfall'|'a') = 1/240 = 0.0042 (0.42%)
#   P('solid'|'a') = 1/240 = 0.0042 (0.42%)
#   P('settlement'|'a') = 1/240 = 0.0042 (0.42%)
#   P('stone'|'a') = 1/240 = 0.0042 (0.42%)
#   P('worse'|'a') = 1/240 = 0.0042 (0.42%)
#   P('leak'|'a') = 1/240 = 0.0042 (0.42%)
#   P('lookoff'|'a') = 1/240 = 0.0042 (0.42%)
#   P('cliff'|'a') = 1/240 = 0.0042 (0.42%)
#   P('bottle'|'a') = 1/240 = 0.0042 (0.42%)
#   P('likeness'|'a') = 1/240 = 0.0042 (0.42%)
#   P('donkeys'|'a') = 1/240 = 0.0042 (0.42%)
#   P('road'|'a') = 1/240 = 0.0042 (0.42%)
#   P('mile'|'a') = 1/240 = 0.0042 (0.42%)
#   P('window'|'a') = 1/240 = 0.0042 (0.42%)
#   P('whole'|'a') = 1/240 = 0.0042 (0.42%)
#   P('packing'|'a') = 1/240 = 0.0042 (0.42%)
#   P('horn'|'a') = 1/240 = 0.0042 (0.42%)
#   P('village'|'a') = 1/240 = 0.0042 (0.42%)
#   P('poem'|'a') = 1/240 = 0.0042 (0.42%)
#   P('tile'|'a') = 1/240 = 0.0042 (0.42%)
#   P('stricken'|'a') = 1/240 = 0.0042 (0.42%)
#   P('hornyhanded'|'a') = 1/240 = 0.0042 (0.42%)
#   P('demand'|'a') = 1/240 = 0.0042 (0.42%)
#   P('small'|'a') = 1/240 = 0.0042 (0.42%)
#   P('paddle'|'a') = 1/240 = 0.0042 (0.42%)
#   P('trapper'|'a') = 1/240 = 0.0042 (0.42%)
#   P('soul'|'a') = 1/240 = 0.0042 (0.42%)
#   P('windbreak'|'a') = 1/240 = 0.0042 (0.42%)
#   P('headshake'|'a') = 1/240 = 0.0042 (0.42%)
#   P('strait'|'a') = 1/240 = 0.0042 (0.42%)
#   P('ghost'|'a') = 1/240 = 0.0042 (0.42%)
#   P('mother'|'a') = 1/240 = 0.0042 (0.42%)
#   P('common'|'a') = 1/240 = 0.0042 (0.42%)
#   P('table'|'a') = 1/240 = 0.0042 (0.42%)
#   P('skeleton'|'a') = 1/240 = 0.0042 (0.42%)
#   P('pile'|'a') = 1/240 = 0.0042 (0.42%)
#   P('baby'|'a') = 1/240 = 0.0042 (0.42%)
#   P('crutch'|'a') = 1/240 = 0.0042 (0.42%)
#   P('vision'|'a') = 1/240 = 0.0042 (0.42%)
#   P('chandelier'|'a') = 1/240 = 0.0042 (0.42%)
#   P('moment'|'a') = 1/240 = 0.0042 (0.42%)
#   P('tongue'|'a') = 1/240 = 0.0042 (0.42%)
#   P('thing'|'a') = 1/240 = 0.0042 (0.42%)
#   P('scribble'|'a') = 1/240 = 0.0042 (0.42%)
#   P('shutter'|'a') = 1/240 = 0.0042 (0.42%)
#   P('mans'|'a') = 1/240 = 0.0042 (0.42%)
#   P('lie'|'a') = 1/240 = 0.0042 (0.42%)
#   P('single'|'a') = 1/240 = 0.0042 (0.42%)
#   P('bough'|'a') = 1/240 = 0.0042 (0.42%)
#   P('crystal'|'a') = 1/240 = 0.0042 (0.42%)
#   P('brush'|'a') = 1/240 = 0.0042 (0.42%)
#   P('crooked'|'a') = 1/240 = 0.0042 (0.42%)
#   P('piercing'|'a') = 1/240 = 0.0042 (0.42%)
#   P('governor'|'a') = 1/240 = 0.0042 (0.42%)
#   P('rockstrewn'|'a') = 1/240 = 0.0042 (0.42%)
#   P('byroad'|'a') = 1/240 = 0.0042 (0.42%)
#   P('tribe'|'a') = 1/240 = 0.0042 (0.42%)
#   P('tent'|'a') = 1/240 = 0.0042 (0.42%)
#   P('swish'|'a') = 1/240 = 0.0042 (0.42%)
#   P('girl'|'a') = 1/240 = 0.0042 (0.42%)
#   P('family'|'a') = 1/240 = 0.0042 (0.42%)
#   P('sudden'|'a') = 1/240 = 0.0042 (0.42%)
#   P('lane'|'a') = 1/240 = 0.0042 (0.42%)
#   P('viola'|'a') = 1/240 = 0.0042 (0.42%)
#   P('stark'|'a') = 1/240 = 0.0042 (0.42%)
#   P('plain'|'a') = 1/240 = 0.0042 (0.42%)
#   P('shattered'|'a') = 1/240 = 0.0042 (0.42%)
#   P('member'|'a') = 1/240 = 0.0042 (0.42%)
#   P('person'|'a') = 1/240 = 0.0042 (0.42%)
#   P('lake'|'a') = 1/240 = 0.0042 (0.42%)
#   P('storm'|'a') = 1/240 = 0.0042 (0.42%)
#   P('myth'|'a') = 1/240 = 0.0042 (0.42%)
#   P('match'|'a') = 1/240 = 0.0042 (0.42%)
#   P('hand'|'a') = 1/240 = 0.0042 (0.42%)
#   P('bead'|'a') = 1/240 = 0.0042 (0.42%)
#   P('wild'|'a') = 1/240 = 0.0042 (0.42%)
#   P('purer'|'a') = 1/240 = 0.0042 (0.42%)
#   P('picture'|'a') = 1/240 = 0.0042 (0.42%)
#   P('screen'|'a') = 1/240 = 0.0042 (0.42%)
#   P('name'|'a') = 1/240 = 0.0042 (0.42%)
#   P('timber'|'a') = 1/240 = 0.0042 (0.42%)
#   P('doorsill'|'a') = 1/240 = 0.0042 (0.42%)
#   P('new'|'a') = 1/240 = 0.0042 (0.42%)
#   P('dite'|'a') = 1/240 = 0.0042 (0.42%)
#   P('case'|'a') = 1/240 = 0.0042 (0.42%)
#   P('shelf'|'a') = 1/240 = 0.0042 (0.42%)
#   P('pound'|'a') = 1/240 = 0.0042 (0.42%)
#   P('fulllength'|'a') = 1/240 = 0.0042 (0.42%)
#   P('shelfs'|'a') = 1/240 = 0.0042 (0.42%)
#   P('clock'|'a') = 1/240 = 0.0042 (0.42%)
#   P('row'|'a') = 1/240 = 0.0042 (0.42%)
#   P('violin'|'a') = 1/240 = 0.0042 (0.42%)
#   P('glimpse'|'a') = 1/240 = 0.0042 (0.42%)
#   P('garden'|'a') = 1/240 = 0.0042 (0.42%)
#   P('sunny'|'a') = 1/240 = 0.0042 (0.42%)
#   P('passing'|'a') = 1/240 = 0.0042 (0.42%)
#   P('tunnel'|'a') = 1/240 = 0.0042 (0.42%)
#   P('quarry'|'a') = 1/240 = 0.0042 (0.42%)
#   P('story'|'a') = 1/240 = 0.0042 (0.42%)
#   P('certain'|'a') = 1/240 = 0.0042 (0.42%)
#   P('few'|'a') = 1/240 = 0.0042 (0.42%)
#   P('cheering'|'a') = 1/240 = 0.0042 (0.42%)
#   P('buggy'|'a') = 1/240 = 0.0042 (0.42%)
#   P('sign'|'a') = 1/240 = 0.0042 (0.42%)
#   P('harness'|'a') = 1/240 = 0.0042 (0.42%)
#   P('pine'|'a') = 1/240 = 0.0042 (0.42%)
#   P('belilaced'|'a') = 1/240 = 0.0042 (0.42%)
#   P('dent'|'a') = 1/240 = 0.0042 (0.42%)
#   P('spring'|'a') = 1/240 = 0.0042 (0.42%)
#   P('broken'|'a') = 1/240 = 0.0042 (0.42%)
#   P('spell'|'a') = 1/240 = 0.0042 (0.42%)
#   P('thousand'|'a') = 1/240 = 0.0042 (0.42%)
#   P('trillium'|'a') = 1/240 = 0.0042 (0.42%)
#   P('piano'|'a') = 1/240 = 0.0042 (0.42%)
#   P('digger'|'a') = 1/240 = 0.0042 (0.42%)
#   P('smother'|'a') = 1/240 = 0.0042 (0.42%)
#   P('note'|'a') = 1/240 = 0.0042 (0.42%)
#   P('steeple'|'a') = 1/240 = 0.0042 (0.42%)
#   P('beaded'|'a') = 1/240 = 0.0042 (0.42%)
#   P('nova'|'a') = 1/240 = 0.0042 (0.42%)
#   P('headless'|'a') = 1/240 = 0.0042 (0.42%)
#   P('smart'|'a') = 1/240 = 0.0042 (0.42%)
#   P('big'|'a') = 1/240 = 0.0042 (0.42%)
#   P('long'|'a') = 1/240 = 0.0042 (0.42%)
#   P('child'|'a') = 1/240 = 0.0042 (0.42%)
#   P('friend'|'a') = 1/240 = 0.0042 (0.42%)
#   P('bad'|'a') = 1/240 = 0.0042 (0.42%)
#   P('home'|'a') = 1/240 = 0.0042 (0.42%)
#   P('show'|'a') = 1/240 = 0.0042 (0.42%)
#   P('hen'|'a') = 1/240 = 0.0042 (0.42%)
#   P('flock'|'a') = 1/240 = 0.0042 (0.42%)
#   P('times'|'a') = 1/240 = 0.0042 (0.42%)
#   P('bill'|'a') = 1/240 = 0.0042 (0.42%)
#   P('tall'|'a') = 1/240 = 0.0042 (0.42%)
#   P('barrel'|'a') = 1/240 = 0.0042 (0.42%)
#   P('mess'|'a') = 1/240 = 0.0042 (0.42%)
#   P('paradise'|'a') = 1/240 = 0.0042 (0.42%)
#   P('dormant'|'a') = 1/240 = 0.0042 (0.42%)
#   P('plane'|'a') = 1/240 = 0.0042 (0.42%)
#   P('gaunt'|'a') = 1/240 = 0.0042 (0.42%)
#   P('featherhammer'|'a') = 1/240 = 0.0042 (0.42%)
#   P('double'|'a') = 1/240 = 0.0042 (0.42%)
#
# After 'abode' (total count: 1):
#   P('END'|'abode') = 1/1 = 1.0000 (100.00%)
#
# After 'abouncing' (total count: 1):
#   P('on'|'abouncing') = 1/1 = 1.0000 (100.00%)
#
# After 'about' (total count: 17):
#   P('END'|'about') = 4/17 = 0.2353 (23.53%)
#   P('the'|'about') = 3/17 = 0.1765 (17.65%)
#   P('it'|'about') = 3/17 = 0.1765 (17.65%)
#   P('where'|'about') = 1/17 = 0.0588 (5.88%)
#   P('this'|'about') = 1/17 = 0.0588 (5.88%)
#   P('her'|'about') = 1/17 = 0.0588 (5.88%)
#   P('all'|'about') = 1/17 = 0.0588 (5.88%)
#   P('when'|'about') = 1/17 = 0.0588 (5.88%)
#   P('property'|'about') = 1/17 = 0.0588 (5.88%)
#   P('john'|'about') = 1/17 = 0.0588 (5.88%)
#
# After 'above' (total count: 2):
#   P('END'|'above') = 1/2 = 0.5000 (50.00%)
#   P('the'|'above') = 1/2 = 0.5000 (50.00%)
#
# After 'accept' (total count: 1):
#   P('the'|'accept') = 1/1 = 1.0000 (100.00%)
#
# After 'according' (total count: 1):
#   P('as'|'according') = 1/1 = 1.0000 (100.00%)
#
# After 'accounts' (total count: 1):
#   P('END'|'accounts') = 1/1 = 1.0000 (100.00%)
#
# After 'acquaintance' (total count: 1):
#   P('made'|'acquaintance') = 1/1 = 1.0000 (100.00%)
#
# After 'acquainted' (total count: 2):
#   P('with'|'acquainted') = 2/2 = 1.0000 (100.00%)
#
# ... and 2180 more word transitions

# %% [markdown]
# ### C. Second-order Transitions

# %%
# Dictionary to store second-order transition counts
second_order_count = defaultdict(lambda: defaultdict(int))
word_pair_count = defaultdict(int)

# Count transitions
for words in processed_lines:
    for i in range(len(words) - 2):
        word1 = words[i]
        word2 = words[i + 1]
        word3 = words[i + 2]
        pair = (word1, word2)
        second_order_count[pair][word3] += 1
        word_pair_count[pair] += 1

# Calculate probabilities
second_order_prob = defaultdict(dict)

for pair, next_words in second_order_count.items():
    total_count = word_pair_count[pair]
    for next_word, count in next_words.items():
        second_order_prob[pair][next_word] = count / total_count

print("Second-order Transition Probabilities:")
print("="*70)
print(f"Formula: P(wₜ|wₜ₋₂,wₜ₋₁) = count(wₜ₋₂,wₜ₋₁,wₜ) / count(wₜ₋₂,wₜ₋₁)")
print("="*70)

# Display some examples
example_count = 0
for pair in sorted(second_order_prob.keys()):
    if example_count < 10:  # Show first 10 examples
        print(f"\nAfter ('{pair[0]}', '{pair[1]}') (total count: {word_pair_count[pair]}):")
        for next_word, prob in sorted(second_order_prob[pair].items(), key=lambda x: x[1], reverse=True):
            count = second_order_count[pair][next_word]
            print(f"  P('{next_word}'|('{pair[0]}','{pair[1]}')) = {count}/{word_pair_count[pair]} = {prob:.4f} ({prob*100:.2f}%)")
        example_count += 1

print(f"\n... and {len(second_order_prob) - 10} more word pair transitions")
# Out:
# Second-order Transition Probabilities:
# ======================================================================
# Formula: P(wₜ|wₜ₋₂,wₜ₋₁) = count(wₜ₋₂,wₜ₋₁,wₜ) / count(wₜ₋₂,wₜ₋₁)
# ======================================================================
#
# After ('a', 'baby') (total count: 1):
#   P('i'|('a','baby')) = 1/1 = 1.0000 (100.00%)
#
# After ('a', 'bad') (total count: 1):
#   P('farmer'|('a','bad')) = 1/1 = 1.0000 (100.00%)
#
# After ('a', 'barkless') (total count: 1):
#   P('spectre'|('a','barkless')) = 1/1 = 1.0000 (100.00%)
#
# After ('a', 'barrel') (total count: 1):
#   P('from'|('a','barrel')) = 1/1 = 1.0000 (100.00%)
#
# After ('a', 'bat') (total count: 1):
#   P('END'|('a','bat')) = 1/1 = 1.0000 (100.00%)
#
# After ('a', 'bead') (total count: 1):
#   P('of'|('a','bead')) = 1/1 = 1.0000 (100.00%)
#
# After ('a', 'beaded') (total count: 1):
#   P('fur'|('a','beaded')) = 1/1 = 1.0000 (100.00%)
#
# After ('a', 'belilaced') (total count: 1):
#   P('cellar'|('a','belilaced')) = 1/1 = 1.0000 (100.00%)
#
# After ('a', 'big') (total count: 1):
#   P('church'|('a','big')) = 1/1 = 1.0000 (100.00%)
#
# After ('a', 'bill') (total count: 1):
#   P('END'|('a','bill')) = 1/1 = 1.0000 (100.00%)
#
# ... and 7021 more word pair transitions

# %% [markdown]
# ## Step 4: Model Summary

# %%
print("="*50)
print("MARKOV CHAIN MODEL TRAINED SUCCESSFULLY!")
print("="*50)
print(f"Total lines processed: {total_lines}")
print(f"Unique initial words: {len(initial_word_prob)}")
print(f"Unique first-order transitions: {len(first_order_prob)}")
print(f"Unique second-order transitions: {len(second_order_prob)}")
print("="*50)
# Out:
# ==================================================
# MARKOV CHAIN MODEL TRAINED SUCCESSFULLY!
# ==================================================
# Total lines processed: 1436
# Unique initial words: 305
# Unique first-order transitions: 2190
# Unique second-order transitions: 7031
# ==================================================

# %% [markdown]
# ## Step 5: Poetry Generation - Method A (Cumulative Probability)
# Using random selection based on probability distribution

# %%
print("METHOD A: CUMULATIVE PROBABILITY (Random/Varied Output)")

generated_poem_a = []

for line_num in range(5):
    print(f"\n{'='*70}")
    print(f"GENERATING LINE {line_num + 1}")
    print(f"{'='*70}")
    
    generated_words = []
    
    # Step 1: Select first word using initial probabilities
    print("\nStep 1: Selecting first word from initial probabilities")
    print("-" * 70)
    
    words = list(initial_word_prob.keys())
    probabilities = list(initial_word_prob.values())
    
    # Calculate cumulative probabilities
    cumulative_probs = []
    cum_sum = 0
    for prob in probabilities:
        cum_sum += prob
        cumulative_probs.append(cum_sum)
    
    # Display the probability distribution
    print("Word choices and cumulative probabilities:")
    for i, word in enumerate(words):
        print(f"  '{word}': P={probabilities[i]:.4f}, Cumulative={cumulative_probs[i]:.4f}")
    
    # Generate random number and select word
    rand = random.random()
    print(f"\nRandom number generated: {rand:.4f}")
    
    first_word = None
    for i, cum_prob in enumerate(cumulative_probs):
        if rand <= cum_prob:
            first_word = words[i]
            print(f"Selected: '{first_word}' (falls in range [0, {cum_prob:.4f}])")
            break
    
    generated_words.append(first_word)
    
    # Step 2: Select second word using first-order transitions
    print("\nStep 2: Selecting second word using first-order transitions")
    print("-" * 70)
    
    if first_word in first_order_prob:
        words = list(first_order_prob[first_word].keys())
        probabilities = list(first_order_prob[first_word].values())
        
        # Calculate cumulative probabilities
        cumulative_probs = []
        cum_sum = 0
        for prob in probabilities:
            cum_sum += prob
            cumulative_probs.append(cum_sum)
        
        print(f"After '{first_word}', possible words:")
        for i, word in enumerate(words):
            print(f"  '{word}': P={probabilities[i]:.4f}, Cumulative={cumulative_probs[i]:.4f}")
        
        rand = random.random()
        print(f"\nRandom number generated: {rand:.4f}")
        
        second_word = None
        for i, cum_prob in enumerate(cumulative_probs):
            if rand <= cum_prob:
                second_word = words[i]
                print(f"Selected: '{second_word}'")
                break
        
        if second_word == 'END':
            print("\nEND token reached. Line complete.")
        else:
            generated_words.append(second_word)
    
    # Step 3: Select subsequent words using second-order transitions
    if len(generated_words) >= 2 and generated_words[-1] != 'END':
        print("\nStep 3: Selecting subsequent words using second-order transitions")
        print("-" * 70)
        
        word_count = 3
        while True:
            pair = (generated_words[-2], generated_words[-1])
            
            if pair in second_order_prob:
                print(f"\nSelecting word {word_count} after ('{pair[0]}', '{pair[1]}'):")
                
                words = list(second_order_prob[pair].keys())
                probabilities = list(second_order_prob[pair].values())
                
                # Calculate cumulative probabilities
                cumulative_probs = []
                cum_sum = 0
                for prob in probabilities:
                    cum_sum += prob
                    cumulative_probs.append(cum_sum)
                
                for i, word in enumerate(words):
                    print(f"  '{word}': P={probabilities[i]:.4f}, Cumulative={cumulative_probs[i]:.4f}")
                
                rand = random.random()
                print(f"Random number: {rand:.4f}")
                
                next_word = None
                for i, cum_prob in enumerate(cumulative_probs):
                    if rand <= cum_prob:
                        next_word = words[i]
                        print(f"Selected: '{next_word}'")
                        break
                
                if next_word == 'END':
                    print("\nEND token reached. Line complete.")
                    break
                else:
                    generated_words.append(next_word)
                    word_count += 1
            else:
                print(f"\nNo transitions found for ('{pair[0]}', '{pair[1]}'). Ending line.")
                break
    
    # Store the generated line
    line_text = ' '.join(generated_words)
    generated_poem_a.append(line_text)
    print(f"\n>>> Generated Line {line_num + 1}: {line_text}")

# Display the complete poem
print("\n" + "="*70)
print("GENERATED POEM (METHOD A - CUMULATIVE PROBABILITY):")
print("="*70)
for line in generated_poem_a:
    print(line)
print("="*70)
# Out:
# METHOD A: CUMULATIVE PROBABILITY (Random/Varied Output)
#
# ======================================================================
# GENERATING LINE 1
# ======================================================================
#
# Step 1: Selecting first word from initial probabilities
# ----------------------------------------------------------------------
# Word choices and cumulative probabilities:
#   'two': P=0.0056, Cumulative=0.0056
#   'and': P=0.0898, Cumulative=0.0954
#   'to': P=0.0348, Cumulative=0.1302
#   'then': P=0.0084, Cumulative=0.1386
#   'because': P=0.0007, Cumulative=0.1393
#   'though': P=0.0049, Cumulative=0.1442
#   'had': P=0.0028, Cumulative=0.1469
#   'in': P=0.0202, Cumulative=0.1671
#   'oh': P=0.0028, Cumulative=0.1699
#   'yet': P=0.0021, Cumulative=0.1720
#   'i': P=0.0822, Cumulative=0.2542
#   'somewhere': P=0.0007, Cumulative=0.2549
#   'whose': P=0.0014, Cumulative=0.2563
#   'his': P=0.0049, Cumulative=0.2611
#   'he': P=0.0237, Cumulative=0.2848
#   'my': P=0.0049, Cumulative=0.2897
#   'between': P=0.0021, Cumulative=0.2918
#   'the': P=0.0571, Cumulative=0.3489
#   'of': P=0.0202, Cumulative=0.3691
#   'but': P=0.0355, Cumulative=0.4046
#   'some': P=0.0035, Cumulative=0.4081
#   'from': P=0.0070, Cumulative=0.4150
#   'is': P=0.0035, Cumulative=0.4185
#   'natures': P=0.0007, Cumulative=0.4192
#   'her': P=0.0014, Cumulative=0.4206
#   'so': P=0.0091, Cumulative=0.4297
#   'nothing': P=0.0014, Cumulative=0.4311
#   'when': P=0.0063, Cumulative=0.4373
#   'came': P=0.0007, Cumulative=0.4380
#   'one': P=0.0077, Cumulative=0.4457
#   'proclaimed': P=0.0007, Cumulative=0.4464
#   'smoothlaid': P=0.0007, Cumulative=0.4471
#   'half': P=0.0021, Cumulative=0.4492
#   'up': P=0.0049, Cumulative=0.4540
#   'a': P=0.0209, Cumulative=0.4749
#   'disturbed': P=0.0014, Cumulative=0.4763
#   'comes': P=0.0007, Cumulative=0.4770
#   'by': P=0.0077, Cumulative=0.4847
#   'if': P=0.0084, Cumulative=0.4930
#   'were': P=0.0021, Cumulative=0.4951
#   'ten': P=0.0007, Cumulative=0.4958
#   'as': P=0.0097, Cumulative=0.5056
#   'it': P=0.0160, Cumulative=0.5216
#   'lifted': P=0.0007, Cumulative=0.5223
#   'she': P=0.0118, Cumulative=0.5341
#   'transfixed': P=0.0007, Cumulative=0.5348
#   'across': P=0.0007, Cumulative=0.5355
#   'was': P=0.0063, Cumulative=0.5418
#   'once': P=0.0014, Cumulative=0.5432
#   'that': P=0.0202, Cumulative=0.5634
#   'looked': P=0.0007, Cumulative=0.5641
#   'stood': P=0.0007, Cumulative=0.5648
#   'you': P=0.0279, Cumulative=0.5926
#   'me': P=0.0007, Cumulative=0.5933
#   'sometimes': P=0.0028, Cumulative=0.5961
#   'brown': P=0.0014, Cumulative=0.5975
#   'cross': P=0.0007, Cumulative=0.5982
#   'describing': P=0.0007, Cumulative=0.5989
#   'got': P=0.0007, Cumulative=0.5996
#   'walls': P=0.0007, Cumulative=0.6003
#   'like': P=0.0056, Cumulative=0.6058
#   'upon': P=0.0014, Cumulative=0.6072
#   'with': P=0.0125, Cumulative=0.6198
#   'faster': P=0.0007, Cumulative=0.6205
#   'sitting': P=0.0007, Cumulative=0.6212
#   'according': P=0.0007, Cumulative=0.6219
#   'hes': P=0.0077, Cumulative=0.6295
#   'or': P=0.0077, Cumulative=0.6372
#   'incredulous': P=0.0007, Cumulative=0.6379
#   'wellibe': P=0.0007, Cumulative=0.6386
#   'on': P=0.0077, Cumulative=0.6462
#   'should': P=0.0014, Cumulative=0.6476
#   'yankees': P=0.0007, Cumulative=0.6483
#   'dont': P=0.0049, Cumulative=0.6532
#   'until': P=0.0014, Cumulative=0.6546
#   'after': P=0.0007, Cumulative=0.6553
#   'not': P=0.0091, Cumulative=0.6643
#   'at': P=0.0042, Cumulative=0.6685
#   'no': P=0.0091, Cumulative=0.6776
#   'ive': P=0.0028, Cumulative=0.6804
#   'while': P=0.0007, Cumulative=0.6811
#   'bout': P=0.0007, Cumulative=0.6818
#   'now': P=0.0028, Cumulative=0.6845
#   'im': P=0.0035, Cumulative=0.6880
#   'theyve': P=0.0007, Cumulative=0.6887
#   'flattered': P=0.0007, Cumulative=0.6894
#   'they': P=0.0132, Cumulative=0.7026
#   'always': P=0.0007, Cumulative=0.7033
#   'ill': P=0.0070, Cumulative=0.7103
#   'theyll': P=0.0007, Cumulative=0.7110
#   'for': P=0.0049, Cumulative=0.7159
#   'couldnt': P=0.0014, Cumulative=0.7173
#   'voted': P=0.0007, Cumulative=0.7180
#   'which': P=0.0021, Cumulative=0.7201
#   'their': P=0.0014, Cumulative=0.7214
#   'wentworth': P=0.0007, Cumulative=0.7221
#   'only': P=0.0035, Cumulative=0.7256
#   'rights': P=0.0007, Cumulative=0.7263
#   'has': P=0.0014, Cumulative=0.7277
#   'itd': P=0.0007, Cumulative=0.7284
#   'said': P=0.0007, Cumulative=0.7291
#   'hed': P=0.0035, Cumulative=0.7326
#   'all': P=0.0056, Cumulative=0.7382
#   'gnaws': P=0.0007, Cumulative=0.7389
#   'last': P=0.0007, Cumulative=0.7396
#   'over': P=0.0035, Cumulative=0.7430
#   'well': P=0.0035, Cumulative=0.7465
#   'off': P=0.0014, Cumulative=0.7479
#   'old': P=0.0014, Cumulative=0.7493
#   'thered': P=0.0007, Cumulative=0.7500
#   'someday': P=0.0007, Cumulative=0.7507
#   'today': P=0.0007, Cumulative=0.7514
#   'huh': P=0.0007, Cumulative=0.7521
#   'lets': P=0.0021, Cumulative=0.7542
#   'youve': P=0.0007, Cumulative=0.7549
#   'can': P=0.0007, Cumulative=0.7556
#   'be': P=0.0021, Cumulative=0.7577
#   'we': P=0.0104, Cumulative=0.7681
#   'ascending': P=0.0007, Cumulative=0.7688
#   'sos': P=0.0014, Cumulative=0.7702
#   'hadnt': P=0.0007, Cumulative=0.7709
#   'look': P=0.0007, Cumulative=0.7716
#   'what': P=0.0097, Cumulative=0.7813
#   'however': P=0.0014, Cumulative=0.7827
#   'come': P=0.0028, Cumulative=0.7855
#   'its': P=0.0146, Cumulative=0.8001
#   'perhaps': P=0.0014, Cumulative=0.8015
#   'excuse': P=0.0007, Cumulative=0.8022
#   'who': P=0.0042, Cumulative=0.8064
#   'life': P=0.0007, Cumulative=0.8071
#   'our': P=0.0014, Cumulative=0.8085
#   'through': P=0.0014, Cumulative=0.8099
#   'except': P=0.0014, Cumulative=0.8113
#   'books': P=0.0014, Cumulative=0.8127
#   'where': P=0.0056, Cumulative=0.8182
#   'enough': P=0.0007, Cumulative=0.8189
#   'unfortunately': P=0.0007, Cumulative=0.8196
#   'boys': P=0.0007, Cumulative=0.8203
#   'shatter': P=0.0007, Cumulative=0.8210
#   'how': P=0.0042, Cumulative=0.8252
#   'till': P=0.0014, Cumulative=0.8266
#   'tried': P=0.0007, Cumulative=0.8273
#   'having': P=0.0007, Cumulative=0.8280
#   'here': P=0.0028, Cumulative=0.8308
#   'take': P=0.0021, Cumulative=0.8329
#   'why': P=0.0021, Cumulative=0.8350
#   'goodlooking': P=0.0007, Cumulative=0.8357
#   'both': P=0.0007, Cumulative=0.8364
#   'legitimately': P=0.0007, Cumulative=0.8370
#   'there': P=0.0042, Cumulative=0.8412
#   'crosslegged': P=0.0007, Cumulative=0.8419
#   'alias': P=0.0007, Cumulative=0.8426
#   'about': P=0.0007, Cumulative=0.8433
#   'theres': P=0.0007, Cumulative=0.8440
#   'give': P=0.0007, Cumulative=0.8447
#   'thrown': P=0.0007, Cumulative=0.8454
#   'unless': P=0.0007, Cumulative=0.8461
#   'than': P=0.0014, Cumulative=0.8475
#   'behind': P=0.0014, Cumulative=0.8489
#   'mother': P=0.0049, Cumulative=0.8538
#   'summoning': P=0.0007, Cumulative=0.8545
#   'whos': P=0.0007, Cumulative=0.8552
#   'son': P=0.0063, Cumulative=0.8614
#   'done': P=0.0007, Cumulative=0.8621
#   'rather': P=0.0007, Cumulative=0.8628
#   'tell': P=0.0014, Cumulative=0.8642
#   'yes': P=0.0056, Cumulative=0.8698
#   'against': P=0.0007, Cumulative=0.8705
#   'halting': P=0.0007, Cumulative=0.8712
#   'never': P=0.0007, Cumulative=0.8719
#   'another': P=0.0014, Cumulative=0.8733
#   'right': P=0.0007, Cumulative=0.8740
#   'father': P=0.0007, Cumulative=0.8747
#   'especially': P=0.0007, Cumulative=0.8753
#   'might': P=0.0007, Cumulative=0.8760
#   'toffile': P=0.0035, Cumulative=0.8795
#   'struck': P=0.0007, Cumulative=0.8802
#   'began': P=0.0007, Cumulative=0.8809
#   'waiting': P=0.0007, Cumulative=0.8816
#   'flashed': P=0.0007, Cumulative=0.8823
#   'smoke': P=0.0007, Cumulative=0.8830
#   'hand': P=0.0007, Cumulative=0.8837
#   'stillgoing': P=0.0007, Cumulative=0.8844
#   'before': P=0.0014, Cumulative=0.8858
#   'almost': P=0.0007, Cumulative=0.8865
#   'quick': P=0.0007, Cumulative=0.8872
#   'let': P=0.0014, Cumulative=0.8886
#   'brushing': P=0.0007, Cumulative=0.8893
#   'thats': P=0.0035, Cumulative=0.8928
#   'o': P=0.0007, Cumulative=0.8935
#   'wed': P=0.0007, Cumulative=0.8942
#   'could': P=0.0007, Cumulative=0.8948
#   'among': P=0.0021, Cumulative=0.8969
#   'ancestral': P=0.0007, Cumulative=0.8976
#   'someone': P=0.0007, Cumulative=0.8983
#   'thence': P=0.0007, Cumulative=0.8990
#   'made': P=0.0007, Cumulative=0.8997
#   'are': P=0.0007, Cumulative=0.9004
#   'strolled': P=0.0007, Cumulative=0.9011
#   'anyone': P=0.0014, Cumulative=0.9025
#   'this': P=0.0042, Cumulative=0.9067
#   'provision': P=0.0007, Cumulative=0.9074
#   'drawn': P=0.0014, Cumulative=0.9088
#   'stark': P=0.0007, Cumulative=0.9095
#   'would': P=0.0014, Cumulative=0.9109
#   'several': P=0.0007, Cumulative=0.9116
#   'under': P=0.0014, Cumulative=0.9130
#   'just': P=0.0007, Cumulative=0.9136
#   'does': P=0.0014, Cumulative=0.9150
#   'bowed': P=0.0007, Cumulative=0.9157
#   'beyond': P=0.0014, Cumulative=0.9171
#   'four': P=0.0007, Cumulative=0.9178
#   'dyou': P=0.0007, Cumulative=0.9185
#   'studying': P=0.0007, Cumulative=0.9192
#   'first': P=0.0014, Cumulative=0.9206
#   'bless': P=0.0014, Cumulative=0.9220
#   'shes': P=0.0021, Cumulative=0.9241
#   'heres': P=0.0007, Cumulative=0.9248
#   'making': P=0.0007, Cumulative=0.9255
#   'see': P=0.0007, Cumulative=0.9262
#   'strung': P=0.0007, Cumulative=0.9269
#   'something': P=0.0014, Cumulative=0.9283
#   'speaking': P=0.0007, Cumulative=0.9290
#   'strangely': P=0.0007, Cumulative=0.9297
#   'call': P=0.0014, Cumulative=0.9311
#   'nor': P=0.0028, Cumulative=0.9338
#   'nine': P=0.0007, Cumulative=0.9345
#   'anything': P=0.0007, Cumulative=0.9352
#   'folks': P=0.0007, Cumulative=0.9359
#   'mebbe': P=0.0007, Cumulative=0.9366
#   'more': P=0.0007, Cumulative=0.9373
#   'will': P=0.0014, Cumulative=0.9387
#   'nowhere': P=0.0007, Cumulative=0.9394
#   'builder': P=0.0007, Cumulative=0.9401
#   'whatever': P=0.0007, Cumulative=0.9408
#   'inscription': P=0.0007, Cumulative=0.9415
#   'winds': P=0.0007, Cumulative=0.9422
#   'moisture': P=0.0007, Cumulative=0.9429
#   'heaven': P=0.0007, Cumulative=0.9436
#   'back': P=0.0014, Cumulative=0.9450
#   'may': P=0.0007, Cumulative=0.9457
#   'great': P=0.0007, Cumulative=0.9464
#   'long': P=0.0007, Cumulative=0.9471
#   'besides': P=0.0007, Cumulative=0.9478
#   'still': P=0.0014, Cumulative=0.9492
#   'charge': P=0.0007, Cumulative=0.9499
#   'make': P=0.0014, Cumulative=0.9513
#   'someones': P=0.0007, Cumulative=0.9519
#   'into': P=0.0007, Cumulative=0.9526
#   'weep': P=0.0007, Cumulative=0.9533
#   'your': P=0.0007, Cumulative=0.9540
#   'cold': P=0.0007, Cumulative=0.9547
#   'too': P=0.0014, Cumulative=0.9561
#   'drink': P=0.0007, Cumulative=0.9568
#   'wherever': P=0.0007, Cumulative=0.9575
#   'birch': P=0.0007, Cumulative=0.9582
#   'time': P=0.0007, Cumulative=0.9589
#   'small': P=0.0007, Cumulative=0.9596
#   'out': P=0.0007, Cumulative=0.9603
#   'awake': P=0.0007, Cumulative=0.9610
#   'wishing': P=0.0007, Cumulative=0.9617
#   'saturn': P=0.0007, Cumulative=0.9624
#   'speculation': P=0.0007, Cumulative=0.9631
#   'theirs': P=0.0007, Cumulative=0.9638
#   'uttered': P=0.0007, Cumulative=0.9645
#   'trembled': P=0.0007, Cumulative=0.9652
#   'appear': P=0.0007, Cumulative=0.9659
#   'around': P=0.0007, Cumulative=0.9666
#   'since': P=0.0007, Cumulative=0.9673
#   'lord': P=0.0007, Cumulative=0.9680
#   'havent': P=0.0014, Cumulative=0.9694
#   'whats': P=0.0028, Cumulative=0.9721
#   'estelles': P=0.0014, Cumulative=0.9735
#   'weve': P=0.0007, Cumulative=0.9742
#   'left': P=0.0007, Cumulative=0.9749
#   'hell': P=0.0007, Cumulative=0.9756
#   'skyhigh': P=0.0007, Cumulative=0.9763
#   'arent': P=0.0007, Cumulative=0.9770
#   'john': P=0.0042, Cumulative=0.9812
#   'better': P=0.0007, Cumulative=0.9819
#   'reason': P=0.0007, Cumulative=0.9826
#   'such': P=0.0007, Cumulative=0.9833
#   'twas': P=0.0007, Cumulative=0.9840
#   'johns': P=0.0014, Cumulative=0.9854
#   'estelle': P=0.0007, Cumulative=0.9861
#   'farmers': P=0.0007, Cumulative=0.9868
#   'full': P=0.0007, Cumulative=0.9875
#   'moving': P=0.0007, Cumulative=0.9882
#   'nothings': P=0.0007, Cumulative=0.9889
#   'twenty': P=0.0007, Cumulative=0.9896
#   'receipted': P=0.0007, Cumulative=0.9903
#   'wampum': P=0.0007, Cumulative=0.9909
#   'cant': P=0.0007, Cumulative=0.9916
#   'being': P=0.0007, Cumulative=0.9923
#   'oho': P=0.0007, Cumulative=0.9930
#   'bad': P=0.0007, Cumulative=0.9937
#   'nonsense': P=0.0007, Cumulative=0.9944
#   'whod': P=0.0007, Cumulative=0.9951
#   'say': P=0.0007, Cumulative=0.9958
#   'youll': P=0.0007, Cumulative=0.9965
#   'coming': P=0.0007, Cumulative=0.9972
#   'isnt': P=0.0007, Cumulative=0.9979
#   'do': P=0.0007, Cumulative=0.9986
#   'content': P=0.0007, Cumulative=0.9993
#   'an': P=0.0007, Cumulative=1.0000
#
# Random number generated: 0.3003
# Selected: 'the' (falls in range [0, 0.3489])
#
# Step 2: Selecting second word using first-order transitions
# ----------------------------------------------------------------------
# After 'the', possible words:
#   'undergrowth': P=0.0018, Cumulative=0.0018
#   'other': P=0.0018, Cumulative=0.0037
#   'better': P=0.0018, Cumulative=0.0055
#   'passing': P=0.0018, Cumulative=0.0073
#   'same': P=0.0073, Cumulative=0.0146
#   'first': P=0.0037, Cumulative=0.0183
#   'one': P=0.0091, Cumulative=0.0274
#   'difference': P=0.0018, Cumulative=0.0293
#   'village': P=0.0018, Cumulative=0.0311
#   'woods': P=0.0055, Cumulative=0.0366
#   'darkest': P=0.0018, Cumulative=0.0384
#   'year': P=0.0018, Cumulative=0.0402
#   'only': P=0.0110, Cumulative=0.0512
#   'sweep': P=0.0018, Cumulative=0.0530
#   'world': P=0.0073, Cumulative=0.0603
#   'night': P=0.0128, Cumulative=0.0731
#   'furthest': P=0.0037, Cumulative=0.0768
#   'saddest': P=0.0018, Cumulative=0.0786
#   'watchman': P=0.0018, Cumulative=0.0804
#   'sound': P=0.0055, Cumulative=0.0859
#   'sky': P=0.0018, Cumulative=0.0878
#   'time': P=0.0091, Cumulative=0.0969
#   'mowing': P=0.0018, Cumulative=0.0987
#   'headless': P=0.0018, Cumulative=0.1005
#   'heavy': P=0.0018, Cumulative=0.1024
#   'garden': P=0.0037, Cumulative=0.1060
#   'whir': P=0.0018, Cumulative=0.1079
#   'tangle': P=0.0018, Cumulative=0.1097
#   'wall': P=0.0018, Cumulative=0.1115
#   'faded': P=0.0018, Cumulative=0.1133
#   'last': P=0.0037, Cumulative=0.1170
#   'stars': P=0.0018, Cumulative=0.1188
#   'soulandbody': P=0.0018, Cumulative=0.1207
#   'country': P=0.0018, Cumulative=0.1225
#   'hillside': P=0.0018, Cumulative=0.1243
#   'day': P=0.0073, Cumulative=0.1316
#   'sun': P=0.0110, Cumulative=0.1426
#   'way': P=0.0165, Cumulative=0.1590
#   'rug': P=0.0018, Cumulative=0.1609
#   'floor': P=0.0091, Cumulative=0.1700
#   'light': P=0.0091, Cumulative=0.1792
#   'wet': P=0.0037, Cumulative=0.1828
#   'tail': P=0.0037, Cumulative=0.1865
#   'confusion': P=0.0018, Cumulative=0.1883
#   'excited': P=0.0018, Cumulative=0.1901
#   'moon': P=0.0055, Cumulative=0.1956
#   'suns': P=0.0018, Cumulative=0.1974
#   'high': P=0.0018, Cumulative=0.1993
#   'swarm': P=0.0055, Cumulative=0.2048
#   'spell': P=0.0018, Cumulative=0.2066
#   'end': P=0.0037, Cumulative=0.2102
#   'thought': P=0.0018, Cumulative=0.2121
#   'kind': P=0.0037, Cumulative=0.2157
#   'heat': P=0.0037, Cumulative=0.2194
#   'road': P=0.0055, Cumulative=0.2249
#   'coat': P=0.0018, Cumulative=0.2267
#   'blue': P=0.0037, Cumulative=0.2303
#   'strange': P=0.0018, Cumulative=0.2322
#   'news': P=0.0018, Cumulative=0.2340
#   'orchid': P=0.0018, Cumulative=0.2358
#   'house': P=0.0073, Cumulative=0.2431
#   'gale': P=0.0018, Cumulative=0.2450
#   'icy': P=0.0018, Cumulative=0.2468
#   'scene': P=0.0018, Cumulative=0.2486
#   'lantern': P=0.0037, Cumulative=0.2523
#   'figures': P=0.0018, Cumulative=0.2541
#   'grange': P=0.0018, Cumulative=0.2559
#   'battle': P=0.0018, Cumulative=0.2578
#   'river': P=0.0018, Cumulative=0.2596
#   'slippery': P=0.0018, Cumulative=0.2614
#   'january': P=0.0018, Cumulative=0.2633
#   'polish': P=0.0018, Cumulative=0.2651
#   'crust': P=0.0018, Cumulative=0.2669
#   'manner': P=0.0018, Cumulative=0.2687
#   'course': P=0.0018, Cumulative=0.2706
#   'cold': P=0.0073, Cumulative=0.2779
#   'long': P=0.0018, Cumulative=0.2797
#   'witchs': P=0.0018, Cumulative=0.2815
#   'whole': P=0.0018, Cumulative=0.2834
#   'arthur': P=0.0037, Cumulative=0.2870
#   'reason': P=0.0018, Cumulative=0.2888
#   'town': P=0.0055, Cumulative=0.2943
#   'times': P=0.0018, Cumulative=0.2962
#   'warrant': P=0.0018, Cumulative=0.2980
#   'tote': P=0.0018, Cumulative=0.2998
#   'father': P=0.0018, Cumulative=0.3016
#   'law': P=0.0018, Cumulative=0.3035
#   'temptation': P=0.0018, Cumulative=0.3053
#   'expense': P=0.0018, Cumulative=0.3071
#   'poor': P=0.0018, Cumulative=0.3090
#   'posts': P=0.0018, Cumulative=0.3108
#   'crib': P=0.0018, Cumulative=0.3126
#   'four': P=0.0018, Cumulative=0.3144
#   'hitching': P=0.0018, Cumulative=0.3163
#   'stable': P=0.0018, Cumulative=0.3181
#   'smarty': P=0.0018, Cumulative=0.3199
#   'huse': P=0.0018, Cumulative=0.3218
#   'wind': P=0.0018, Cumulative=0.3236
#   'ridgepole': P=0.0018, Cumulative=0.3254
#   'rain': P=0.0073, Cumulative=0.3327
#   'trees': P=0.0018, Cumulative=0.3346
#   'mosses': P=0.0018, Cumulative=0.3364
#   'dark': P=0.0037, Cumulative=0.3400
#   'courage': P=0.0018, Cumulative=0.3419
#   'mountain': P=0.0073, Cumulative=0.3492
#   'mica': P=0.0018, Cumulative=0.3510
#   'place': P=0.0128, Cumulative=0.3638
#   'early': P=0.0018, Cumulative=0.3656
#   'desert': P=0.0018, Cumulative=0.3675
#   'stone': P=0.0018, Cumulative=0.3693
#   'old': P=0.0110, Cumulative=0.3803
#   'cliff': P=0.0018, Cumulative=0.3821
#   'thrilly': P=0.0018, Cumulative=0.3839
#   'fountain': P=0.0037, Cumulative=0.3876
#   'famous': P=0.0018, Cumulative=0.3894
#   'substitute': P=0.0018, Cumulative=0.3912
#   'two': P=0.0018, Cumulative=0.3931
#   'avalanches': P=0.0018, Cumulative=0.3949
#   'chance': P=0.0037, Cumulative=0.3985
#   'outside': P=0.0018, Cumulative=0.4004
#   'people': P=0.0018, Cumulative=0.4022
#   'poetess': P=0.0037, Cumulative=0.4059
#   'book': P=0.0018, Cumulative=0.4077
#   'posies': P=0.0018, Cumulative=0.4095
#   'birds': P=0.0037, Cumulative=0.4132
#   'flowers': P=0.0037, Cumulative=0.4168
#   'poetesss': P=0.0055, Cumulative=0.4223
#   'window': P=0.0018, Cumulative=0.4241
#   'family': P=0.0055, Cumulative=0.4296
#   'unswept': P=0.0018, Cumulative=0.4314
#   'tender': P=0.0018, Cumulative=0.4333
#   'tempting': P=0.0018, Cumulative=0.4351
#   'attic': P=0.0165, Cumulative=0.4516
#   'burden': P=0.0018, Cumulative=0.4534
#   'box': P=0.0018, Cumulative=0.4552
#   'small': P=0.0018, Cumulative=0.4570
#   'tug': P=0.0018, Cumulative=0.4589
#   'fur': P=0.0018, Cumulative=0.4607
#   'door': P=0.0201, Cumulative=0.4808
#   'seal': P=0.0018, Cumulative=0.4826
#   'north': P=0.0018, Cumulative=0.4845
#   'dead': P=0.0091, Cumulative=0.4936
#   'great': P=0.0018, Cumulative=0.4954
#   'mountains': P=0.0018, Cumulative=0.4973
#   'talking': P=0.0018, Cumulative=0.4991
#   'stake': P=0.0018, Cumulative=0.5009
#   'button': P=0.0018, Cumulative=0.5027
#   'sioux': P=0.0018, Cumulative=0.5046
#   'headboard': P=0.0037, Cumulative=0.5082
#   'barrier': P=0.0018, Cumulative=0.5101
#   'cellar': P=0.0274, Cumulative=0.5375
#   'kitchen': P=0.0110, Cumulative=0.5484
#   'bedroom': P=0.0073, Cumulative=0.5558
#   'bed': P=0.0055, Cumulative=0.5612
#   'clothes': P=0.0018, Cumulative=0.5631
#   'bones': P=0.0091, Cumulative=0.5722
#   'cellarstairs': P=0.0018, Cumulative=0.5740
#   'room': P=0.0055, Cumulative=0.5795
#   'board': P=0.0037, Cumulative=0.5832
#   'hard': P=0.0018, Cumulative=0.5850
#   'stairs': P=0.0055, Cumulative=0.5905
#   'bulkhead': P=0.0018, Cumulative=0.5923
#   'knob': P=0.0037, Cumulative=0.5960
#   'landing': P=0.0018, Cumulative=0.5978
#   'faintest': P=0.0018, Cumulative=0.5996
#   'thing': P=0.0037, Cumulative=0.6033
#   'wish': P=0.0018, Cumulative=0.6051
#   'sockets': P=0.0018, Cumulative=0.6069
#   'hand': P=0.0018, Cumulative=0.6088
#   'fingerpieces': P=0.0018, Cumulative=0.6106
#   'hall': P=0.0055, Cumulative=0.6161
#   'novelty': P=0.0018, Cumulative=0.6179
#   'joints': P=0.0018, Cumulative=0.6197
#   'slap': P=0.0018, Cumulative=0.6216
#   'handrail': P=0.0018, Cumulative=0.6234
#   'grave': P=0.0018, Cumulative=0.6252
#   'level': P=0.0018, Cumulative=0.6271
#   'chalkpile': P=0.0018, Cumulative=0.6289
#   'uncommonly': P=0.0018, Cumulative=0.6307
#   'wild': P=0.0037, Cumulative=0.6344
#   'toteroad': P=0.0018, Cumulative=0.6362
#   'moment': P=0.0018, Cumulative=0.6380
#   'steps': P=0.0018, Cumulative=0.6399
#   'dry': P=0.0018, Cumulative=0.6417
#   'truth': P=0.0055, Cumulative=0.6472
#   'least': P=0.0018, Cumulative=0.6490
#   'story': P=0.0018, Cumulative=0.6508
#   'fingerbone': P=0.0018, Cumulative=0.6527
#   'buttons': P=0.0018, Cumulative=0.6545
#   'name': P=0.0055, Cumulative=0.6600
#   'rural': P=0.0018, Cumulative=0.6618
#   'west': P=0.0018, Cumulative=0.6636
#   'breath': P=0.0018, Cumulative=0.6654
#   'white': P=0.0018, Cumulative=0.6673
#   'tree': P=0.0018, Cumulative=0.6691
#   'axe': P=0.0018, Cumulative=0.6709
#   'origin': P=0.0018, Cumulative=0.6728
#   'houses': P=0.0018, Cumulative=0.6746
#   'help': P=0.0018, Cumulative=0.6764
#   'craters': P=0.0018, Cumulative=0.6782
#   'past': P=0.0018, Cumulative=0.6801
#   'young': P=0.0018, Cumulative=0.6819
#   'storm': P=0.0037, Cumulative=0.6856
#   'grass': P=0.0018, Cumulative=0.6874
#   'others': P=0.0018, Cumulative=0.6892
#   'second': P=0.0018, Cumulative=0.6910
#   'curving': P=0.0018, Cumulative=0.6929
#   'weather': P=0.0037, Cumulative=0.6965
#   'heavens': P=0.0018, Cumulative=0.6984
#   'branch': P=0.0018, Cumulative=0.7002
#   'proof': P=0.0018, Cumulative=0.7020
#   'raspberry': P=0.0018, Cumulative=0.7038
#   'shelter': P=0.0018, Cumulative=0.7057
#   'eyes': P=0.0018, Cumulative=0.7075
#   'situation': P=0.0018, Cumulative=0.7093
#   'stark': P=0.0018, Cumulative=0.7112
#   'indians': P=0.0018, Cumulative=0.7130
#   'seven': P=0.0018, Cumulative=0.7148
#   'pit': P=0.0018, Cumulative=0.7166
#   'pipes': P=0.0018, Cumulative=0.7185
#   'jug': P=0.0018, Cumulative=0.7203
#   'nose': P=0.0018, Cumulative=0.7221
#   'chin': P=0.0018, Cumulative=0.7239
#   'noise': P=0.0018, Cumulative=0.7258
#   'brook': P=0.0037, Cumulative=0.7294
#   'empty': P=0.0018, Cumulative=0.7313
#   'voices': P=0.0165, Cumulative=0.7477
#   'roar': P=0.0018, Cumulative=0.7495
#   'bandmusic': P=0.0018, Cumulative=0.7514
#   'art': P=0.0018, Cumulative=0.7532
#   'sounds': P=0.0018, Cumulative=0.7550
#   'meaning': P=0.0018, Cumulative=0.7569
#   'sense': P=0.0018, Cumulative=0.7587
#   'unafraid': P=0.0018, Cumulative=0.7605
#   'raspberries': P=0.0018, Cumulative=0.7623
#   'ancient': P=0.0018, Cumulative=0.7642
#   'life': P=0.0018, Cumulative=0.7660
#   'open': P=0.0037, Cumulative=0.7697
#   'sacred': P=0.0018, Cumulative=0.7715
#   'new': P=0.0018, Cumulative=0.7733
#   'salt': P=0.0018, Cumulative=0.7751
#   'timber': P=0.0018, Cumulative=0.7770
#   'ideals': P=0.0018, Cumulative=0.7788
#   'little': P=0.0037, Cumulative=0.7824
#   'chimney': P=0.0037, Cumulative=0.7861
#   'ground': P=0.0073, Cumulative=0.7934
#   'stove': P=0.0018, Cumulative=0.7952
#   'ominous': P=0.0018, Cumulative=0.7971
#   'papered': P=0.0018, Cumulative=0.7989
#   'smell': P=0.0037, Cumulative=0.8026
#   'chimneys': P=0.0018, Cumulative=0.8044
#   'cottages': P=0.0018, Cumulative=0.8062
#   'folk': P=0.0018, Cumulative=0.8080
#   'snow': P=0.0037, Cumulative=0.8117
#   'slumbering': P=0.0018, Cumulative=0.8135
#   'earth': P=0.0055, Cumulative=0.8190
#   'hours': P=0.0018, Cumulative=0.8208
#   'train': P=0.0018, Cumulative=0.8227
#   'track': P=0.0018, Cumulative=0.8245
#   'loss': P=0.0018, Cumulative=0.8263
#   'former': P=0.0018, Cumulative=0.8282
#   'wear': P=0.0018, Cumulative=0.8300
#   'ledges': P=0.0018, Cumulative=0.8318
#   'chisel': P=0.0018, Cumulative=0.8336
#   'arctic': P=0.0018, Cumulative=0.8355
#   'serial': P=0.0018, Cumulative=0.8373
#   'height': P=0.0037, Cumulative=0.8410
#   'adventure': P=0.0018, Cumulative=0.8428
#   'childrens': P=0.0037, Cumulative=0.8464
#   'playthings': P=0.0018, Cumulative=0.8483
#   'playhouse': P=0.0018, Cumulative=0.8501
#   'children': P=0.0018, Cumulative=0.8519
#   'water': P=0.0018, Cumulative=0.8537
#   'valley': P=0.0018, Cumulative=0.8556
#   'instep': P=0.0018, Cumulative=0.8574
#   'waterside': P=0.0018, Cumulative=0.8592
#   'grail': P=0.0018, Cumulative=0.8611
#   'wrong': P=0.0018, Cumulative=0.8629
#   'goblet': P=0.0018, Cumulative=0.8647
#   'birch': P=0.0018, Cumulative=0.8665
#   'newcut': P=0.0018, Cumulative=0.8684
#   'odor': P=0.0018, Cumulative=0.8702
#   'frogs': P=0.0018, Cumulative=0.8720
#   'minute': P=0.0018, Cumulative=0.8739
#   'recent': P=0.0018, Cumulative=0.8757
#   'boughs': P=0.0018, Cumulative=0.8775
#   'plowed': P=0.0018, Cumulative=0.8793
#   'pianos': P=0.0018, Cumulative=0.8812
#   'hour': P=0.0018, Cumulative=0.8830
#   'hiss': P=0.0018, Cumulative=0.8848
#   'pace': P=0.0018, Cumulative=0.8867
#   'tower': P=0.0037, Cumulative=0.8903
#   'named': P=0.0018, Cumulative=0.8921
#   'lettered': P=0.0018, Cumulative=0.8940
#   'sigmas': P=0.0018, Cumulative=0.8958
#   'cosmic': P=0.0018, Cumulative=0.8976
#   'clock': P=0.0018, Cumulative=0.8995
#   'utmost': P=0.0018, Cumulative=0.9013
#   'wonder': P=0.0018, Cumulative=0.9031
#   'eye': P=0.0018, Cumulative=0.9049
#   'surest': P=0.0018, Cumulative=0.9068
#   'very': P=0.0018, Cumulative=0.9086
#   'infant': P=0.0018, Cumulative=0.9104
#   'bushy': P=0.0018, Cumulative=0.9122
#   'use': P=0.0037, Cumulative=0.9159
#   'word': P=0.0018, Cumulative=0.9177
#   'furniture': P=0.0018, Cumulative=0.9196
#   'yard': P=0.0037, Cumulative=0.9232
#   'growing': P=0.0018, Cumulative=0.9250
#   'hoe': P=0.0018, Cumulative=0.9269
#   'strains': P=0.0018, Cumulative=0.9287
#   'run': P=0.0018, Cumulative=0.9305
#   'dear': P=0.0018, Cumulative=0.9324
#   'farm': P=0.0037, Cumulative=0.9360
#   'mortgage': P=0.0018, Cumulative=0.9378
#   'purse': P=0.0037, Cumulative=0.9415
#   'rights': P=0.0018, Cumulative=0.9433
#   'housework': P=0.0037, Cumulative=0.9470
#   'outdoor': P=0.0018, Cumulative=0.9488
#   'best': P=0.0018, Cumulative=0.9506
#   'legs': P=0.0018, Cumulative=0.9525
#   'rule': P=0.0018, Cumulative=0.9543
#   'upper': P=0.0037, Cumulative=0.9580
#   'hens': P=0.0018, Cumulative=0.9598
#   'offers': P=0.0018, Cumulative=0.9616
#   'money': P=0.0037, Cumulative=0.9653
#   'cupboard': P=0.0018, Cumulative=0.9671
#   'tin': P=0.0018, Cumulative=0.9689
#   'cock': P=0.0018, Cumulative=0.9707
#   'crystal': P=0.0018, Cumulative=0.9726
#   'bill': P=0.0018, Cumulative=0.9744
#   'worse': P=0.0037, Cumulative=0.9781
#   'root': P=0.0018, Cumulative=0.9799
#   'real': P=0.0018, Cumulative=0.9817
#   'neighbours': P=0.0018, Cumulative=0.9835
#   'strain': P=0.0018, Cumulative=0.9854
#   'man': P=0.0037, Cumulative=0.9890
#   'job': P=0.0018, Cumulative=0.9909
#   'hurry': P=0.0018, Cumulative=0.9927
#   'reins': P=0.0018, Cumulative=0.9945
#   'wheels': P=0.0018, Cumulative=0.9963
#   'closing': P=0.0018, Cumulative=0.9982
#   'years': P=0.0018, Cumulative=1.0000
#
# Random number generated: 0.4034
# Selected: 'poetess'
#
# Step 3: Selecting subsequent words using second-order transitions
# ----------------------------------------------------------------------
#
# Selecting word 3 after ('the', 'poetess'):
#   'who': P=0.5000, Cumulative=0.5000
#   'had': P=0.5000, Cumulative=1.0000
# Random number: 0.6860
# Selected: 'had'
#
# Selecting word 4 after ('poetess', 'had'):
#   'sighed': P=1.0000, Cumulative=1.0000
# Random number: 0.6664
# Selected: 'sighed'
#
# Selecting word 5 after ('had', 'sighed'):
#   'i': P=1.0000, Cumulative=1.0000
# Random number: 0.4535
# Selected: 'i'
#
# Selecting word 6 after ('sighed', 'i'):
#   'knew': P=1.0000, Cumulative=1.0000
# Random number: 0.1091
# Selected: 'knew'
#
# Selecting word 7 after ('i', 'knew'):
#   'END': P=0.2500, Cumulative=0.2500
#   'in': P=0.2500, Cumulative=0.5000
#   'them': P=0.2500, Cumulative=0.7500
#   'there': P=0.2500, Cumulative=1.0000
# Random number: 0.8668
# Selected: 'there'
#
# Selecting word 8 after ('knew', 'there'):
#   'must': P=1.0000, Cumulative=1.0000
# Random number: 0.8103
# Selected: 'must'
#
# Selecting word 9 after ('there', 'must'):
#   'be': P=1.0000, Cumulative=1.0000
# Random number: 0.5105
# Selected: 'be'
#
# Selecting word 10 after ('must', 'be'):
#   'to': P=0.1111, Cumulative=0.1111
#   'near': P=0.1111, Cumulative=0.2222
#   'there': P=0.1111, Cumulative=0.3333
#   'learned': P=0.1111, Cumulative=0.4444
#   'strange': P=0.1111, Cumulative=0.5556
#   'very': P=0.1111, Cumulative=0.6667
#   'right': P=0.1111, Cumulative=0.7778
#   'blind': P=0.1111, Cumulative=0.8889
#   'something': P=0.1111, Cumulative=1.0000
# Random number: 0.9097
# Selected: 'something'
#
# Selecting word 11 after ('be', 'something'):
#   'END': P=1.0000, Cumulative=1.0000
# Random number: 0.8268
# Selected: 'END'
#
# END token reached. Line complete.
#
# >>> Generated Line 1: the poetess had sighed i knew there must be something
#
# ======================================================================
# GENERATING LINE 2
# ======================================================================
#
# Step 1: Selecting first word from initial probabilities
# ----------------------------------------------------------------------
# Word choices and cumulative probabilities:
#   'two': P=0.0056, Cumulative=0.0056
#   'and': P=0.0898, Cumulative=0.0954
#   'to': P=0.0348, Cumulative=0.1302
#   'then': P=0.0084, Cumulative=0.1386
#   'because': P=0.0007, Cumulative=0.1393
#   'though': P=0.0049, Cumulative=0.1442
#   'had': P=0.0028, Cumulative=0.1469
#   'in': P=0.0202, Cumulative=0.1671
#   'oh': P=0.0028, Cumulative=0.1699
#   'yet': P=0.0021, Cumulative=0.1720
#   'i': P=0.0822, Cumulative=0.2542
#   'somewhere': P=0.0007, Cumulative=0.2549
#   'whose': P=0.0014, Cumulative=0.2563
#   'his': P=0.0049, Cumulative=0.2611
#   'he': P=0.0237, Cumulative=0.2848
#   'my': P=0.0049, Cumulative=0.2897
#   'between': P=0.0021, Cumulative=0.2918
#   'the': P=0.0571, Cumulative=0.3489
#   'of': P=0.0202, Cumulative=0.3691
#   'but': P=0.0355, Cumulative=0.4046
#   'some': P=0.0035, Cumulative=0.4081
#   'from': P=0.0070, Cumulative=0.4150
#   'is': P=0.0035, Cumulative=0.4185
#   'natures': P=0.0007, Cumulative=0.4192
#   'her': P=0.0014, Cumulative=0.4206
#   'so': P=0.0091, Cumulative=0.4297
#   'nothing': P=0.0014, Cumulative=0.4311
#   'when': P=0.0063, Cumulative=0.4373
#   'came': P=0.0007, Cumulative=0.4380
#   'one': P=0.0077, Cumulative=0.4457
#   'proclaimed': P=0.0007, Cumulative=0.4464
#   'smoothlaid': P=0.0007, Cumulative=0.4471
#   'half': P=0.0021, Cumulative=0.4492
#   'up': P=0.0049, Cumulative=0.4540
#   'a': P=0.0209, Cumulative=0.4749
#   'disturbed': P=0.0014, Cumulative=0.4763
#   'comes': P=0.0007, Cumulative=0.4770
#   'by': P=0.0077, Cumulative=0.4847
#   'if': P=0.0084, Cumulative=0.4930
#   'were': P=0.0021, Cumulative=0.4951
#   'ten': P=0.0007, Cumulative=0.4958
#   'as': P=0.0097, Cumulative=0.5056
#   'it': P=0.0160, Cumulative=0.5216
#   'lifted': P=0.0007, Cumulative=0.5223
#   'she': P=0.0118, Cumulative=0.5341
#   'transfixed': P=0.0007, Cumulative=0.5348
#   'across': P=0.0007, Cumulative=0.5355
#   'was': P=0.0063, Cumulative=0.5418
#   'once': P=0.0014, Cumulative=0.5432
#   'that': P=0.0202, Cumulative=0.5634
#   'looked': P=0.0007, Cumulative=0.5641
#   'stood': P=0.0007, Cumulative=0.5648
#   'you': P=0.0279, Cumulative=0.5926
#   'me': P=0.0007, Cumulative=0.5933
#   'sometimes': P=0.0028, Cumulative=0.5961
#   'brown': P=0.0014, Cumulative=0.5975
#   'cross': P=0.0007, Cumulative=0.5982
#   'describing': P=0.0007, Cumulative=0.5989
#   'got': P=0.0007, Cumulative=0.5996
#   'walls': P=0.0007, Cumulative=0.6003
#   'like': P=0.0056, Cumulative=0.6058
#   'upon': P=0.0014, Cumulative=0.6072
#   'with': P=0.0125, Cumulative=0.6198
#   'faster': P=0.0007, Cumulative=0.6205
#   'sitting': P=0.0007, Cumulative=0.6212
#   'according': P=0.0007, Cumulative=0.6219
#   'hes': P=0.0077, Cumulative=0.6295
#   'or': P=0.0077, Cumulative=0.6372
#   'incredulous': P=0.0007, Cumulative=0.6379
#   'wellibe': P=0.0007, Cumulative=0.6386
#   'on': P=0.0077, Cumulative=0.6462
#   'should': P=0.0014, Cumulative=0.6476
#   'yankees': P=0.0007, Cumulative=0.6483
#   'dont': P=0.0049, Cumulative=0.6532
#   'until': P=0.0014, Cumulative=0.6546
#   'after': P=0.0007, Cumulative=0.6553
#   'not': P=0.0091, Cumulative=0.6643
#   'at': P=0.0042, Cumulative=0.6685
#   'no': P=0.0091, Cumulative=0.6776
#   'ive': P=0.0028, Cumulative=0.6804
#   'while': P=0.0007, Cumulative=0.6811
#   'bout': P=0.0007, Cumulative=0.6818
#   'now': P=0.0028, Cumulative=0.6845
#   'im': P=0.0035, Cumulative=0.6880
#   'theyve': P=0.0007, Cumulative=0.6887
#   'flattered': P=0.0007, Cumulative=0.6894
#   'they': P=0.0132, Cumulative=0.7026
#   'always': P=0.0007, Cumulative=0.7033
#   'ill': P=0.0070, Cumulative=0.7103
#   'theyll': P=0.0007, Cumulative=0.7110
#   'for': P=0.0049, Cumulative=0.7159
#   'couldnt': P=0.0014, Cumulative=0.7173
#   'voted': P=0.0007, Cumulative=0.7180
#   'which': P=0.0021, Cumulative=0.7201
#   'their': P=0.0014, Cumulative=0.7214
#   'wentworth': P=0.0007, Cumulative=0.7221
#   'only': P=0.0035, Cumulative=0.7256
#   'rights': P=0.0007, Cumulative=0.7263
#   'has': P=0.0014, Cumulative=0.7277
#   'itd': P=0.0007, Cumulative=0.7284
#   'said': P=0.0007, Cumulative=0.7291
#   'hed': P=0.0035, Cumulative=0.7326
#   'all': P=0.0056, Cumulative=0.7382
#   'gnaws': P=0.0007, Cumulative=0.7389
#   'last': P=0.0007, Cumulative=0.7396
#   'over': P=0.0035, Cumulative=0.7430
#   'well': P=0.0035, Cumulative=0.7465
#   'off': P=0.0014, Cumulative=0.7479
#   'old': P=0.0014, Cumulative=0.7493
#   'thered': P=0.0007, Cumulative=0.7500
#   'someday': P=0.0007, Cumulative=0.7507
#   'today': P=0.0007, Cumulative=0.7514
#   'huh': P=0.0007, Cumulative=0.7521
#   'lets': P=0.0021, Cumulative=0.7542
#   'youve': P=0.0007, Cumulative=0.7549
#   'can': P=0.0007, Cumulative=0.7556
#   'be': P=0.0021, Cumulative=0.7577
#   'we': P=0.0104, Cumulative=0.7681
#   'ascending': P=0.0007, Cumulative=0.7688
#   'sos': P=0.0014, Cumulative=0.7702
#   'hadnt': P=0.0007, Cumulative=0.7709
#   'look': P=0.0007, Cumulative=0.7716
#   'what': P=0.0097, Cumulative=0.7813
#   'however': P=0.0014, Cumulative=0.7827
#   'come': P=0.0028, Cumulative=0.7855
#   'its': P=0.0146, Cumulative=0.8001
#   'perhaps': P=0.0014, Cumulative=0.8015
#   'excuse': P=0.0007, Cumulative=0.8022
#   'who': P=0.0042, Cumulative=0.8064
#   'life': P=0.0007, Cumulative=0.8071
#   'our': P=0.0014, Cumulative=0.8085
#   'through': P=0.0014, Cumulative=0.8099
#   'except': P=0.0014, Cumulative=0.8113
#   'books': P=0.0014, Cumulative=0.8127
#   'where': P=0.0056, Cumulative=0.8182
#   'enough': P=0.0007, Cumulative=0.8189
#   'unfortunately': P=0.0007, Cumulative=0.8196
#   'boys': P=0.0007, Cumulative=0.8203
#   'shatter': P=0.0007, Cumulative=0.8210
#   'how': P=0.0042, Cumulative=0.8252
#   'till': P=0.0014, Cumulative=0.8266
#   'tried': P=0.0007, Cumulative=0.8273
#   'having': P=0.0007, Cumulative=0.8280
#   'here': P=0.0028, Cumulative=0.8308
#   'take': P=0.0021, Cumulative=0.8329
#   'why': P=0.0021, Cumulative=0.8350
#   'goodlooking': P=0.0007, Cumulative=0.8357
#   'both': P=0.0007, Cumulative=0.8364
#   'legitimately': P=0.0007, Cumulative=0.8370
#   'there': P=0.0042, Cumulative=0.8412
#   'crosslegged': P=0.0007, Cumulative=0.8419
#   'alias': P=0.0007, Cumulative=0.8426
#   'about': P=0.0007, Cumulative=0.8433
#   'theres': P=0.0007, Cumulative=0.8440
#   'give': P=0.0007, Cumulative=0.8447
#   'thrown': P=0.0007, Cumulative=0.8454
#   'unless': P=0.0007, Cumulative=0.8461
#   'than': P=0.0014, Cumulative=0.8475
#   'behind': P=0.0014, Cumulative=0.8489
#   'mother': P=0.0049, Cumulative=0.8538
#   'summoning': P=0.0007, Cumulative=0.8545
#   'whos': P=0.0007, Cumulative=0.8552
#   'son': P=0.0063, Cumulative=0.8614
#   'done': P=0.0007, Cumulative=0.8621
#   'rather': P=0.0007, Cumulative=0.8628
#   'tell': P=0.0014, Cumulative=0.8642
#   'yes': P=0.0056, Cumulative=0.8698
#   'against': P=0.0007, Cumulative=0.8705
#   'halting': P=0.0007, Cumulative=0.8712
#   'never': P=0.0007, Cumulative=0.8719
#   'another': P=0.0014, Cumulative=0.8733
#   'right': P=0.0007, Cumulative=0.8740
#   'father': P=0.0007, Cumulative=0.8747
#   'especially': P=0.0007, Cumulative=0.8753
#   'might': P=0.0007, Cumulative=0.8760
#   'toffile': P=0.0035, Cumulative=0.8795
#   'struck': P=0.0007, Cumulative=0.8802
#   'began': P=0.0007, Cumulative=0.8809
#   'waiting': P=0.0007, Cumulative=0.8816
#   'flashed': P=0.0007, Cumulative=0.8823
#   'smoke': P=0.0007, Cumulative=0.8830
#   'hand': P=0.0007, Cumulative=0.8837
#   'stillgoing': P=0.0007, Cumulative=0.8844
#   'before': P=0.0014, Cumulative=0.8858
#   'almost': P=0.0007, Cumulative=0.8865
#   'quick': P=0.0007, Cumulative=0.8872
#   'let': P=0.0014, Cumulative=0.8886
#   'brushing': P=0.0007, Cumulative=0.8893
#   'thats': P=0.0035, Cumulative=0.8928
#   'o': P=0.0007, Cumulative=0.8935
#   'wed': P=0.0007, Cumulative=0.8942
#   'could': P=0.0007, Cumulative=0.8948
#   'among': P=0.0021, Cumulative=0.8969
#   'ancestral': P=0.0007, Cumulative=0.8976
#   'someone': P=0.0007, Cumulative=0.8983
#   'thence': P=0.0007, Cumulative=0.8990
#   'made': P=0.0007, Cumulative=0.8997
#   'are': P=0.0007, Cumulative=0.9004
#   'strolled': P=0.0007, Cumulative=0.9011
#   'anyone': P=0.0014, Cumulative=0.9025
#   'this': P=0.0042, Cumulative=0.9067
#   'provision': P=0.0007, Cumulative=0.9074
#   'drawn': P=0.0014, Cumulative=0.9088
#   'stark': P=0.0007, Cumulative=0.9095
#   'would': P=0.0014, Cumulative=0.9109
#   'several': P=0.0007, Cumulative=0.9116
#   'under': P=0.0014, Cumulative=0.9130
#   'just': P=0.0007, Cumulative=0.9136
#   'does': P=0.0014, Cumulative=0.9150
#   'bowed': P=0.0007, Cumulative=0.9157
#   'beyond': P=0.0014, Cumulative=0.9171
#   'four': P=0.0007, Cumulative=0.9178
#   'dyou': P=0.0007, Cumulative=0.9185
#   'studying': P=0.0007, Cumulative=0.9192
#   'first': P=0.0014, Cumulative=0.9206
#   'bless': P=0.0014, Cumulative=0.9220
#   'shes': P=0.0021, Cumulative=0.9241
#   'heres': P=0.0007, Cumulative=0.9248
#   'making': P=0.0007, Cumulative=0.9255
#   'see': P=0.0007, Cumulative=0.9262
#   'strung': P=0.0007, Cumulative=0.9269
#   'something': P=0.0014, Cumulative=0.9283
#   'speaking': P=0.0007, Cumulative=0.9290
#   'strangely': P=0.0007, Cumulative=0.9297
#   'call': P=0.0014, Cumulative=0.9311
#   'nor': P=0.0028, Cumulative=0.9338
#   'nine': P=0.0007, Cumulative=0.9345
#   'anything': P=0.0007, Cumulative=0.9352
#   'folks': P=0.0007, Cumulative=0.9359
#   'mebbe': P=0.0007, Cumulative=0.9366
#   'more': P=0.0007, Cumulative=0.9373
#   'will': P=0.0014, Cumulative=0.9387
#   'nowhere': P=0.0007, Cumulative=0.9394
#   'builder': P=0.0007, Cumulative=0.9401
#   'whatever': P=0.0007, Cumulative=0.9408
#   'inscription': P=0.0007, Cumulative=0.9415
#   'winds': P=0.0007, Cumulative=0.9422
#   'moisture': P=0.0007, Cumulative=0.9429
#   'heaven': P=0.0007, Cumulative=0.9436
#   'back': P=0.0014, Cumulative=0.9450
#   'may': P=0.0007, Cumulative=0.9457
#   'great': P=0.0007, Cumulative=0.9464
#   'long': P=0.0007, Cumulative=0.9471
#   'besides': P=0.0007, Cumulative=0.9478
#   'still': P=0.0014, Cumulative=0.9492
#   'charge': P=0.0007, Cumulative=0.9499
#   'make': P=0.0014, Cumulative=0.9513
#   'someones': P=0.0007, Cumulative=0.9519
#   'into': P=0.0007, Cumulative=0.9526
#   'weep': P=0.0007, Cumulative=0.9533
#   'your': P=0.0007, Cumulative=0.9540
#   'cold': P=0.0007, Cumulative=0.9547
#   'too': P=0.0014, Cumulative=0.9561
#   'drink': P=0.0007, Cumulative=0.9568
#   'wherever': P=0.0007, Cumulative=0.9575
#   'birch': P=0.0007, Cumulative=0.9582
#   'time': P=0.0007, Cumulative=0.9589
#   'small': P=0.0007, Cumulative=0.9596
#   'out': P=0.0007, Cumulative=0.9603
#   'awake': P=0.0007, Cumulative=0.9610
#   'wishing': P=0.0007, Cumulative=0.9617
#   'saturn': P=0.0007, Cumulative=0.9624
#   'speculation': P=0.0007, Cumulative=0.9631
#   'theirs': P=0.0007, Cumulative=0.9638
#   'uttered': P=0.0007, Cumulative=0.9645
#   'trembled': P=0.0007, Cumulative=0.9652
#   'appear': P=0.0007, Cumulative=0.9659
#   'around': P=0.0007, Cumulative=0.9666
#   'since': P=0.0007, Cumulative=0.9673
#   'lord': P=0.0007, Cumulative=0.9680
#   'havent': P=0.0014, Cumulative=0.9694
#   'whats': P=0.0028, Cumulative=0.9721
#   'estelles': P=0.0014, Cumulative=0.9735
#   'weve': P=0.0007, Cumulative=0.9742
#   'left': P=0.0007, Cumulative=0.9749
#   'hell': P=0.0007, Cumulative=0.9756
#   'skyhigh': P=0.0007, Cumulative=0.9763
#   'arent': P=0.0007, Cumulative=0.9770
#   'john': P=0.0042, Cumulative=0.9812
#   'better': P=0.0007, Cumulative=0.9819
#   'reason': P=0.0007, Cumulative=0.9826
#   'such': P=0.0007, Cumulative=0.9833
#   'twas': P=0.0007, Cumulative=0.9840
#   'johns': P=0.0014, Cumulative=0.9854
#   'estelle': P=0.0007, Cumulative=0.9861
#   'farmers': P=0.0007, Cumulative=0.9868
#   'full': P=0.0007, Cumulative=0.9875
#   'moving': P=0.0007, Cumulative=0.9882
#   'nothings': P=0.0007, Cumulative=0.9889
#   'twenty': P=0.0007, Cumulative=0.9896
#   'receipted': P=0.0007, Cumulative=0.9903
#   'wampum': P=0.0007, Cumulative=0.9909
#   'cant': P=0.0007, Cumulative=0.9916
#   'being': P=0.0007, Cumulative=0.9923
#   'oho': P=0.0007, Cumulative=0.9930
#   'bad': P=0.0007, Cumulative=0.9937
#   'nonsense': P=0.0007, Cumulative=0.9944
#   'whod': P=0.0007, Cumulative=0.9951
#   'say': P=0.0007, Cumulative=0.9958
#   'youll': P=0.0007, Cumulative=0.9965
#   'coming': P=0.0007, Cumulative=0.9972
#   'isnt': P=0.0007, Cumulative=0.9979
#   'do': P=0.0007, Cumulative=0.9986
#   'content': P=0.0007, Cumulative=0.9993
#   'an': P=0.0007, Cumulative=1.0000
#
# Random number generated: 0.4636
# Selected: 'a' (falls in range [0, 0.4749])
#
# Step 2: Selecting second word using first-order transitions
# ----------------------------------------------------------------------
# After 'a', possible words:
#   'yellow': P=0.0042, Cumulative=0.0042
#   'sigh': P=0.0042, Cumulative=0.0083
#   'wood': P=0.0042, Cumulative=0.0125
#   'farmhouse': P=0.0042, Cumulative=0.0167
#   'shake': P=0.0042, Cumulative=0.0208
#   'flower': P=0.0042, Cumulative=0.0250
#   'tree': P=0.0083, Cumulative=0.0333
#   'leaf': P=0.0083, Cumulative=0.0417
#   'voice': P=0.0042, Cumulative=0.0458
#   'wizard': P=0.0042, Cumulative=0.0500
#   'witch': P=0.0208, Cumulative=0.0708
#   'gentle': P=0.0083, Cumulative=0.0792
#   'jerk': P=0.0042, Cumulative=0.0833
#   'breath': P=0.0042, Cumulative=0.0875
#   'stray': P=0.0042, Cumulative=0.0917
#   'swamp': P=0.0042, Cumulative=0.0958
#   'sort': P=0.0083, Cumulative=0.1042
#   'resurrected': P=0.0042, Cumulative=0.1083
#   'barkless': P=0.0042, Cumulative=0.1125
#   'lofty': P=0.0042, Cumulative=0.1167
#   'hole': P=0.0083, Cumulative=0.1250
#   'coasting': P=0.0042, Cumulative=0.1292
#   'man': P=0.0292, Cumulative=0.1583
#   'matter': P=0.0042, Cumulative=0.1625
#   'present': P=0.0042, Cumulative=0.1667
#   'lot': P=0.0042, Cumulative=0.1708
#   'record': P=0.0042, Cumulative=0.1750
#   'noted': P=0.0042, Cumulative=0.1792
#   'bat': P=0.0042, Cumulative=0.1833
#   'post': P=0.0042, Cumulative=0.1875
#   'cribber': P=0.0042, Cumulative=0.1917
#   'horse': P=0.0042, Cumulative=0.1958
#   'strapping': P=0.0042, Cumulative=0.2000
#   'night': P=0.0042, Cumulative=0.2042
#   'broomstick': P=0.0042, Cumulative=0.2083
#   'waterfall': P=0.0042, Cumulative=0.2125
#   'solid': P=0.0042, Cumulative=0.2167
#   'settlement': P=0.0042, Cumulative=0.2208
#   'stone': P=0.0042, Cumulative=0.2250
#   'worse': P=0.0042, Cumulative=0.2292
#   'leak': P=0.0042, Cumulative=0.2333
#   'good': P=0.0083, Cumulative=0.2417
#   'guide': P=0.0125, Cumulative=0.2542
#   'day': P=0.0125, Cumulative=0.2667
#   'lookoff': P=0.0042, Cumulative=0.2708
#   'cliff': P=0.0042, Cumulative=0.2750
#   'bottle': P=0.0042, Cumulative=0.2792
#   'likeness': P=0.0042, Cumulative=0.2833
#   'donkeys': P=0.0042, Cumulative=0.2875
#   'road': P=0.0042, Cumulative=0.2917
#   'mile': P=0.0042, Cumulative=0.2958
#   'house': P=0.0333, Cumulative=0.3292
#   'window': P=0.0042, Cumulative=0.3333
#   'whole': P=0.0042, Cumulative=0.3375
#   'packing': P=0.0042, Cumulative=0.3417
#   'horn': P=0.0042, Cumulative=0.3458
#   'village': P=0.0042, Cumulative=0.3500
#   'poem': P=0.0042, Cumulative=0.3542
#   'book': P=0.0083, Cumulative=0.3625
#   'tile': P=0.0042, Cumulative=0.3667
#   'bird': P=0.0125, Cumulative=0.3792
#   'stricken': P=0.0042, Cumulative=0.3833
#   'hornyhanded': P=0.0042, Cumulative=0.3875
#   'demand': P=0.0042, Cumulative=0.3917
#   'small': P=0.0042, Cumulative=0.3958
#   'paddle': P=0.0042, Cumulative=0.4000
#   'trapper': P=0.0042, Cumulative=0.4042
#   'soul': P=0.0042, Cumulative=0.4083
#   'windbreak': P=0.0042, Cumulative=0.4125
#   'headshake': P=0.0042, Cumulative=0.4167
#   'strait': P=0.0042, Cumulative=0.4208
#   'ghost': P=0.0042, Cumulative=0.4250
#   'farm': P=0.0167, Cumulative=0.4417
#   'mother': P=0.0042, Cumulative=0.4458
#   'winter': P=0.0125, Cumulative=0.4583
#   'common': P=0.0042, Cumulative=0.4625
#   'table': P=0.0042, Cumulative=0.4667
#   'skeleton': P=0.0042, Cumulative=0.4708
#   'pile': P=0.0042, Cumulative=0.4750
#   'baby': P=0.0042, Cumulative=0.4792
#   'crutch': P=0.0042, Cumulative=0.4833
#   'little': P=0.0208, Cumulative=0.5042
#   'vision': P=0.0042, Cumulative=0.5083
#   'chandelier': P=0.0042, Cumulative=0.5125
#   'moment': P=0.0042, Cumulative=0.5167
#   'tongue': P=0.0042, Cumulative=0.5208
#   'thing': P=0.0042, Cumulative=0.5250
#   'scribble': P=0.0042, Cumulative=0.5292
#   'shutter': P=0.0042, Cumulative=0.5333
#   'grave': P=0.0083, Cumulative=0.5417
#   'mans': P=0.0042, Cumulative=0.5458
#   'lie': P=0.0042, Cumulative=0.5500
#   'single': P=0.0042, Cumulative=0.5542
#   'bough': P=0.0042, Cumulative=0.5583
#   'hill': P=0.0083, Cumulative=0.5667
#   'crystal': P=0.0042, Cumulative=0.5708
#   'brush': P=0.0042, Cumulative=0.5750
#   'crooked': P=0.0042, Cumulative=0.5792
#   'piercing': P=0.0042, Cumulative=0.5833
#   'governor': P=0.0042, Cumulative=0.5875
#   'rockstrewn': P=0.0042, Cumulative=0.5917
#   'byroad': P=0.0042, Cumulative=0.5958
#   'tribe': P=0.0042, Cumulative=0.6000
#   'tent': P=0.0042, Cumulative=0.6042
#   'swish': P=0.0042, Cumulative=0.6083
#   'girl': P=0.0042, Cumulative=0.6125
#   'family': P=0.0042, Cumulative=0.6167
#   'sudden': P=0.0042, Cumulative=0.6208
#   'lane': P=0.0042, Cumulative=0.6250
#   'viola': P=0.0042, Cumulative=0.6292
#   'stark': P=0.0042, Cumulative=0.6333
#   'plain': P=0.0042, Cumulative=0.6375
#   'shattered': P=0.0042, Cumulative=0.6417
#   'brook': P=0.0125, Cumulative=0.6542
#   'member': P=0.0042, Cumulative=0.6583
#   'person': P=0.0042, Cumulative=0.6625
#   'lake': P=0.0042, Cumulative=0.6667
#   'storm': P=0.0042, Cumulative=0.6708
#   'myth': P=0.0042, Cumulative=0.6750
#   'match': P=0.0042, Cumulative=0.6792
#   'hand': P=0.0042, Cumulative=0.6833
#   'bead': P=0.0042, Cumulative=0.6875
#   'wild': P=0.0042, Cumulative=0.6917
#   'purer': P=0.0042, Cumulative=0.6958
#   'picture': P=0.0042, Cumulative=0.7000
#   'screen': P=0.0042, Cumulative=0.7042
#   'name': P=0.0042, Cumulative=0.7083
#   'timber': P=0.0042, Cumulative=0.7125
#   'doorsill': P=0.0042, Cumulative=0.7167
#   'new': P=0.0042, Cumulative=0.7208
#   'time': P=0.0083, Cumulative=0.7292
#   'dite': P=0.0042, Cumulative=0.7333
#   'case': P=0.0042, Cumulative=0.7375
#   'chimney': P=0.0083, Cumulative=0.7458
#   'shelf': P=0.0042, Cumulative=0.7500
#   'pound': P=0.0042, Cumulative=0.7542
#   'fulllength': P=0.0042, Cumulative=0.7583
#   'shelfs': P=0.0042, Cumulative=0.7625
#   'clock': P=0.0042, Cumulative=0.7667
#   'row': P=0.0042, Cumulative=0.7708
#   'violin': P=0.0042, Cumulative=0.7750
#   'glimpse': P=0.0042, Cumulative=0.7792
#   'garden': P=0.0042, Cumulative=0.7833
#   'sunny': P=0.0042, Cumulative=0.7875
#   'passing': P=0.0042, Cumulative=0.7917
#   'tunnel': P=0.0042, Cumulative=0.7958
#   'town': P=0.0083, Cumulative=0.8042
#   'quarry': P=0.0042, Cumulative=0.8083
#   'story': P=0.0042, Cumulative=0.8125
#   'certain': P=0.0042, Cumulative=0.8167
#   'few': P=0.0042, Cumulative=0.8208
#   'cheering': P=0.0042, Cumulative=0.8250
#   'buggy': P=0.0042, Cumulative=0.8292
#   'sign': P=0.0042, Cumulative=0.8333
#   'harness': P=0.0042, Cumulative=0.8375
#   'pine': P=0.0042, Cumulative=0.8417
#   'belilaced': P=0.0042, Cumulative=0.8458
#   'dent': P=0.0042, Cumulative=0.8500
#   'spring': P=0.0042, Cumulative=0.8542
#   'broken': P=0.0042, Cumulative=0.8583
#   'spell': P=0.0042, Cumulative=0.8625
#   'thousand': P=0.0042, Cumulative=0.8667
#   'trillium': P=0.0042, Cumulative=0.8708
#   'piano': P=0.0042, Cumulative=0.8750
#   'digger': P=0.0042, Cumulative=0.8792
#   'smother': P=0.0042, Cumulative=0.8833
#   'note': P=0.0042, Cumulative=0.8875
#   'steeple': P=0.0042, Cumulative=0.8917
#   'beaded': P=0.0042, Cumulative=0.8958
#   'nova': P=0.0042, Cumulative=0.9000
#   'headless': P=0.0042, Cumulative=0.9042
#   'smart': P=0.0042, Cumulative=0.9083
#   'big': P=0.0042, Cumulative=0.9125
#   'long': P=0.0042, Cumulative=0.9167
#   'child': P=0.0042, Cumulative=0.9208
#   'friend': P=0.0042, Cumulative=0.9250
#   'bad': P=0.0042, Cumulative=0.9292
#   'home': P=0.0042, Cumulative=0.9333
#   'show': P=0.0042, Cumulative=0.9375
#   'hen': P=0.0042, Cumulative=0.9417
#   'flock': P=0.0042, Cumulative=0.9458
#   'times': P=0.0042, Cumulative=0.9500
#   'bill': P=0.0042, Cumulative=0.9542
#   'glass': P=0.0083, Cumulative=0.9625
#   'tall': P=0.0042, Cumulative=0.9667
#   'barrel': P=0.0042, Cumulative=0.9708
#   'mess': P=0.0042, Cumulative=0.9750
#   'paradise': P=0.0042, Cumulative=0.9792
#   'dormant': P=0.0042, Cumulative=0.9833
# ...
# Word choices and cumulative probabilities:
#   'two': P=0.0056, Cumulative=0.0056
#   'and': P=0.0898, Cumulative=0.0954
#   'to': P=0.0348, Cumulative=0.1302
#   'then': P=0.0084, Cumulative=0.1386
#   'because': P=0.0007, Cumulative=0.1393
#   'though': P=0.0049, Cumulative=0.1442
#   'had': P=0.0028, Cumulative=0.1469
#   'in': P=0.0202, Cumulative=0.1671
#   'oh': P=0.0028, Cumulative=0.1699
#   'yet': P=0.0021, Cumulative=0.1720
#   'i': P=0.0822, Cumulative=0.2542
#   'somewhere': P=0.0007, Cumulative=0.2549
#   'whose': P=0.0014, Cumulative=0.2563
#   'his': P=0.0049, Cumulative=0.2611
#   'he': P=0.0237, Cumulative=0.2848
#   'my': P=0.0049, Cumulative=0.2897
#   'between': P=0.0021, Cumulative=0.2918
#   'the': P=0.0571, Cumulative=0.3489
#   'of': P=0.0202, Cumulative=0.3691
#   'but': P=0.0355, Cumulative=0.4046
#   'some': P=0.0035, Cumulative=0.4081
#   'from': P=0.0070, Cumulative=0.4150
#   'is': P=0.0035, Cumulative=0.4185
#   'natures': P=0.0007, Cumulative=0.4192
#   'her': P=0.0014, Cumulative=0.4206
#   'so': P=0.0091, Cumulative=0.4297
#   'nothing': P=0.0014, Cumulative=0.4311
#   'when': P=0.0063, Cumulative=0.4373
#   'came': P=0.0007, Cumulative=0.4380
#   'one': P=0.0077, Cumulative=0.4457
#   'proclaimed': P=0.0007, Cumulative=0.4464
#   'smoothlaid': P=0.0007, Cumulative=0.4471
#   'half': P=0.0021, Cumulative=0.4492
#   'up': P=0.0049, Cumulative=0.4540
#   'a': P=0.0209, Cumulative=0.4749
#   'disturbed': P=0.0014, Cumulative=0.4763
#   'comes': P=0.0007, Cumulative=0.4770
#   'by': P=0.0077, Cumulative=0.4847
#   'if': P=0.0084, Cumulative=0.4930
#   'were': P=0.0021, Cumulative=0.4951
#   'ten': P=0.0007, Cumulative=0.4958
#   'as': P=0.0097, Cumulative=0.5056
#   'it': P=0.0160, Cumulative=0.5216
#   'lifted': P=0.0007, Cumulative=0.5223
#   'she': P=0.0118, Cumulative=0.5341
#   'transfixed': P=0.0007, Cumulative=0.5348
#   'across': P=0.0007, Cumulative=0.5355
#   'was': P=0.0063, Cumulative=0.5418
#   'once': P=0.0014, Cumulative=0.5432
#   'that': P=0.0202, Cumulative=0.5634
#   'looked': P=0.0007, Cumulative=0.5641
#   'stood': P=0.0007, Cumulative=0.5648
#   'you': P=0.0279, Cumulative=0.5926
#   'me': P=0.0007, Cumulative=0.5933
#   'sometimes': P=0.0028, Cumulative=0.5961
#   'brown': P=0.0014, Cumulative=0.5975
#   'cross': P=0.0007, Cumulative=0.5982
#   'describing': P=0.0007, Cumulative=0.5989
#   'got': P=0.0007, Cumulative=0.5996
#   'walls': P=0.0007, Cumulative=0.6003
#   'like': P=0.0056, Cumulative=0.6058
#   'upon': P=0.0014, Cumulative=0.6072
#   'with': P=0.0125, Cumulative=0.6198
#   'faster': P=0.0007, Cumulative=0.6205
#   'sitting': P=0.0007, Cumulative=0.6212
#   'according': P=0.0007, Cumulative=0.6219
#   'hes': P=0.0077, Cumulative=0.6295
#   'or': P=0.0077, Cumulative=0.6372
#   'incredulous': P=0.0007, Cumulative=0.6379
#   'wellibe': P=0.0007, Cumulative=0.6386
#   'on': P=0.0077, Cumulative=0.6462
#   'should': P=0.0014, Cumulative=0.6476
#   'yankees': P=0.0007, Cumulative=0.6483
#   'dont': P=0.0049, Cumulative=0.6532
#   'until': P=0.0014, Cumulative=0.6546
#   'after': P=0.0007, Cumulative=0.6553
#   'not': P=0.0091, Cumulative=0.6643
#   'at': P=0.0042, Cumulative=0.6685
#   'no': P=0.0091, Cumulative=0.6776
#   'ive': P=0.0028, Cumulative=0.6804
#   'while': P=0.0007, Cumulative=0.6811
#   'bout': P=0.0007, Cumulative=0.6818
#   'now': P=0.0028, Cumulative=0.6845
#   'im': P=0.0035, Cumulative=0.6880
#   'theyve': P=0.0007, Cumulative=0.6887
#   'flattered': P=0.0007, Cumulative=0.6894
#   'they': P=0.0132, Cumulative=0.7026
#   'always': P=0.0007, Cumulative=0.7033
#   'ill': P=0.0070, Cumulative=0.7103
#   'theyll': P=0.0007, Cumulative=0.7110
#   'for': P=0.0049, Cumulative=0.7159
#   'couldnt': P=0.0014, Cumulative=0.7173
#   'voted': P=0.0007, Cumulative=0.7180
#   'which': P=0.0021, Cumulative=0.7201
#   'their': P=0.0014, Cumulative=0.7214
#   'wentworth': P=0.0007, Cumulative=0.7221
#   'only': P=0.0035, Cumulative=0.7256
#   'rights': P=0.0007, Cumulative=0.7263
#   'has': P=0.0014, Cumulative=0.7277
#   'itd': P=0.0007, Cumulative=0.7284
#   'said': P=0.0007, Cumulative=0.7291
#   'hed': P=0.0035, Cumulative=0.7326
#   'all': P=0.0056, Cumulative=0.7382
#   'gnaws': P=0.0007, Cumulative=0.7389
#   'last': P=0.0007, Cumulative=0.7396
#   'over': P=0.0035, Cumulative=0.7430
#   'well': P=0.0035, Cumulative=0.7465
#   'off': P=0.0014, Cumulative=0.7479
#   'old': P=0.0014, Cumulative=0.7493
#   'thered': P=0.0007, Cumulative=0.7500
#   'someday': P=0.0007, Cumulative=0.7507
#   'today': P=0.0007, Cumulative=0.7514
#   'huh': P=0.0007, Cumulative=0.7521
#   'lets': P=0.0021, Cumulative=0.7542
#   'youve': P=0.0007, Cumulative=0.7549
#   'can': P=0.0007, Cumulative=0.7556
#   'be': P=0.0021, Cumulative=0.7577
#   'we': P=0.0104, Cumulative=0.7681
#   'ascending': P=0.0007, Cumulative=0.7688
#   'sos': P=0.0014, Cumulative=0.7702
#   'hadnt': P=0.0007, Cumulative=0.7709
#   'look': P=0.0007, Cumulative=0.7716
#   'what': P=0.0097, Cumulative=0.7813
#   'however': P=0.0014, Cumulative=0.7827
#   'come': P=0.0028, Cumulative=0.7855
#   'its': P=0.0146, Cumulative=0.8001
#   'perhaps': P=0.0014, Cumulative=0.8015
#   'excuse': P=0.0007, Cumulative=0.8022
#   'who': P=0.0042, Cumulative=0.8064
#   'life': P=0.0007, Cumulative=0.8071
#   'our': P=0.0014, Cumulative=0.8085
#   'through': P=0.0014, Cumulative=0.8099
#   'except': P=0.0014, Cumulative=0.8113
#   'books': P=0.0014, Cumulative=0.8127
#   'where': P=0.0056, Cumulative=0.8182
#   'enough': P=0.0007, Cumulative=0.8189
#   'unfortunately': P=0.0007, Cumulative=0.8196
#   'boys': P=0.0007, Cumulative=0.8203
#   'shatter': P=0.0007, Cumulative=0.8210
#   'how': P=0.0042, Cumulative=0.8252
#   'till': P=0.0014, Cumulative=0.8266
#   'tried': P=0.0007, Cumulative=0.8273
#   'having': P=0.0007, Cumulative=0.8280
#   'here': P=0.0028, Cumulative=0.8308
#   'take': P=0.0021, Cumulative=0.8329
#   'why': P=0.0021, Cumulative=0.8350
#   'goodlooking': P=0.0007, Cumulative=0.8357
#   'both': P=0.0007, Cumulative=0.8364
#   'legitimately': P=0.0007, Cumulative=0.8370
#   'there': P=0.0042, Cumulative=0.8412
#   'crosslegged': P=0.0007, Cumulative=0.8419
#   'alias': P=0.0007, Cumulative=0.8426
#   'about': P=0.0007, Cumulative=0.8433
#   'theres': P=0.0007, Cumulative=0.8440
#   'give': P=0.0007, Cumulative=0.8447
#   'thrown': P=0.0007, Cumulative=0.8454
#   'unless': P=0.0007, Cumulative=0.8461
#   'than': P=0.0014, Cumulative=0.8475
#   'behind': P=0.0014, Cumulative=0.8489
#   'mother': P=0.0049, Cumulative=0.8538
#   'summoning': P=0.0007, Cumulative=0.8545
#   'whos': P=0.0007, Cumulative=0.8552
#   'son': P=0.0063, Cumulative=0.8614
#   'done': P=0.0007, Cumulative=0.8621
#   'rather': P=0.0007, Cumulative=0.8628
#   'tell': P=0.0014, Cumulative=0.8642
#   'yes': P=0.0056, Cumulative=0.8698
#   'against': P=0.0007, Cumulative=0.8705
#   'halting': P=0.0007, Cumulative=0.8712
#   'never': P=0.0007, Cumulative=0.8719
#   'another': P=0.0014, Cumulative=0.8733
#   'right': P=0.0007, Cumulative=0.8740
#   'father': P=0.0007, Cumulative=0.8747
#   'especially': P=0.0007, Cumulative=0.8753
#   'might': P=0.0007, Cumulative=0.8760
#   'toffile': P=0.0035, Cumulative=0.8795
#   'struck': P=0.0007, Cumulative=0.8802
#   'began': P=0.0007, Cumulative=0.8809
#   'waiting': P=0.0007, Cumulative=0.8816
#   'flashed': P=0.0007, Cumulative=0.8823
#   'smoke': P=0.0007, Cumulative=0.8830
#   'hand': P=0.0007, Cumulative=0.8837
#   'stillgoing': P=0.0007, Cumulative=0.8844
#   'before': P=0.0014, Cumulative=0.8858
#   'almost': P=0.0007, Cumulative=0.8865
#   'quick': P=0.0007, Cumulative=0.8872
#   'let': P=0.0014, Cumulative=0.8886
#   'brushing': P=0.0007, Cumulative=0.8893
#   'thats': P=0.0035, Cumulative=0.8928
#   'o': P=0.0007, Cumulative=0.8935
#   'wed': P=0.0007, Cumulative=0.8942
#   'could': P=0.0007, Cumulative=0.8948
#   'among': P=0.0021, Cumulative=0.8969
#   'ancestral': P=0.0007, Cumulative=0.8976
#   'someone': P=0.0007, Cumulative=0.8983
#   'thence': P=0.0007, Cumulative=0.8990
#   'made': P=0.0007, Cumulative=0.8997
#   'are': P=0.0007, Cumulative=0.9004
#   'strolled': P=0.0007, Cumulative=0.9011
#   'anyone': P=0.0014, Cumulative=0.9025
#   'this': P=0.0042, Cumulative=0.9067
#   'provision': P=0.0007, Cumulative=0.9074
#   'drawn': P=0.0014, Cumulative=0.9088
#   'stark': P=0.0007, Cumulative=0.9095
#   'would': P=0.0014, Cumulative=0.9109
#   'several': P=0.0007, Cumulative=0.9116
#   'under': P=0.0014, Cumulative=0.9130
#   'just': P=0.0007, Cumulative=0.9136
#   'does': P=0.0014, Cumulative=0.9150
#   'bowed': P=0.0007, Cumulative=0.9157
#   'beyond': P=0.0014, Cumulative=0.9171
#   'four': P=0.0007, Cumulative=0.9178
#   'dyou': P=0.0007, Cumulative=0.9185
#   'studying': P=0.0007, Cumulative=0.9192
#   'first': P=0.0014, Cumulative=0.9206
#   'bless': P=0.0014, Cumulative=0.9220
#   'shes': P=0.0021, Cumulative=0.9241
#   'heres': P=0.0007, Cumulative=0.9248
#   'making': P=0.0007, Cumulative=0.9255
#   'see': P=0.0007, Cumulative=0.9262
#   'strung': P=0.0007, Cumulative=0.9269
#   'something': P=0.0014, Cumulative=0.9283
#   'speaking': P=0.0007, Cumulative=0.9290
#   'strangely': P=0.0007, Cumulative=0.9297
#   'call': P=0.0014, Cumulative=0.9311
#   'nor': P=0.0028, Cumulative=0.9338
#   'nine': P=0.0007, Cumulative=0.9345
#   'anything': P=0.0007, Cumulative=0.9352
#   'folks': P=0.0007, Cumulative=0.9359
#   'mebbe': P=0.0007, Cumulative=0.9366
#   'more': P=0.0007, Cumulative=0.9373
#   'will': P=0.0014, Cumulative=0.9387
#   'nowhere': P=0.0007, Cumulative=0.9394
#   'builder': P=0.0007, Cumulative=0.9401
#   'whatever': P=0.0007, Cumulative=0.9408
#   'inscription': P=0.0007, Cumulative=0.9415
#   'winds': P=0.0007, Cumulative=0.9422
#   'moisture': P=0.0007, Cumulative=0.9429
#   'heaven': P=0.0007, Cumulative=0.9436
#   'back': P=0.0014, Cumulative=0.9450
#   'may': P=0.0007, Cumulative=0.9457
#   'great': P=0.0007, Cumulative=0.9464
#   'long': P=0.0007, Cumulative=0.9471
#   'besides': P=0.0007, Cumulative=0.9478
#   'still': P=0.0014, Cumulative=0.9492
#   'charge': P=0.0007, Cumulative=0.9499
#   'make': P=0.0014, Cumulative=0.9513
#   'someones': P=0.0007, Cumulative=0.9519
#   'into': P=0.0007, Cumulative=0.9526
#   'weep': P=0.0007, Cumulative=0.9533
#   'your': P=0.0007, Cumulative=0.9540
#   'cold': P=0.0007, Cumulative=0.9547
#   'too': P=0.0014, Cumulative=0.9561
#   'drink': P=0.0007, Cumulative=0.9568
#   'wherever': P=0.0007, Cumulative=0.9575
#   'birch': P=0.0007, Cumulative=0.9582
#   'time': P=0.0007, Cumulative=0.9589
#   'small': P=0.0007, Cumulative=0.9596
#   'out': P=0.0007, Cumulative=0.9603
#   'awake': P=0.0007, Cumulative=0.9610
#   'wishing': P=0.0007, Cumulative=0.9617
#   'saturn': P=0.0007, Cumulative=0.9624
#   'speculation': P=0.0007, Cumulative=0.9631
#   'theirs': P=0.0007, Cumulative=0.9638
#   'uttered': P=0.0007, Cumulative=0.9645
#   'trembled': P=0.0007, Cumulative=0.9652
#   'appear': P=0.0007, Cumulative=0.9659
#   'around': P=0.0007, Cumulative=0.9666
#   'since': P=0.0007, Cumulative=0.9673
#   'lord': P=0.0007, Cumulative=0.9680
#   'havent': P=0.0014, Cumulative=0.9694
#   'whats': P=0.0028, Cumulative=0.9721
#   'estelles': P=0.0014, Cumulative=0.9735
#   'weve': P=0.0007, Cumulative=0.9742
#   'left': P=0.0007, Cumulative=0.9749
#   'hell': P=0.0007, Cumulative=0.9756
#   'skyhigh': P=0.0007, Cumulative=0.9763
#   'arent': P=0.0007, Cumulative=0.9770
#   'john': P=0.0042, Cumulative=0.9812
#   'better': P=0.0007, Cumulative=0.9819
#   'reason': P=0.0007, Cumulative=0.9826
#   'such': P=0.0007, Cumulative=0.9833
#   'twas': P=0.0007, Cumulative=0.9840
#   'johns': P=0.0014, Cumulative=0.9854
#   'estelle': P=0.0007, Cumulative=0.9861
#   'farmers': P=0.0007, Cumulative=0.9868
#   'full': P=0.0007, Cumulative=0.9875
#   'moving': P=0.0007, Cumulative=0.9882
#   'nothings': P=0.0007, Cumulative=0.9889
#   'twenty': P=0.0007, Cumulative=0.9896
#   'receipted': P=0.0007, Cumulative=0.9903
#   'wampum': P=0.0007, Cumulative=0.9909
#   'cant': P=0.0007, Cumulative=0.9916
#   'being': P=0.0007, Cumulative=0.9923
#   'oho': P=0.0007, Cumulative=0.9930
#   'bad': P=0.0007, Cumulative=0.9937
#   'nonsense': P=0.0007, Cumulative=0.9944
#   'whod': P=0.0007, Cumulative=0.9951
#   'say': P=0.0007, Cumulative=0.9958
#   'youll': P=0.0007, Cumulative=0.9965
#   'coming': P=0.0007, Cumulative=0.9972
#   'isnt': P=0.0007, Cumulative=0.9979
#   'do': P=0.0007, Cumulative=0.9986
#   'content': P=0.0007, Cumulative=0.9993
#   'an': P=0.0007, Cumulative=1.0000
#
# Random number generated: 0.2792
# Selected: 'he' (falls in range [0, 0.2848])
#
# Step 2: Selecting second word using first-order transitions
# ----------------------------------------------------------------------
# After 'he', possible words:
#   'will': P=0.0174, Cumulative=0.0174
#   'gives': P=0.0087, Cumulative=0.0261
#   'had': P=0.0435, Cumulative=0.0696
#   'did': P=0.0174, Cumulative=0.0870
#   'was': P=0.0609, Cumulative=0.1478
#   'saw': P=0.0087, Cumulative=0.1565
#   'stove': P=0.0087, Cumulative=0.1652
#   'strove': P=0.0087, Cumulative=0.1739
#   'gained': P=0.0087, Cumulative=0.1826
#   'came': P=0.0174, Cumulative=0.2000
#   'chanced': P=0.0087, Cumulative=0.2087
#   'chose': P=0.0087, Cumulative=0.2174
#   'feared': P=0.0087, Cumulative=0.2261
#   'never': P=0.0261, Cumulative=0.2522
#   'described': P=0.0087, Cumulative=0.2609
#   'reeled': P=0.0087, Cumulative=0.2696
#   'lurched': P=0.0087, Cumulative=0.2783
#   'bobbed': P=0.0087, Cumulative=0.2870
#   'checked': P=0.0087, Cumulative=0.2957
#   'fell': P=0.0087, Cumulative=0.3043
#   'fought': P=0.0087, Cumulative=0.3130
#   'gave': P=0.0087, Cumulative=0.3217
#   'said': P=0.0609, Cumulative=0.3826
#   'looked': P=0.0087, Cumulative=0.3913
#   'couldnt': P=0.0087, Cumulative=0.4000
#   'bowed': P=0.0087, Cumulative=0.4087
#   'steered': P=0.0087, Cumulative=0.4174
#   'snapped': P=0.0087, Cumulative=0.4261
#   'want': P=0.0087, Cumulative=0.4348
#   'ever': P=0.0174, Cumulative=0.4522
#   'stood': P=0.0174, Cumulative=0.4696
#   'whined': P=0.0087, Cumulative=0.4783
#   'slept': P=0.0087, Cumulative=0.4870
#   'hadnt': P=0.0087, Cumulative=0.4957
#   'dont': P=0.0087, Cumulative=0.5043
#   'started': P=0.0087, Cumulative=0.5130
#   'found': P=0.0087, Cumulative=0.5217
#   'got': P=0.0174, Cumulative=0.5391
#   'liked': P=0.0174, Cumulative=0.5565
#   'guessed': P=0.0087, Cumulative=0.5652
#   'is': P=0.0348, Cumulative=0.6000
#   'sees': P=0.0087, Cumulative=0.6087
#   'cant': P=0.0261, Cumulative=0.6348
#   'picked': P=0.0087, Cumulative=0.6435
#   'read': P=0.0087, Cumulative=0.6522
#   'doesnt': P=0.0261, Cumulative=0.6783
#   'broke': P=0.0087, Cumulative=0.6870
#   'always': P=0.0087, Cumulative=0.6957
#   'killed': P=0.0087, Cumulative=0.7043
#   'were': P=0.0087, Cumulative=0.7130
#   'would': P=0.0087, Cumulative=0.7217
#   'nodded': P=0.0087, Cumulative=0.7304
#   'inquired': P=0.0087, Cumulative=0.7391
#   'drew': P=0.0087, Cumulative=0.7478
#   'sat': P=0.0087, Cumulative=0.7565
#   'thinks': P=0.0174, Cumulative=0.7739
#   'must': P=0.0174, Cumulative=0.7913
#   'wont': P=0.0174, Cumulative=0.8087
#   'do': P=0.0174, Cumulative=0.8261
#   'gets': P=0.0261, Cumulative=0.8522
#   'and': P=0.0087, Cumulative=0.8609
#   'could': P=0.0087, Cumulative=0.8696
#   'hoed': P=0.0087, Cumulative=0.8783
#   'knows': P=0.0174, Cumulative=0.8957
#   'has': P=0.0261, Cumulative=0.9217
#   'should': P=0.0087, Cumulative=0.9304
#   'us': P=0.0087, Cumulative=0.9391
#   'wouldnt': P=0.0087, Cumulative=0.9478
#   'manages': P=0.0087, Cumulative=0.9565
#   'can': P=0.0174, Cumulative=0.9739
#   'be': P=0.0087, Cumulative=0.9826
#   'looks': P=0.0087, Cumulative=0.9913
#   'didnt': P=0.0087, Cumulative=1.0000
#
# Random number generated: 0.4519
# Selected: 'ever'
#
# Step 3: Selecting subsequent words using second-order transitions
# ----------------------------------------------------------------------
#
# Selecting word 3 after ('he', 'ever'):
#   'voted': P=0.5000, Cumulative=0.5000
#   'cared': P=0.5000, Cumulative=1.0000
# Random number: 0.0571
# Selected: 'voted'
#
# Selecting word 4 after ('ever', 'voted'):
#   'END': P=1.0000, Cumulative=1.0000
# Random number: 0.1191
# Selected: 'END'
#
# END token reached. Line complete.
#
# >>> Generated Line 5: he ever voted
#
# ======================================================================
# GENERATED POEM (METHOD A - CUMULATIVE PROBABILITY):
# ======================================================================
# the poetess had sighed i knew there must be something
# a stricken bird
# but he didnt enter
# how men will be likely to regard as sacred
# he ever voted
# ======================================================================

# %% [markdown]
# ## Step 6: Poetry Generation - Method B (Deterministic)
# Using highest probability selection

# %%
print("METHOD B: DETERMINISTIC (Highest Probability)")

generated_poem_b = []

for line_num in range(5):
    print(f"\n{'='*70}")
    print(f"GENERATING LINE {line_num + 1}")
    print(f"{'='*70}")
    
    generated_words = []
    
    # Step 1: Select first word with highest probability
    print("\nStep 1: Selecting first word with highest initial probability")
    print("-" * 70)
    
    # Display all options
    print("Word choices and probabilities:")
    for word, prob in sorted(initial_word_prob.items(), key=lambda x: x[1], reverse=True):
        print(f"  '{word}': P={prob:.4f} ({prob*100:.2f}%)")
    
    # Select word with max probability
    first_word = max(initial_word_prob.items(), key=lambda x: x[1])[0]
    print(f"\nSelected: '{first_word}' (highest probability: {initial_word_prob[first_word]:.4f})")
    generated_words.append(first_word)
    
    # Step 2: Select second word with highest probability
    print("\nStep 2: Selecting second word with highest first-order probability")
    print("-" * 70)
    
    if first_word in first_order_prob:
        print(f"After '{first_word}', possible words:")
        for word, prob in sorted(first_order_prob[first_word].items(), key=lambda x: x[1], reverse=True):
            print(f"  '{word}': P={prob:.4f} ({prob*100:.2f}%)")
        
        second_word = max(first_order_prob[first_word].items(), key=lambda x: x[1])[0]
        print(f"\nSelected: '{second_word}' (highest probability: {first_order_prob[first_word][second_word]:.4f})")
        
        if second_word == 'END':
            print("\nEND token reached. Line complete.")
        else:
            generated_words.append(second_word)
    
    # Step 3: Select subsequent words with highest probabilities
    if len(generated_words) >= 2 and generated_words[-1] != 'END':
        print("\nStep 3: Selecting subsequent words with highest second-order probabilities")
        print("-" * 70)
        
        word_count = 3
        while True:
            pair = (generated_words[-2], generated_words[-1])
            
            if pair in second_order_prob:
                print(f"\nSelecting word {word_count} after ('{pair[0]}', '{pair[1]}'):")
                
                for word, prob in sorted(second_order_prob[pair].items(), key=lambda x: x[1], reverse=True):
                    print(f"  '{word}': P={prob:.4f} ({prob*100:.2f}%)")
                
                next_word = max(second_order_prob[pair].items(), key=lambda x: x[1])[0]
                print(f"Selected: '{next_word}' (highest probability: {second_order_prob[pair][next_word]:.4f})")
                
                if next_word == 'END':
                    print("\nEND token reached. Line complete.")
                    break
                else:
                    generated_words.append(next_word)
                    word_count += 1
            else:
                print(f"\nNo transitions found for ('{pair[0]}', '{pair[1]}'). Ending line.")
                break
    
    # Store the generated line
    line_text = ' '.join(generated_words)
    generated_poem_b.append(line_text)
    print(f"\n>>> Generated Line {line_num + 1}: {line_text}")

# Display the complete poem
print("\n" + "="*70)
print("GENERATED POEM (METHOD B - DETERMINISTIC):")
print("="*70)
for line in generated_poem_b:
    print(line)
print("="*70)
# Out:
# METHOD B: DETERMINISTIC (Highest Probability)
#
# ======================================================================
# GENERATING LINE 1
# ======================================================================
#
# Step 1: Selecting first word with highest initial probability
# ----------------------------------------------------------------------
# Word choices and probabilities:
#   'and': P=0.0898 (8.98%)
#   'i': P=0.0822 (8.22%)
#   'the': P=0.0571 (5.71%)
#   'but': P=0.0355 (3.55%)
#   'to': P=0.0348 (3.48%)
#   'you': P=0.0279 (2.79%)
#   'he': P=0.0237 (2.37%)
#   'a': P=0.0209 (2.09%)
#   'in': P=0.0202 (2.02%)
#   'of': P=0.0202 (2.02%)
#   'that': P=0.0202 (2.02%)
#   'it': P=0.0160 (1.60%)
#   'its': P=0.0146 (1.46%)
#   'they': P=0.0132 (1.32%)
#   'with': P=0.0125 (1.25%)
#   'she': P=0.0118 (1.18%)
#   'we': P=0.0104 (1.04%)
#   'as': P=0.0097 (0.97%)
#   'what': P=0.0097 (0.97%)
#   'so': P=0.0091 (0.91%)
#   'not': P=0.0091 (0.91%)
#   'no': P=0.0091 (0.91%)
#   'then': P=0.0084 (0.84%)
#   'if': P=0.0084 (0.84%)
#   'one': P=0.0077 (0.77%)
#   'by': P=0.0077 (0.77%)
#   'hes': P=0.0077 (0.77%)
#   'or': P=0.0077 (0.77%)
#   'on': P=0.0077 (0.77%)
#   'from': P=0.0070 (0.70%)
#   'ill': P=0.0070 (0.70%)
#   'when': P=0.0063 (0.63%)
#   'was': P=0.0063 (0.63%)
#   'son': P=0.0063 (0.63%)
#   'two': P=0.0056 (0.56%)
#   'like': P=0.0056 (0.56%)
#   'all': P=0.0056 (0.56%)
#   'where': P=0.0056 (0.56%)
#   'yes': P=0.0056 (0.56%)
#   'though': P=0.0049 (0.49%)
#   'his': P=0.0049 (0.49%)
#   'my': P=0.0049 (0.49%)
#   'up': P=0.0049 (0.49%)
#   'dont': P=0.0049 (0.49%)
#   'for': P=0.0049 (0.49%)
#   'mother': P=0.0049 (0.49%)
#   'at': P=0.0042 (0.42%)
#   'who': P=0.0042 (0.42%)
#   'how': P=0.0042 (0.42%)
#   'there': P=0.0042 (0.42%)
#   'this': P=0.0042 (0.42%)
#   'john': P=0.0042 (0.42%)
#   'some': P=0.0035 (0.35%)
#   'is': P=0.0035 (0.35%)
#   'im': P=0.0035 (0.35%)
#   'only': P=0.0035 (0.35%)
#   'hed': P=0.0035 (0.35%)
#   'over': P=0.0035 (0.35%)
#   'well': P=0.0035 (0.35%)
#   'toffile': P=0.0035 (0.35%)
#   'thats': P=0.0035 (0.35%)
#   'had': P=0.0028 (0.28%)
#   'oh': P=0.0028 (0.28%)
#   'sometimes': P=0.0028 (0.28%)
#   'ive': P=0.0028 (0.28%)
#   'now': P=0.0028 (0.28%)
#   'come': P=0.0028 (0.28%)
#   'here': P=0.0028 (0.28%)
#   'nor': P=0.0028 (0.28%)
#   'whats': P=0.0028 (0.28%)
#   'yet': P=0.0021 (0.21%)
#   'between': P=0.0021 (0.21%)
#   'half': P=0.0021 (0.21%)
#   'were': P=0.0021 (0.21%)
#   'which': P=0.0021 (0.21%)
#   'lets': P=0.0021 (0.21%)
#   'be': P=0.0021 (0.21%)
#   'take': P=0.0021 (0.21%)
#   'why': P=0.0021 (0.21%)
#   'among': P=0.0021 (0.21%)
#   'shes': P=0.0021 (0.21%)
#   'whose': P=0.0014 (0.14%)
#   'her': P=0.0014 (0.14%)
#   'nothing': P=0.0014 (0.14%)
#   'disturbed': P=0.0014 (0.14%)
#   'once': P=0.0014 (0.14%)
#   'brown': P=0.0014 (0.14%)
#   'upon': P=0.0014 (0.14%)
#   'should': P=0.0014 (0.14%)
#   'until': P=0.0014 (0.14%)
#   'couldnt': P=0.0014 (0.14%)
#   'their': P=0.0014 (0.14%)
#   'has': P=0.0014 (0.14%)
#   'off': P=0.0014 (0.14%)
#   'old': P=0.0014 (0.14%)
#   'sos': P=0.0014 (0.14%)
#   'however': P=0.0014 (0.14%)
#   'perhaps': P=0.0014 (0.14%)
#   'our': P=0.0014 (0.14%)
#   'through': P=0.0014 (0.14%)
#   'except': P=0.0014 (0.14%)
#   'books': P=0.0014 (0.14%)
#   'till': P=0.0014 (0.14%)
#   'than': P=0.0014 (0.14%)
#   'behind': P=0.0014 (0.14%)
#   'tell': P=0.0014 (0.14%)
#   'another': P=0.0014 (0.14%)
#   'before': P=0.0014 (0.14%)
#   'let': P=0.0014 (0.14%)
#   'anyone': P=0.0014 (0.14%)
#   'drawn': P=0.0014 (0.14%)
#   'would': P=0.0014 (0.14%)
#   'under': P=0.0014 (0.14%)
#   'does': P=0.0014 (0.14%)
#   'beyond': P=0.0014 (0.14%)
#   'first': P=0.0014 (0.14%)
#   'bless': P=0.0014 (0.14%)
#   'something': P=0.0014 (0.14%)
#   'call': P=0.0014 (0.14%)
#   'will': P=0.0014 (0.14%)
#   'back': P=0.0014 (0.14%)
#   'still': P=0.0014 (0.14%)
#   'make': P=0.0014 (0.14%)
#   'too': P=0.0014 (0.14%)
#   'havent': P=0.0014 (0.14%)
#   'estelles': P=0.0014 (0.14%)
#   'johns': P=0.0014 (0.14%)
#   'because': P=0.0007 (0.07%)
#   'somewhere': P=0.0007 (0.07%)
#   'natures': P=0.0007 (0.07%)
#   'came': P=0.0007 (0.07%)
#   'proclaimed': P=0.0007 (0.07%)
#   'smoothlaid': P=0.0007 (0.07%)
#   'comes': P=0.0007 (0.07%)
#   'ten': P=0.0007 (0.07%)
#   'lifted': P=0.0007 (0.07%)
#   'transfixed': P=0.0007 (0.07%)
#   'across': P=0.0007 (0.07%)
#   'looked': P=0.0007 (0.07%)
#   'stood': P=0.0007 (0.07%)
#   'me': P=0.0007 (0.07%)
#   'cross': P=0.0007 (0.07%)
#   'describing': P=0.0007 (0.07%)
#   'got': P=0.0007 (0.07%)
#   'walls': P=0.0007 (0.07%)
#   'faster': P=0.0007 (0.07%)
#   'sitting': P=0.0007 (0.07%)
#   'according': P=0.0007 (0.07%)
#   'incredulous': P=0.0007 (0.07%)
#   'wellibe': P=0.0007 (0.07%)
#   'yankees': P=0.0007 (0.07%)
#   'after': P=0.0007 (0.07%)
#   'while': P=0.0007 (0.07%)
#   'bout': P=0.0007 (0.07%)
#   'theyve': P=0.0007 (0.07%)
#   'flattered': P=0.0007 (0.07%)
#   'always': P=0.0007 (0.07%)
#   'theyll': P=0.0007 (0.07%)
#   'voted': P=0.0007 (0.07%)
#   'wentworth': P=0.0007 (0.07%)
#   'rights': P=0.0007 (0.07%)
#   'itd': P=0.0007 (0.07%)
#   'said': P=0.0007 (0.07%)
#   'gnaws': P=0.0007 (0.07%)
#   'last': P=0.0007 (0.07%)
#   'thered': P=0.0007 (0.07%)
#   'someday': P=0.0007 (0.07%)
#   'today': P=0.0007 (0.07%)
#   'huh': P=0.0007 (0.07%)
#   'youve': P=0.0007 (0.07%)
#   'can': P=0.0007 (0.07%)
#   'ascending': P=0.0007 (0.07%)
#   'hadnt': P=0.0007 (0.07%)
#   'look': P=0.0007 (0.07%)
#   'excuse': P=0.0007 (0.07%)
#   'life': P=0.0007 (0.07%)
#   'enough': P=0.0007 (0.07%)
#   'unfortunately': P=0.0007 (0.07%)
#   'boys': P=0.0007 (0.07%)
#   'shatter': P=0.0007 (0.07%)
#   'tried': P=0.0007 (0.07%)
#   'having': P=0.0007 (0.07%)
#   'goodlooking': P=0.0007 (0.07%)
#   'both': P=0.0007 (0.07%)
#   'legitimately': P=0.0007 (0.07%)
#   'crosslegged': P=0.0007 (0.07%)
#   'alias': P=0.0007 (0.07%)
#   'about': P=0.0007 (0.07%)
#   'theres': P=0.0007 (0.07%)
#   'give': P=0.0007 (0.07%)
#   'thrown': P=0.0007 (0.07%)
#   'unless': P=0.0007 (0.07%)
#   'summoning': P=0.0007 (0.07%)
#   'whos': P=0.0007 (0.07%)
#   'done': P=0.0007 (0.07%)
#   'rather': P=0.0007 (0.07%)
#   'against': P=0.0007 (0.07%)
#   'halting': P=0.0007 (0.07%)
#   'never': P=0.0007 (0.07%)
#   'right': P=0.0007 (0.07%)
#   'father': P=0.0007 (0.07%)
#   'especially': P=0.0007 (0.07%)
#   'might': P=0.0007 (0.07%)
#   'struck': P=0.0007 (0.07%)
#   'began': P=0.0007 (0.07%)
#   'waiting': P=0.0007 (0.07%)
#   'flashed': P=0.0007 (0.07%)
#   'smoke': P=0.0007 (0.07%)
#   'hand': P=0.0007 (0.07%)
#   'stillgoing': P=0.0007 (0.07%)
#   'almost': P=0.0007 (0.07%)
#   'quick': P=0.0007 (0.07%)
#   'brushing': P=0.0007 (0.07%)
#   'o': P=0.0007 (0.07%)
#   'wed': P=0.0007 (0.07%)
#   'could': P=0.0007 (0.07%)
#   'ancestral': P=0.0007 (0.07%)
#   'someone': P=0.0007 (0.07%)
#   'thence': P=0.0007 (0.07%)
#   'made': P=0.0007 (0.07%)
#   'are': P=0.0007 (0.07%)
#   'strolled': P=0.0007 (0.07%)
#   'provision': P=0.0007 (0.07%)
#   'stark': P=0.0007 (0.07%)
#   'several': P=0.0007 (0.07%)
#   'just': P=0.0007 (0.07%)
#   'bowed': P=0.0007 (0.07%)
#   'four': P=0.0007 (0.07%)
#   'dyou': P=0.0007 (0.07%)
#   'studying': P=0.0007 (0.07%)
#   'heres': P=0.0007 (0.07%)
#   'making': P=0.0007 (0.07%)
#   'see': P=0.0007 (0.07%)
#   'strung': P=0.0007 (0.07%)
#   'speaking': P=0.0007 (0.07%)
#   'strangely': P=0.0007 (0.07%)
#   'nine': P=0.0007 (0.07%)
#   'anything': P=0.0007 (0.07%)
#   'folks': P=0.0007 (0.07%)
#   'mebbe': P=0.0007 (0.07%)
#   'more': P=0.0007 (0.07%)
#   'nowhere': P=0.0007 (0.07%)
#   'builder': P=0.0007 (0.07%)
#   'whatever': P=0.0007 (0.07%)
#   'inscription': P=0.0007 (0.07%)
#   'winds': P=0.0007 (0.07%)
#   'moisture': P=0.0007 (0.07%)
#   'heaven': P=0.0007 (0.07%)
#   'may': P=0.0007 (0.07%)
#   'great': P=0.0007 (0.07%)
#   'long': P=0.0007 (0.07%)
#   'besides': P=0.0007 (0.07%)
#   'charge': P=0.0007 (0.07%)
#   'someones': P=0.0007 (0.07%)
#   'into': P=0.0007 (0.07%)
#   'weep': P=0.0007 (0.07%)
#   'your': P=0.0007 (0.07%)
#   'cold': P=0.0007 (0.07%)
#   'drink': P=0.0007 (0.07%)
#   'wherever': P=0.0007 (0.07%)
#   'birch': P=0.0007 (0.07%)
#   'time': P=0.0007 (0.07%)
#   'small': P=0.0007 (0.07%)
#   'out': P=0.0007 (0.07%)
#   'awake': P=0.0007 (0.07%)
#   'wishing': P=0.0007 (0.07%)
#   'saturn': P=0.0007 (0.07%)
#   'speculation': P=0.0007 (0.07%)
#   'theirs': P=0.0007 (0.07%)
#   'uttered': P=0.0007 (0.07%)
#   'trembled': P=0.0007 (0.07%)
#   'appear': P=0.0007 (0.07%)
#   'around': P=0.0007 (0.07%)
#   'since': P=0.0007 (0.07%)
#   'lord': P=0.0007 (0.07%)
#   'weve': P=0.0007 (0.07%)
#   'left': P=0.0007 (0.07%)
#   'hell': P=0.0007 (0.07%)
#   'skyhigh': P=0.0007 (0.07%)
#   'arent': P=0.0007 (0.07%)
#   'better': P=0.0007 (0.07%)
#   'reason': P=0.0007 (0.07%)
#   'such': P=0.0007 (0.07%)
#   'twas': P=0.0007 (0.07%)
#   'estelle': P=0.0007 (0.07%)
#   'farmers': P=0.0007 (0.07%)
#   'full': P=0.0007 (0.07%)
#   'moving': P=0.0007 (0.07%)
#   'nothings': P=0.0007 (0.07%)
#   'twenty': P=0.0007 (0.07%)
#   'receipted': P=0.0007 (0.07%)
#   'wampum': P=0.0007 (0.07%)
#   'cant': P=0.0007 (0.07%)
#   'being': P=0.0007 (0.07%)
#   'oho': P=0.0007 (0.07%)
#   'bad': P=0.0007 (0.07%)
#   'nonsense': P=0.0007 (0.07%)
#   'whod': P=0.0007 (0.07%)
#   'say': P=0.0007 (0.07%)
#   'youll': P=0.0007 (0.07%)
#   'coming': P=0.0007 (0.07%)
#   'isnt': P=0.0007 (0.07%)
#   'do': P=0.0007 (0.07%)
#   'content': P=0.0007 (0.07%)
#   'an': P=0.0007 (0.07%)
#
# Selected: 'and' (highest probability: 0.0898)
#
# Step 2: Selecting second word with highest first-order probability
# ----------------------------------------------------------------------
# After 'and', possible words:
#   'i': P=0.0410 (4.10%)
#   'the': P=0.0410 (4.10%)
#   'then': P=0.0239 (2.39%)
#   'tell': P=0.0137 (1.37%)
#   'see': P=0.0137 (1.37%)
#   'when': P=0.0102 (1.02%)
#   'how': P=0.0102 (1.02%)
#   'hold': P=0.0102 (1.02%)
#   'swollen': P=0.0102 (1.02%)
#   'a': P=0.0102 (1.02%)
#   'all': P=0.0102 (1.02%)
#   'in': P=0.0102 (1.02%)
#   'sorry': P=0.0068 (0.68%)
#   'be': P=0.0068 (0.68%)
#   'both': P=0.0068 (0.68%)
#   'that': P=0.0068 (0.68%)
#   'miles': P=0.0068 (0.68%)
#   'now': P=0.0068 (0.68%)
#   'put': P=0.0068 (0.68%)
#   'since': P=0.0068 (0.68%)
#   'there': P=0.0068 (0.68%)
#   'he': P=0.0068 (0.68%)
#   'this': P=0.0068 (0.68%)
#   'if': P=0.0068 (0.68%)
#   'had': P=0.0068 (0.68%)
#   'make': P=0.0068 (0.68%)
#   'kick': P=0.0068 (0.68%)
#   'thats': P=0.0068 (0.68%)
#   'spoke': P=0.0068 (0.68%)
#   'save': P=0.0068 (0.68%)
#   'left': P=0.0068 (0.68%)
#   'his': P=0.0068 (0.68%)
#   'headboard': P=0.0068 (0.68%)
#   'buried': P=0.0068 (0.68%)
#   'shouted': P=0.0068 (0.68%)
#   'sit': P=0.0068 (0.68%)
#   'take': P=0.0068 (0.68%)
#   'lift': P=0.0068 (0.68%)
#   'those': P=0.0068 (0.68%)
#   'perhaps': P=0.0068 (0.68%)
#   'still': P=0.0068 (0.68%)
#   'your': P=0.0068 (0.68%)
#   'besides': P=0.0068 (0.68%)
#   'we': P=0.0068 (0.68%)
#   'looked': P=0.0034 (0.34%)
#   'having': P=0.0034 (0.34%)
#   'wanted': P=0.0034 (0.34%)
#   'ages': P=0.0034 (0.34%)
#   'frozen': P=0.0034 (0.34%)
#   'downy': P=0.0034 (0.34%)
#   'deep': P=0.0034 (0.34%)
#   'would': P=0.0034 (0.34%)
#   'back': P=0.0034 (0.34%)
#   'dropped': P=0.0034 (0.34%)
#   'stopped': P=0.0034 (0.34%)
#   'further': P=0.0034 (0.34%)
#   'caught': P=0.0034 (0.34%)
#   'threw': P=0.0034 (0.34%)
#   'wetkneed': P=0.0034 (0.34%)
#   'birds': P=0.0034 (0.34%)
#   'redoubling': P=0.0034 (0.34%)
#   'twitter': P=0.0034 (0.34%)
#   'suddenly': P=0.0034 (0.34%)
#   'scuttled': P=0.0034 (0.34%)
#   'side': P=0.0034 (0.34%)
#   'scurf': P=0.0034 (0.34%)
#   'weary': P=0.0034 (0.34%)
#   'overheated': P=0.0034 (0.34%)
#   'rested': P=0.0034 (0.34%)
#   'raised': P=0.0034 (0.34%)
#   'whats': P=0.0034 (0.34%)
#   'many': P=0.0034 (0.34%)
#   'barn': P=0.0034 (0.34%)
#   'blew': P=0.0034 (0.34%)
#   'stamped': P=0.0034 (0.34%)
#   'said': P=0.0034 (0.34%)
#   'sometimes': P=0.0034 (0.34%)
#   'END': P=0.0034 (0.34%)
#   'some': P=0.0034 (0.34%)
#   'made': P=0.0034 (0.34%)
#   'came': P=0.0034 (0.34%)
#   'politician': P=0.0034 (0.34%)
#   'took': P=0.0034 (0.34%)
#   'warrens': P=0.0034 (0.34%)
#   'thatd': P=0.0034 (0.34%)
#   'rode': P=0.0034 (0.34%)
#   'bones': P=0.0034 (0.34%)
#   'leave': P=0.0034 (0.34%)
#   'as': P=0.0034 (0.34%)
#   'posts': P=0.0034 (0.34%)
#   'fences': P=0.0034 (0.34%)
#   'from': P=0.0034 (0.34%)
#   'snow': P=0.0034 (0.34%)
#   'full': P=0.0034 (0.34%)
#   'experts': P=0.0034 (0.34%)
#   'show': P=0.0034 (0.34%)
#   'built': P=0.0034 (0.34%)
#   'emptied': P=0.0034 (0.34%)
#   'forty': P=0.0034 (0.34%)
#   'were': P=0.0034 (0.34%)
#   'on': P=0.0034 (0.34%)
#   'anyway': P=0.0034 (0.34%)
#   'bottle': P=0.0034 (0.34%)
#   'keep': P=0.0034 (0.34%)
#   'wrote': P=0.0034 (0.34%)
#   'taken': P=0.0034 (0.34%)
#   'bad': P=0.0034 (0.34%)
#   'lead': P=0.0034 (0.34%)
#   'opening': P=0.0034 (0.34%)
#   'lie': P=0.0034 (0.34%)
#   'bushes': P=0.0034 (0.34%)
#   'stroked': P=0.0034 (0.34%)
#   'me': P=0.0034 (0.34%)
#   'between': P=0.0034 (0.34%)
#   'wont': P=0.0034 (0.34%)
#   'hes': P=0.0034 (0.34%)
#   'mist': P=0.0034 (0.34%)
#   'nothing': P=0.0034 (0.34%)
#   'better': P=0.0034 (0.34%)
#   'son': P=0.0034 (0.34%)
#   'carried': P=0.0034 (0.34%)
#   'mother': P=0.0034 (0.34%)
#   'neither': P=0.0034 (0.34%)
#   'thought': P=0.0034 (0.34%)
#   'good': P=0.0034 (0.34%)
#   'licked': P=0.0034 (0.34%)
#   'fell': P=0.0034 (0.34%)
#   'set': P=0.0034 (0.34%)
#   'bring': P=0.0034 (0.34%)
#   'sure': P=0.0034 (0.34%)
#   'held': P=0.0034 (0.34%)
#   'push': P=0.0034 (0.34%)
#   'stand': P=0.0034 (0.34%)
#   'swift': P=0.0034 (0.34%)
#   'sproutlands': P=0.0034 (0.34%)
#   'orchard': P=0.0034 (0.34%)
#   'try': P=0.0034 (0.34%)
#   'get': P=0.0034 (0.34%)
#   'moments': P=0.0034 (0.34%)
#   'one': P=0.0034 (0.34%)
#   'she': P=0.0034 (0.34%)
#   'you': P=0.0034 (0.34%)
#   'baileys': P=0.0034 (0.34%)
#   'doubtless': P=0.0034 (0.34%)
#   'by': P=0.0034 (0.34%)
#   'dangle': P=0.0034 (0.34%)
#   'disappeared': P=0.0034 (0.34%)
#   'ended': P=0.0034 (0.34%)
#   'below': P=0.0034 (0.34%)
#   'what': P=0.0034 (0.34%)
#   'dim': P=0.0034 (0.34%)
#   'its': P=0.0034 (0.34%)
#   'smoking': P=0.0034 (0.34%)
#   'gets': P=0.0034 (0.34%)
#   'sos': P=0.0034 (0.34%)
#   'hew': P=0.0034 (0.34%)
#   'shape': P=0.0034 (0.34%)
#   'come': P=0.0034 (0.34%)
#   'begin': P=0.0034 (0.34%)
#   'it': P=0.0034 (0.34%)
#   'build': P=0.0034 (0.34%)
#   'youthful': P=0.0034 (0.34%)
#   'repented': P=0.0034 (0.34%)
#   'color': P=0.0034 (0.34%)
#   'odor': P=0.0034 (0.34%)
#   'go': P=0.0034 (0.34%)
#   'drouth': P=0.0034 (0.34%)
#   'broken': P=0.0034 (0.34%)
#   'theres': P=0.0034 (0.34%)
#   'original': P=0.0034 (0.34%)
#   'thorn': P=0.0034 (0.34%)
#   'stifling': P=0.0034 (0.34%)
#   'wet': P=0.0034 (0.34%)
#   'sound': P=0.0034 (0.34%)
#   'pair': P=0.0034 (0.34%)
#   'got': P=0.0034 (0.34%)
#   'new': P=0.0034 (0.34%)
#   'wife': P=0.0034 (0.34%)
#   'music': P=0.0034 (0.34%)
#   'give': P=0.0034 (0.34%)
#   'fight': P=0.0034 (0.34%)
#   'feather': P=0.0034 (0.34%)
#   'muffled': P=0.0034 (0.34%)
#   'such': P=0.0034 (0.34%)
#   'moon': P=0.0034 (0.34%)
#   'stars': P=0.0034 (0.34%)
#   'mars': P=0.0034 (0.34%)
#   'jupiter': P=0.0034 (0.34%)
#   'taus': P=0.0034 (0.34%)
#   'stirred': P=0.0034 (0.34%)
#   'under': P=0.0034 (0.34%)
#   'nation': P=0.0034 (0.34%)
#   'though': P=0.0034 (0.34%)
#   'tide': P=0.0034 (0.34%)
#   'wheres': P=0.0034 (0.34%)
#   'gone': P=0.0034 (0.34%)
#   'shell': P=0.0034 (0.34%)
#   'lord': P=0.0034 (0.34%)
#   'where': P=0.0034 (0.34%)
#   'no': P=0.0034 (0.34%)
#   'end': P=0.0034 (0.34%)
#   'after': P=0.0034 (0.34%)
#   'cows': P=0.0034 (0.34%)
#   'pigs': P=0.0034 (0.34%)
#   'like': P=0.0034 (0.34%)
#   'youre': P=0.0034 (0.34%)
#   'turn': P=0.0034 (0.34%)
#   'stop': P=0.0034 (0.34%)
#   'romp': P=0.0034 (0.34%)
#   'not': P=0.0034 (0.34%)
#   'last': P=0.0034 (0.34%)
#   'which': P=0.0034 (0.34%)
#   'sport': P=0.0034 (0.34%)
#
# Selected: 'i' (highest probability: 0.0410)
#
# Step 3: Selecting subsequent words with highest second-order probabilities
# ----------------------------------------------------------------------
#
# Selecting word 3 after ('and', 'i'):
#   'END': P=0.2500 (25.00%)
#   'can': P=0.0833 (8.33%)
#   'dont': P=0.0833 (8.33%)
#   'read': P=0.0833 (8.33%)
#   'know': P=0.0833 (8.33%)
#   'dread': P=0.0833 (8.33%)
#   'thought': P=0.0833 (8.33%)
#   'only': P=0.0833 (8.33%)
#   'have': P=0.0833 (8.33%)
#   'get': P=0.0833 (8.33%)
# Selected: 'END' (highest probability: 0.2500)
#
# END token reached. Line complete.
#
# >>> Generated Line 1: and i
#
# ======================================================================
# GENERATING LINE 2
# ======================================================================
#
# Step 1: Selecting first word with highest initial probability
# ----------------------------------------------------------------------
# Word choices and probabilities:
#   'and': P=0.0898 (8.98%)
#   'i': P=0.0822 (8.22%)
#   'the': P=0.0571 (5.71%)
#   'but': P=0.0355 (3.55%)
#   'to': P=0.0348 (3.48%)
#   'you': P=0.0279 (2.79%)
#   'he': P=0.0237 (2.37%)
#   'a': P=0.0209 (2.09%)
#   'in': P=0.0202 (2.02%)
#   'of': P=0.0202 (2.02%)
#   'that': P=0.0202 (2.02%)
#   'it': P=0.0160 (1.60%)
#   'its': P=0.0146 (1.46%)
#   'they': P=0.0132 (1.32%)
#   'with': P=0.0125 (1.25%)
#   'she': P=0.0118 (1.18%)
#   'we': P=0.0104 (1.04%)
#   'as': P=0.0097 (0.97%)
#   'what': P=0.0097 (0.97%)
#   'so': P=0.0091 (0.91%)
#   'not': P=0.0091 (0.91%)
#   'no': P=0.0091 (0.91%)
#   'then': P=0.0084 (0.84%)
#   'if': P=0.0084 (0.84%)
#   'one': P=0.0077 (0.77%)
#   'by': P=0.0077 (0.77%)
#   'hes': P=0.0077 (0.77%)
#   'or': P=0.0077 (0.77%)
#   'on': P=0.0077 (0.77%)
#   'from': P=0.0070 (0.70%)
#   'ill': P=0.0070 (0.70%)
#   'when': P=0.0063 (0.63%)
#   'was': P=0.0063 (0.63%)
#   'son': P=0.0063 (0.63%)
#   'two': P=0.0056 (0.56%)
#   'like': P=0.0056 (0.56%)
#   'all': P=0.0056 (0.56%)
#   'where': P=0.0056 (0.56%)
#   'yes': P=0.0056 (0.56%)
#   'though': P=0.0049 (0.49%)
#   'his': P=0.0049 (0.49%)
#   'my': P=0.0049 (0.49%)
#   'up': P=0.0049 (0.49%)
#   'dont': P=0.0049 (0.49%)
#   'for': P=0.0049 (0.49%)
#   'mother': P=0.0049 (0.49%)
#   'at': P=0.0042 (0.42%)
#   'who': P=0.0042 (0.42%)
#   'how': P=0.0042 (0.42%)
#   'there': P=0.0042 (0.42%)
#   'this': P=0.0042 (0.42%)
#   'john': P=0.0042 (0.42%)
#   'some': P=0.0035 (0.35%)
#   'is': P=0.0035 (0.35%)
#   'im': P=0.0035 (0.35%)
#   'only': P=0.0035 (0.35%)
#   'hed': P=0.0035 (0.35%)
#   'over': P=0.0035 (0.35%)
#   'well': P=0.0035 (0.35%)
#   'toffile': P=0.0035 (0.35%)
#   'thats': P=0.0035 (0.35%)
#   'had': P=0.0028 (0.28%)
#   'oh': P=0.0028 (0.28%)
#   'sometimes': P=0.0028 (0.28%)
#   'ive': P=0.0028 (0.28%)
#   'now': P=0.0028 (0.28%)
#   'come': P=0.0028 (0.28%)
#   'here': P=0.0028 (0.28%)
#   'nor': P=0.0028 (0.28%)
#   'whats': P=0.0028 (0.28%)
#   'yet': P=0.0021 (0.21%)
#   'between': P=0.0021 (0.21%)
#   'half': P=0.0021 (0.21%)
#   'were': P=0.0021 (0.21%)
#   'which': P=0.0021 (0.21%)
#   'lets': P=0.0021 (0.21%)
#   'be': P=0.0021 (0.21%)
#   'take': P=0.0021 (0.21%)
#   'why': P=0.0021 (0.21%)
#   'among': P=0.0021 (0.21%)
#   'shes': P=0.0021 (0.21%)
#   'whose': P=0.0014 (0.14%)
#   'her': P=0.0014 (0.14%)
#   'nothing': P=0.0014 (0.14%)
#   'disturbed': P=0.0014 (0.14%)
#   'once': P=0.0014 (0.14%)
#   'brown': P=0.0014 (0.14%)
#   'upon': P=0.0014 (0.14%)
#   'should': P=0.0014 (0.14%)
#   'until': P=0.0014 (0.14%)
#   'couldnt': P=0.0014 (0.14%)
#   'their': P=0.0014 (0.14%)
#   'has': P=0.0014 (0.14%)
#   'off': P=0.0014 (0.14%)
#   'old': P=0.0014 (0.14%)
#   'sos': P=0.0014 (0.14%)
#   'however': P=0.0014 (0.14%)
#   'perhaps': P=0.0014 (0.14%)
#   'our': P=0.0014 (0.14%)
#   'through': P=0.0014 (0.14%)
#   'except': P=0.0014 (0.14%)
#   'books': P=0.0014 (0.14%)
#   'till': P=0.0014 (0.14%)
#   'than': P=0.0014 (0.14%)
#   'behind': P=0.0014 (0.14%)
#   'tell': P=0.0014 (0.14%)
#   'another': P=0.0014 (0.14%)
#   'before': P=0.0014 (0.14%)
#   'let': P=0.0014 (0.14%)
#   'anyone': P=0.0014 (0.14%)
#   'drawn': P=0.0014 (0.14%)
#   'would': P=0.0014 (0.14%)
#   'under': P=0.0014 (0.14%)
#   'does': P=0.0014 (0.14%)
#   'beyond': P=0.0014 (0.14%)
#   'first': P=0.0014 (0.14%)
#   'bless': P=0.0014 (0.14%)
#   'something': P=0.0014 (0.14%)
#   'call': P=0.0014 (0.14%)
#   'will': P=0.0014 (0.14%)
#   'back': P=0.0014 (0.14%)
#   'still': P=0.0014 (0.14%)
#   'make': P=0.0014 (0.14%)
#   'too': P=0.0014 (0.14%)
#   'havent': P=0.0014 (0.14%)
#   'estelles': P=0.0014 (0.14%)
#   'johns': P=0.0014 (0.14%)
#   'because': P=0.0007 (0.07%)
#   'somewhere': P=0.0007 (0.07%)
#   'natures': P=0.0007 (0.07%)
#   'came': P=0.0007 (0.07%)
#   'proclaimed': P=0.0007 (0.07%)
#   'smoothlaid': P=0.0007 (0.07%)
#   'comes': P=0.0007 (0.07%)
#   'ten': P=0.0007 (0.07%)
#   'lifted': P=0.0007 (0.07%)
#   'transfixed': P=0.0007 (0.07%)
#   'across': P=0.0007 (0.07%)
#   'looked': P=0.0007 (0.07%)
#   'stood': P=0.0007 (0.07%)
#   'me': P=0.0007 (0.07%)
#   'cross': P=0.0007 (0.07%)
#   'describing': P=0.0007 (0.07%)
#   'got': P=0.0007 (0.07%)
#   'walls': P=0.0007 (0.07%)
#   'faster': P=0.0007 (0.07%)
#   'sitting': P=0.0007 (0.07%)
#   'according': P=0.0007 (0.07%)
#   'incredulous': P=0.0007 (0.07%)
#   'wellibe': P=0.0007 (0.07%)
#   'yankees': P=0.0007 (0.07%)
#   'after': P=0.0007 (0.07%)
#   'while': P=0.0007 (0.07%)
#   'bout': P=0.0007 (0.07%)
#   'theyve': P=0.0007 (0.07%)
#   'flattered': P=0.0007 (0.07%)
#   'always': P=0.0007 (0.07%)
#   'theyll': P=0.0007 (0.07%)
#   'voted': P=0.0007 (0.07%)
#   'wentworth': P=0.0007 (0.07%)
#   'rights': P=0.0007 (0.07%)
#   'itd': P=0.0007 (0.07%)
#   'said': P=0.0007 (0.07%)
#   'gnaws': P=0.0007 (0.07%)
#   'last': P=0.0007 (0.07%)
#   'thered': P=0.0007 (0.07%)
#   'someday': P=0.0007 (0.07%)
#   'today': P=0.0007 (0.07%)
#   'huh': P=0.0007 (0.07%)
#   'youve': P=0.0007 (0.07%)
#   'can': P=0.0007 (0.07%)
#   'ascending': P=0.0007 (0.07%)
#   'hadnt': P=0.0007 (0.07%)
#   'look': P=0.0007 (0.07%)
#   'excuse': P=0.0007 (0.07%)
#   'life': P=0.0007 (0.07%)
#   'enough': P=0.0007 (0.07%)
#   'unfortunately': P=0.0007 (0.07%)
#   'boys': P=0.0007 (0.07%)
#   'shatter': P=0.0007 (0.07%)
#   'tried': P=0.0007 (0.07%)
#   'having': P=0.0007 (0.07%)
#   'goodlooking': P=0.0007 (0.07%)
#   'both': P=0.0007 (0.07%)
#   'legitimately': P=0.0007 (0.07%)
#   'crosslegged': P=0.0007 (0.07%)
#   'alias': P=0.0007 (0.07%)
#   'about': P=0.0007 (0.07%)
#   'theres': P=0.0007 (0.07%)
#   'give': P=0.0007 (0.07%)
#   'thrown': P=0.0007 (0.07%)
#   'unless': P=0.0007 (0.07%)
#   'summoning': P=0.0007 (0.07%)
#   'whos': P=0.0007 (0.07%)
#   'done': P=0.0007 (0.07%)
#   'rather': P=0.0007 (0.07%)
#   'against': P=0.0007 (0.07%)
#   'halting': P=0.0007 (0.07%)
#   'never': P=0.0007 (0.07%)
#   'right': P=0.0007 (0.07%)
#   'father': P=0.0007 (0.07%)
#   'especially': P=0.0007 (0.07%)
#   'might': P=0.0007 (0.07%)
#   'struck': P=0.0007 (0.07%)
#   'began': P=0.0007 (0.07%)
#   'waiting': P=0.0007 (0.07%)
#   'flashed': P=0.0007 (0.07%)
#   'smoke': P=0.0007 (0.07%)
#   'hand': P=0.0007 (0.07%)
#   'stillgoing': P=0.0007 (0.07%)
#   'almost': P=0.0007 (0.07%)
#   'quick': P=0.0007 (0.07%)
#   'brushing': P=0.0007 (0.07%)
#   'o': P=0.0007 (0.07%)
#   'wed': P=0.0007 (0.07%)
#   'could': P=0.0007 (0.07%)
#   'ancestral': P=0.0007 (0.07%)
#   'someone': P=0.0007 (0.07%)
#   'thence': P=0.0007 (0.07%)
#   'made': P=0.0007 (0.07%)
#   'are': P=0.0007 (0.07%)
#   'strolled': P=0.0007 (0.07%)
#   'provision': P=0.0007 (0.07%)
#   'stark': P=0.0007 (0.07%)
#   'several': P=0.0007 (0.07%)
#   'just': P=0.0007 (0.07%)
#   'bowed': P=0.0007 (0.07%)
#   'four': P=0.0007 (0.07%)
#   'dyou': P=0.0007 (0.07%)
#   'studying': P=0.0007 (0.07%)
#   'heres': P=0.0007 (0.07%)
#   'making': P=0.0007 (0.07%)
#   'see': P=0.0007 (0.07%)
#   'strung': P=0.0007 (0.07%)
#   'speaking': P=0.0007 (0.07%)
#   'strangely': P=0.0007 (0.07%)
#   'nine': P=0.0007 (0.07%)
#   'anything': P=0.0007 (0.07%)
#   'folks': P=0.0007 (0.07%)
#   'mebbe': P=0.0007 (0.07%)
#   'more': P=0.0007 (0.07%)
#   'nowhere': P=0.0007 (0.07%)
#   'builder': P=0.0007 (0.07%)
#   'whatever': P=0.0007 (0.07%)
#   'inscription': P=0.0007 (0.07%)
#   'winds': P=0.0007 (0.07%)
#   'moisture': P=0.0007 (0.07%)
#   'heaven': P=0.0007 (0.07%)
#   'may': P=0.0007 (0.07%)
#   'great': P=0.0007 (0.07%)
#   'long': P=0.0007 (0.07%)
#   'besides': P=0.0007 (0.07%)
#   'charge': P=0.0007 (0.07%)
#   'someones': P=0.0007 (0.07%)
#   'into': P=0.0007 (0.07%)
#   'weep': P=0.0007 (0.07%)
#   'your': P=0.0007 (0.07%)
#   'cold': P=0.0007 (0.07%)
#   'drink': P=0.0007 (0.07%)
#   'wherever': P=0.0007 (0.07%)
#   'birch': P=0.0007 (0.07%)
#   'time': P=0.0007 (0.07%)
#   'small': P=0.0007 (0.07%)
#   'out': P=0.0007 (0.07%)
#   'awake': P=0.0007 (0.07%)
#   'wishing': P=0.0007 (0.07%)
#   'saturn': P=0.0007 (0.07%)
#   'speculation': P=0.0007 (0.07%)
#   'theirs': P=0.0007 (0.07%)
#   'uttered': P=0.0007 (0.07%)
#   'trembled': P=0.0007 (0.07%)
#   'appear': P=0.0007 (0.07%)
#   'around': P=0.0007 (0.07%)
#   'since': P=0.0007 (0.07%)
#   'lord': P=0.0007 (0.07%)
#   'weve': P=0.0007 (0.07%)
#   'left': P=0.0007 (0.07%)
#   'hell': P=0.0007 (0.07%)
#   'skyhigh': P=0.0007 (0.07%)
#   'arent': P=0.0007 (0.07%)
#   'better': P=0.0007 (0.07%)
#   'reason': P=0.0007 (0.07%)
#   'such': P=0.0007 (0.07%)
#   'twas': P=0.0007 (0.07%)
#   'estelle': P=0.0007 (0.07%)
#   'farmers': P=0.0007 (0.07%)
#   'full': P=0.0007 (0.07%)
#   'moving': P=0.0007 (0.07%)
#   'nothings': P=0.0007 (0.07%)
#   'twenty': P=0.0007 (0.07%)
#   'receipted': P=0.0007 (0.07%)
#   'wampum': P=0.0007 (0.07%)
#   'cant': P=0.0007 (0.07%)
#   'being': P=0.0007 (0.07%)
#   'oho': P=0.0007 (0.07%)
#   'bad': P=0.0007 (0.07%)
#   'nonsense': P=0.0007 (0.07%)
#   'whod': P=0.0007 (0.07%)
#   'say': P=0.0007 (0.07%)
#   'youll': P=0.0007 (0.07%)
#   'coming': P=0.0007 (0.07%)
#   'isnt': P=0.0007 (0.07%)
#   'do': P=0.0007 (0.07%)
#   'content': P=0.0007 (0.07%)
#   'an': P=0.0007 (0.07%)
#
# Selected: 'and' (highest probability: 0.0898)
#
# Step 2: Selecting second word with highest first-order probability
# ----------------------------------------------------------------------
# After 'and', possible words:
#   'i': P=0.0410 (4.10%)
#   'the': P=0.0410 (4.10%)
#   'then': P=0.0239 (2.39%)
#   'tell': P=0.0137 (1.37%)
#   'see': P=0.0137 (1.37%)
#   'when': P=0.0102 (1.02%)
#   'how': P=0.0102 (1.02%)
#   'hold': P=0.0102 (1.02%)
#   'swollen': P=0.0102 (1.02%)
#   'a': P=0.0102 (1.02%)
#   'all': P=0.0102 (1.02%)
#   'in': P=0.0102 (1.02%)
#   'sorry': P=0.0068 (0.68%)
#   'be': P=0.0068 (0.68%)
#   'both': P=0.0068 (0.68%)
#   'that': P=0.0068 (0.68%)
#   'miles': P=0.0068 (0.68%)
#   'now': P=0.0068 (0.68%)
#   'put': P=0.0068 (0.68%)
#   'since': P=0.0068 (0.68%)
#   'there': P=0.0068 (0.68%)
#   'he': P=0.0068 (0.68%)
#   'this': P=0.0068 (0.68%)
#   'if': P=0.0068 (0.68%)
#   'had': P=0.0068 (0.68%)
#   'make': P=0.0068 (0.68%)
#   'kick': P=0.0068 (0.68%)
#   'thats': P=0.0068 (0.68%)
#   'spoke': P=0.0068 (0.68%)
#   'save': P=0.0068 (0.68%)
#   'left': P=0.0068 (0.68%)
#   'his': P=0.0068 (0.68%)
#   'headboard': P=0.0068 (0.68%)
#   'buried': P=0.0068 (0.68%)
#   'shouted': P=0.0068 (0.68%)
#   'sit': P=0.0068 (0.68%)
#   'take': P=0.0068 (0.68%)
#   'lift': P=0.0068 (0.68%)
#   'those': P=0.0068 (0.68%)
#   'perhaps': P=0.0068 (0.68%)
#   'still': P=0.0068 (0.68%)
#   'your': P=0.0068 (0.68%)
#   'besides': P=0.0068 (0.68%)
#   'we': P=0.0068 (0.68%)
#   'looked': P=0.0034 (0.34%)
#   'having': P=0.0034 (0.34%)
#   'wanted': P=0.0034 (0.34%)
#   'ages': P=0.0034 (0.34%)
#   'frozen': P=0.0034 (0.34%)
#   'downy': P=0.0034 (0.34%)
#   'deep': P=0.0034 (0.34%)
#   'would': P=0.0034 (0.34%)
#   'back': P=0.0034 (0.34%)
#   'dropped': P=0.0034 (0.34%)
#   'stopped': P=0.0034 (0.34%)
#   'further': P=0.0034 (0.34%)
#   'caught': P=0.0034 (0.34%)
#   'threw': P=0.0034 (0.34%)
#   'wetkneed': P=0.0034 (0.34%)
#   'birds': P=0.0034 (0.34%)
#   'redoubling': P=0.0034 (0.34%)
#   'twitter': P=0.0034 (0.34%)
#   'suddenly': P=0.0034 (0.34%)
#   'scuttled': P=0.0034 (0.34%)
#   'side': P=0.0034 (0.34%)
#   'scurf': P=0.0034 (0.34%)
#   'weary': P=0.0034 (0.34%)
#   'overheated': P=0.0034 (0.34%)
#   'rested': P=0.0034 (0.34%)
#   'raised': P=0.0034 (0.34%)
#   'whats': P=0.0034 (0.34%)
#   'many': P=0.0034 (0.34%)
#   'barn': P=0.0034 (0.34%)
#   'blew': P=0.0034 (0.34%)
#   'stamped': P=0.0034 (0.34%)
#   'said': P=0.0034 (0.34%)
#   'sometimes': P=0.0034 (0.34%)
#   'END': P=0.0034 (0.34%)
#   'some': P=0.0034 (0.34%)
#   'made': P=0.0034 (0.34%)
#   'came': P=0.0034 (0.34%)
#   'politician': P=0.0034 (0.34%)
#   'took': P=0.0034 (0.34%)
#   'warrens': P=0.0034 (0.34%)
#   'thatd': P=0.0034 (0.34%)
#   'rode': P=0.0034 (0.34%)
#   'bones': P=0.0034 (0.34%)
#   'leave': P=0.0034 (0.34%)
#   'as': P=0.0034 (0.34%)
#   'posts': P=0.0034 (0.34%)
#   'fences': P=0.0034 (0.34%)
#   'from': P=0.0034 (0.34%)
#   'snow': P=0.0034 (0.34%)
#   'full': P=0.0034 (0.34%)
#   'experts': P=0.0034 (0.34%)
#   'show': P=0.0034 (0.34%)
#   'built': P=0.0034 (0.34%)
#   'emptied': P=0.0034 (0.34%)
#   'forty': P=0.0034 (0.34%)
#   'were': P=0.0034 (0.34%)
#   'on': P=0.0034 (0.34%)
#   'anyway': P=0.0034 (0.34%)
#   'bottle': P=0.0034 (0.34%)
#   'keep': P=0.0034 (0.34%)
#   'wrote': P=0.0034 (0.34%)
#   'taken': P=0.0034 (0.34%)
#   'bad': P=0.0034 (0.34%)
#   'lead': P=0.0034 (0.34%)
#   'opening': P=0.0034 (0.34%)
#   'lie': P=0.0034 (0.34%)
#   'bushes': P=0.0034 (0.34%)
#   'stroked': P=0.0034 (0.34%)
#   'me': P=0.0034 (0.34%)
#   'between': P=0.0034 (0.34%)
#   'wont': P=0.0034 (0.34%)
#   'hes': P=0.0034 (0.34%)
#   'mist': P=0.0034 (0.34%)
#   'nothing': P=0.0034 (0.34%)
#   'better': P=0.0034 (0.34%)
#   'son': P=0.0034 (0.34%)
#   'carried': P=0.0034 (0.34%)
#   'mother': P=0.0034 (0.34%)
#   'neither': P=0.0034 (0.34%)
#   'thought': P=0.0034 (0.34%)
#   'good': P=0.0034 (0.34%)
#   'licked': P=0.0034 (0.34%)
#   'fell': P=0.0034 (0.34%)
#   'set': P=0.0034 (0.34%)
#   'bring': P=0.0034 (0.34%)
#   'sure': P=0.0034 (0.34%)
#   'held': P=0.0034 (0.34%)
#   'push': P=0.0034 (0.34%)
#   'stand': P=0.0034 (0.34%)
#   'swift': P=0.0034 (0.34%)
#   'sproutlands': P=0.0034 (0.34%)
#   'orchard': P=0.0034 (0.34%)
#   'try': P=0.0034 (0.34%)
#   'get': P=0.0034 (0.34%)
#   'moments': P=0.0034 (0.34%)
#   'one': P=0.0034 (0.34%)
#   'she': P=0.0034 (0.34%)
#   'you': P=0.0034 (0.34%)
#   'baileys': P=0.0034 (0.34%)
#   'doubtless': P=0.0034 (0.34%)
#   'by': P=0.0034 (0.34%)
#   'dangle': P=0.0034 (0.34%)
#   'disappeared': P=0.0034 (0.34%)
#   'ended': P=0.0034 (0.34%)
#   'below': P=0.0034 (0.34%)
#   'what': P=0.0034 (0.34%)
#   'dim': P=0.0034 (0.34%)
#   'its': P=0.0034 (0.34%)
#   'smoking': P=0.0034 (0.34%)
#   'gets': P=0.0034 (0.34%)
#   'sos': P=0.0034 (0.34%)
#   'hew': P=0.0034 (0.34%)
#   'shape': P=0.0034 (0.34%)
#   'come': P=0.0034 (0.34%)
#   'begin': P=0.0034 (0.34%)
#   'it': P=0.0034 (0.34%)
#   'build': P=0.0034 (0.34%)
#   'youthful': P=0.0034 (0.34%)
#   'repented': P=0.0034 (0.34%)
#   'color': P=0.0034 (0.34%)
#   'odor': P=0.0034 (0.34%)
#   'go': P=0.0034 (0.34%)
#   'drouth': P=0.0034 (0.34%)
#   'broken': P=0.0034 (0.34%)
#   'theres': P=0.0034 (0.34%)
#   'original': P=0.0034 (0.34%)
#   'thorn': P=0.0034 (0.34%)
#   'stifling': P=0.0034 (0.34%)
#   'wet': P=0.0034 (0.34%)
#   'sound': P=0.0034 (0.34%)
#   'pair': P=0.0034 (0.34%)
#   'got': P=0.0034 (0.34%)
#   'new': P=0.0034 (0.34%)
#   'wife': P=0.0034 (0.34%)
#   'music': P=0.0034 (0.34%)
#   'give': P=0.0034 (0.34%)
#   'fight': P=0.0034 (0.34%)
#   'feather': P=0.0034 (0.34%)
#   'muffled': P=0.0034 (0.34%)
#   'such': P=0.0034 (0.34%)
#   'moon': P=0.0034 (0.34%)
#   'stars': P=0.0034 (0.34%)
#   'mars': P=0.0034 (0.34%)
#   'jupiter': P=0.0034 (0.34%)
#   'taus': P=0.0034 (0.34%)
#   'stirred': P=0.0034 (0.34%)
#   'under': P=0.0034 (0.34%)
#   'nation': P=0.0034 (0.34%)
#   'though': P=0.0034 (0.34%)
#   'tide': P=0.0034 (0.34%)
#   'wheres': P=0.0034 (0.34%)
#   'gone': P=0.0034 (0.34%)
#   'shell': P=0.0034 (0.34%)
#   'lord': P=0.0034 (0.34%)
#   'where': P=0.0034 (0.34%)
#   'no': P=0.0034 (0.34%)
#   'end': P=0.0034 (0.34%)
#   'after': P=0.0034 (0.34%)
#   'cows': P=0.0034 (0.34%)
#   'pigs': P=0.0034 (0.34%)
#   'like': P=0.0034 (0.34%)
#   'youre': P=0.0034 (0.34%)
#   'turn': P=0.0034 (0.34%)
#   'stop': P=0.0034 (0.34%)
#   'romp': P=0.0034 (0.34%)
#   'not': P=0.0034 (0.34%)
#   'last': P=0.0034 (0.34%)
#   'which': P=0.0034 (0.34%)
#   'sport': P=0.0034 (0.34%)
#
# Selected: 'i' (highest probability: 0.0410)
#
# Step 3: Selecting subsequent words with highest second-order probabilities
# ----------------------------------------------------------------------
#
# Selecting word 3 after ('and', 'i'):
#   'END': P=0.2500 (25.00%)
#   'can': P=0.0833 (8.33%)
#   'dont': P=0.0833 (8.33%)
#   'read': P=0.0833 (8.33%)
#   'know': P=0.0833 (8.33%)
#   'dread': P=0.0833 (8.33%)
#   'thought': P=0.0833 (8.33%)
#   'only': P=0.0833 (8.33%)
#   'have': P=0.0833 (8.33%)
#   'get': P=0.0833 (8.33%)
# Selected: 'END' (highest probability: 0.2500)
#
# END token reached. Line complete.
#
# >>> Generated Line 2: and i
#
# ======================================================================
# GENERATING LINE 3
# ======================================================================
#
# Step 1: Selecting first word with highest initial probability
# ----------------------------------------------------------------------
# Word choices and probabilities:
#   'and': P=0.0898 (8.98%)
#   'i': P=0.0822 (8.22%)
#   'the': P=0.0571 (5.71%)
#   'but': P=0.0355 (3.55%)
#   'to': P=0.0348 (3.48%)
#   'you': P=0.0279 (2.79%)
#   'he': P=0.0237 (2.37%)
#   'a': P=0.0209 (2.09%)
#   'in': P=0.0202 (2.02%)
#   'of': P=0.0202 (2.02%)
#   'that': P=0.0202 (2.02%)
#   'it': P=0.0160 (1.60%)
#   'its': P=0.0146 (1.46%)
#   'they': P=0.0132 (1.32%)
#   'with': P=0.0125 (1.25%)
#   'she': P=0.0118 (1.18%)
#   'we': P=0.0104 (1.04%)
#   'as': P=0.0097 (0.97%)
#   'what': P=0.0097 (0.97%)
#   'so': P=0.0091 (0.91%)
#   'not': P=0.0091 (0.91%)
#   'no': P=0.0091 (0.91%)
#   'then': P=0.0084 (0.84%)
#   'if': P=0.0084 (0.84%)
#   'one': P=0.0077 (0.77%)
#   'by': P=0.0077 (0.77%)
#   'hes': P=0.0077 (0.77%)
#   'or': P=0.0077 (0.77%)
#   'on': P=0.0077 (0.77%)
#   'from': P=0.0070 (0.70%)
#   'ill': P=0.0070 (0.70%)
#   'when': P=0.0063 (0.63%)
#   'was': P=0.0063 (0.63%)
#   'son': P=0.0063 (0.63%)
#   'two': P=0.0056 (0.56%)
#   'like': P=0.0056 (0.56%)
#   'all': P=0.0056 (0.56%)
#   'where': P=0.0056 (0.56%)
#   'yes': P=0.0056 (0.56%)
#   'though': P=0.0049 (0.49%)
#   'his': P=0.0049 (0.49%)
#   'my': P=0.0049 (0.49%)
#   'up': P=0.0049 (0.49%)
#   'dont': P=0.0049 (0.49%)
#   'for': P=0.0049 (0.49%)
#   'mother': P=0.0049 (0.49%)
#   'at': P=0.0042 (0.42%)
#   'who': P=0.0042 (0.42%)
#   'how': P=0.0042 (0.42%)
#   'there': P=0.0042 (0.42%)
#   'this': P=0.0042 (0.42%)
#   'john': P=0.0042 (0.42%)
#   'some': P=0.0035 (0.35%)
#   'is': P=0.0035 (0.35%)
#   'im': P=0.0035 (0.35%)
#   'only': P=0.0035 (0.35%)
#   'hed': P=0.0035 (0.35%)
#   'over': P=0.0035 (0.35%)
#   'well': P=0.0035 (0.35%)
#   'toffile': P=0.0035 (0.35%)
#   'thats': P=0.0035 (0.35%)
#   'had': P=0.0028 (0.28%)
#   'oh': P=0.0028 (0.28%)
#   'sometimes': P=0.0028 (0.28%)
#   'ive': P=0.0028 (0.28%)
#   'now': P=0.0028 (0.28%)
#   'come': P=0.0028 (0.28%)
#   'here': P=0.0028 (0.28%)
#   'nor': P=0.0028 (0.28%)
#   'whats': P=0.0028 (0.28%)
#   'yet': P=0.0021 (0.21%)
#   'between': P=0.0021 (0.21%)
#   'half': P=0.0021 (0.21%)
#   'were': P=0.0021 (0.21%)
#   'which': P=0.0021 (0.21%)
#   'lets': P=0.0021 (0.21%)
#   'be': P=0.0021 (0.21%)
#   'take': P=0.0021 (0.21%)
#   'why': P=0.0021 (0.21%)
#   'among': P=0.0021 (0.21%)
#   'shes': P=0.0021 (0.21%)
#   'whose': P=0.0014 (0.14%)
#   'her': P=0.0014 (0.14%)
#   'nothing': P=0.0014 (0.14%)
#   'disturbed': P=0.0014 (0.14%)
#   'once': P=0.0014 (0.14%)
#   'brown': P=0.0014 (0.14%)
#   'upon': P=0.0014 (0.14%)
#   'should': P=0.0014 (0.14%)
#   'until': P=0.0014 (0.14%)
#   'couldnt': P=0.0014 (0.14%)
#   'their': P=0.0014 (0.14%)
#   'has': P=0.0014 (0.14%)
#   'off': P=0.0014 (0.14%)
#   'old': P=0.0014 (0.14%)
#   'sos': P=0.0014 (0.14%)
#   'however': P=0.0014 (0.14%)
#   'perhaps': P=0.0014 (0.14%)
#   'our': P=0.0014 (0.14%)
#   'through': P=0.0014 (0.14%)
#   'except': P=0.0014 (0.14%)
#   'books': P=0.0014 (0.14%)
#   'till': P=0.0014 (0.14%)
#   'than': P=0.0014 (0.14%)
#   'behind': P=0.0014 (0.14%)
#   'tell': P=0.0014 (0.14%)
#   'another': P=0.0014 (0.14%)
#   'before': P=0.0014 (0.14%)
#   'let': P=0.0014 (0.14%)
#   'anyone': P=0.0014 (0.14%)
#   'drawn': P=0.0014 (0.14%)
#   'would': P=0.0014 (0.14%)
#   'under': P=0.0014 (0.14%)
#   'does': P=0.0014 (0.14%)
#   'beyond': P=0.0014 (0.14%)
#   'first': P=0.0014 (0.14%)
#   'bless': P=0.0014 (0.14%)
#   'something': P=0.0014 (0.14%)
#   'call': P=0.0014 (0.14%)
#   'will': P=0.0014 (0.14%)
#   'back': P=0.0014 (0.14%)
#   'still': P=0.0014 (0.14%)
#   'make': P=0.0014 (0.14%)
#   'too': P=0.0014 (0.14%)
#   'havent': P=0.0014 (0.14%)
#   'estelles': P=0.0014 (0.14%)
#   'johns': P=0.0014 (0.14%)
#   'because': P=0.0007 (0.07%)
#   'somewhere': P=0.0007 (0.07%)
#   'natures': P=0.0007 (0.07%)
#   'came': P=0.0007 (0.07%)
#   'proclaimed': P=0.0007 (0.07%)
#   'smoothlaid': P=0.0007 (0.07%)
#   'comes': P=0.0007 (0.07%)
#   'ten': P=0.0007 (0.07%)
#   'lifted': P=0.0007 (0.07%)
#   'transfixed': P=0.0007 (0.07%)
#   'across': P=0.0007 (0.07%)
#   'looked': P=0.0007 (0.07%)
#   'stood': P=0.0007 (0.07%)
#   'me': P=0.0007 (0.07%)
#   'cross': P=0.0007 (0.07%)
#   'describing': P=0.0007 (0.07%)
#   'got': P=0.0007 (0.07%)
#   'walls': P=0.0007 (0.07%)
#   'faster': P=0.0007 (0.07%)
#   'sitting': P=0.0007 (0.07%)
#   'according': P=0.0007 (0.07%)
#   'incredulous': P=0.0007 (0.07%)
#   'wellibe': P=0.0007 (0.07%)
#   'yankees': P=0.0007 (0.07%)
#   'after': P=0.0007 (0.07%)
#   'while': P=0.0007 (0.07%)
#   'bout': P=0.0007 (0.07%)
#   'theyve': P=0.0007 (0.07%)
#   'flattered': P=0.0007 (0.07%)
#   'always': P=0.0007 (0.07%)
#   'theyll': P=0.0007 (0.07%)
#   'voted': P=0.0007 (0.07%)
#   'wentworth': P=0.0007 (0.07%)
#   'rights': P=0.0007 (0.07%)
#   'itd': P=0.0007 (0.07%)
#   'said': P=0.0007 (0.07%)
#   'gnaws': P=0.0007 (0.07%)
#   'last': P=0.0007 (0.07%)
#   'thered': P=0.0007 (0.07%)
#   'someday': P=0.0007 (0.07%)
#   'today': P=0.0007 (0.07%)
#   'huh': P=0.0007 (0.07%)
#   'youve': P=0.0007 (0.07%)
#   'can': P=0.0007 (0.07%)
#   'ascending': P=0.0007 (0.07%)
#   'hadnt': P=0.0007 (0.07%)
#   'look': P=0.0007 (0.07%)
#   'excuse': P=0.0007 (0.07%)
#   'life': P=0.0007 (0.07%)
#   'enough': P=0.0007 (0.07%)
#   'unfortunately': P=0.0007 (0.07%)
#   'boys': P=0.0007 (0.07%)
#   'shatter': P=0.0007 (0.07%)
#   'tried': P=0.0007 (0.07%)
#   'having': P=0.0007 (0.07%)
#   'goodlooking': P=0.0007 (0.07%)
#   'both': P=0.0007 (0.07%)
#   'legitimately': P=0.0007 (0.07%)
#   'crosslegged': P=0.0007 (0.07%)
#   'alias': P=0.0007 (0.07%)
#   'about': P=0.0007 (0.07%)
#   'theres': P=0.0007 (0.07%)
#   'give': P=0.0007 (0.07%)
#   'thrown': P=0.0007 (0.07%)
#   'unless': P=0.0007 (0.07%)
#   'summoning': P=0.0007 (0.07%)
#   'whos': P=0.0007 (0.07%)
#   'done': P=0.0007 (0.07%)
#   'rather': P=0.0007 (0.07%)
#   'against': P=0.0007 (0.07%)
#   'halting': P=0.0007 (0.07%)
#   'never': P=0.0007 (0.07%)
#   'right': P=0.0007 (0.07%)
#   'father': P=0.0007 (0.07%)
#   'especially': P=0.0007 (0.07%)
#   'might': P=0.0007 (0.07%)
#   'struck': P=0.0007 (0.07%)
#   'began': P=0.0007 (0.07%)
#   'waiting': P=0.0007 (0.07%)
#   'flashed': P=0.0007 (0.07%)
#   'smoke': P=0.0007 (0.07%)
#   'hand': P=0.0007 (0.07%)
#   'stillgoing': P=0.0007 (0.07%)
#   'almost': P=0.0007 (0.07%)
#   'quick': P=0.0007 (0.07%)
#   'brushing': P=0.0007 (0.07%)
#   'o': P=0.0007 (0.07%)
#   'wed': P=0.0007 (0.07%)
#   'could': P=0.0007 (0.07%)
#   'ancestral': P=0.0007 (0.07%)
#   'someone': P=0.0007 (0.07%)
#   'thence': P=0.0007 (0.07%)
#   'made': P=0.0007 (0.07%)
#   'are': P=0.0007 (0.07%)
#   'strolled': P=0.0007 (0.07%)
#   'provision': P=0.0007 (0.07%)
#   'stark': P=0.0007 (0.07%)
#   'several': P=0.0007 (0.07%)
#   'just': P=0.0007 (0.07%)
#   'bowed': P=0.0007 (0.07%)
#   'four': P=0.0007 (0.07%)
#   'dyou': P=0.0007 (0.07%)
#   'studying': P=0.0007 (0.07%)
#   'heres': P=0.0007 (0.07%)
#   'making': P=0.0007 (0.07%)
#   'see': P=0.0007 (0.07%)
#   'strung': P=0.0007 (0.07%)
#   'speaking': P=0.0007 (0.07%)
#   'strangely': P=0.0007 (0.07%)
#   'nine': P=0.0007 (0.07%)
#   'anything': P=0.0007 (0.07%)
#   'folks': P=0.0007 (0.07%)
#   'mebbe': P=0.0007 (0.07%)
#   'more': P=0.0007 (0.07%)
#   'nowhere': P=0.0007 (0.07%)
#   'builder': P=0.0007 (0.07%)
#   'whatever': P=0.0007 (0.07%)
#   'inscription': P=0.0007 (0.07%)
#   'winds': P=0.0007 (0.07%)
#   'moisture': P=0.0007 (0.07%)
#   'heaven': P=0.0007 (0.07%)
#   'may': P=0.0007 (0.07%)
#   'great': P=0.0007 (0.07%)
#   'long': P=0.0007 (0.07%)
#   'besides': P=0.0007 (0.07%)
#   'charge': P=0.0007 (0.07%)
#   'someones': P=0.0007 (0.07%)
#   'into': P=0.0007 (0.07%)
#   'weep': P=0.0007 (0.07%)
#   'your': P=0.0007 (0.07%)
#   'cold': P=0.0007 (0.07%)
#   'drink': P=0.0007 (0.07%)
#   'wherever': P=0.0007 (0.07%)
#   'birch': P=0.0007 (0.07%)
#   'time': P=0.0007 (0.07%)
#   'small': P=0.0007 (0.07%)
#   'out': P=0.0007 (0.07%)
#   'awake': P=0.0007 (0.07%)
#   'wishing': P=0.0007 (0.07%)
#   'saturn': P=0.0007 (0.07%)
#   'speculation': P=0.0007 (0.07%)
#   'theirs': P=0.0007 (0.07%)
#   'uttered': P=0.0007 (0.07%)
#   'trembled': P=0.0007 (0.07%)
#   'appear': P=0.0007 (0.07%)
#   'around': P=0.0007 (0.07%)
#   'since': P=0.0007 (0.07%)
#   'lord': P=0.0007 (0.07%)
#   'weve': P=0.0007 (0.07%)
#   'left': P=0.0007 (0.07%)
#   'hell': P=0.0007 (0.07%)
#   'skyhigh': P=0.0007 (0.07%)
#   'arent': P=0.0007 (0.07%)
#   'better': P=0.0007 (0.07%)
#   'reason': P=0.0007 (0.07%)
#   'such': P=0.0007 (0.07%)
#   'twas': P=0.0007 (0.07%)
#   'estelle': P=0.0007 (0.07%)
#   'farmers': P=0.0007 (0.07%)
#   'full': P=0.0007 (0.07%)
#   'moving': P=0.0007 (0.07%)
#   'nothings': P=0.0007 (0.07%)
#   'twenty': P=0.0007 (0.07%)
#   'receipted': P=0.0007 (0.07%)
#   'wampum': P=0.0007 (0.07%)
#   'cant': P=0.0007 (0.07%)
#   'being': P=0.0007 (0.07%)
#   'oho': P=0.0007 (0.07%)
#   'bad': P=0.0007 (0.07%)
#   'nonsense': P=0.0007 (0.07%)
#   'whod': P=0.0007 (0.07%)
#   'say': P=0.0007 (0.07%)
#   'youll': P=0.0007 (0.07%)
#   'coming': P=0.0007 (0.07%)
#   'isnt': P=0.0007 (0.07%)
#   'do': P=0.0007 (0.07%)
#   'content': P=0.0007 (0.07%)
#   'an': P=0.0007 (0.07%)
#
# Selected: 'and' (highest probability: 0.0898)
#
# Step 2: Selecting second word with highest first-order probability
# ----------------------------------------------------------------------
# After 'and', possible words:
#   'i': P=0.0410 (4.10%)
#   'the': P=0.0410 (4.10%)
#   'then': P=0.0239 (2.39%)
#   'tell': P=0.0137 (1.37%)
#   'see': P=0.0137 (1.37%)
#   'when': P=0.0102 (1.02%)
#   'how': P=0.0102 (1.02%)
#   'hold': P=0.0102 (1.02%)
#   'swollen': P=0.0102 (1.02%)
#   'a': P=0.0102 (1.02%)
#   'all': P=0.0102 (1.02%)
#   'in': P=0.0102 (1.02%)
#   'sorry': P=0.0068 (0.68%)
#   'be': P=0.0068 (0.68%)
#   'both': P=0.0068 (0.68%)
#   'that': P=0.0068 (0.68%)
#   'miles': P=0.0068 (0.68%)
#   'now': P=0.0068 (0.68%)
#   'put': P=0.0068 (0.68%)
#   'since': P=0.0068 (0.68%)
#   'there': P=0.0068 (0.68%)
#   'he': P=0.0068 (0.68%)
#   'this': P=0.0068 (0.68%)
#   'if': P=0.0068 (0.68%)
#   'had': P=0.0068 (0.68%)
#   'make': P=0.0068 (0.68%)
#   'kick': P=0.0068 (0.68%)
#   'thats': P=0.0068 (0.68%)
#   'spoke': P=0.0068 (0.68%)
#   'save': P=0.0068 (0.68%)
#   'left': P=0.0068 (0.68%)
#   'his': P=0.0068 (0.68%)
#   'headboard': P=0.0068 (0.68%)
#   'buried': P=0.0068 (0.68%)
#   'shouted': P=0.0068 (0.68%)
#   'sit': P=0.0068 (0.68%)
#   'take': P=0.0068 (0.68%)
#   'lift': P=0.0068 (0.68%)
#   'those': P=0.0068 (0.68%)
#   'perhaps': P=0.0068 (0.68%)
#   'still': P=0.0068 (0.68%)
#   'your': P=0.0068 (0.68%)
#   'besides': P=0.0068 (0.68%)
#   'we': P=0.0068 (0.68%)
#   'looked': P=0.0034 (0.34%)
#   'having': P=0.0034 (0.34%)
#   'wanted': P=0.0034 (0.34%)
#   'ages': P=0.0034 (0.34%)
#   'frozen': P=0.0034 (0.34%)
#   'downy': P=0.0034 (0.34%)
#   'deep': P=0.0034 (0.34%)
#   'would': P=0.0034 (0.34%)
#   'back': P=0.0034 (0.34%)
#   'dropped': P=0.0034 (0.34%)
#   'stopped': P=0.0034 (0.34%)
#   'further': P=0.0034 (0.34%)
#   'caught': P=0.0034 (0.34%)
#   'threw': P=0.0034 (0.34%)
#   'wetkneed': P=0.0034 (0.34%)
#   'birds': P=0.0034 (0.34%)
#   'redoubling': P=0.0034 (0.34%)
#   'twitter': P=0.0034 (0.34%)
#   'suddenly': P=0.0034 (0.34%)
#   'scuttled': P=0.0034 (0.34%)
#   'side': P=0.0034 (0.34%)
#   'scurf': P=0.0034 (0.34%)
#   'weary': P=0.0034 (0.34%)
#   'overheated': P=0.0034 (0.34%)
#   'rested': P=0.0034 (0.34%)
#   'raised': P=0.0034 (0.34%)
#   'whats': P=0.0034 (0.34%)
#   'many': P=0.0034 (0.34%)
#   'barn': P=0.0034 (0.34%)
#   'blew': P=0.0034 (0.34%)
#   'stamped': P=0.0034 (0.34%)
#   'said': P=0.0034 (0.34%)
#   'sometimes': P=0.0034 (0.34%)
#   'END': P=0.0034 (0.34%)
#   'some': P=0.0034 (0.34%)
#   'made': P=0.0034 (0.34%)
#   'came': P=0.0034 (0.34%)
#   'politician': P=0.0034 (0.34%)
#   'took': P=0.0034 (0.34%)
#   'warrens': P=0.0034 (0.34%)
#   'thatd': P=0.0034 (0.34%)
#   'rode': P=0.0034 (0.34%)
#   'bones': P=0.0034 (0.34%)
#   'leave': P=0.0034 (0.34%)
#   'as': P=0.0034 (0.34%)
#   'posts': P=0.0034 (0.34%)
#   'fences': P=0.0034 (0.34%)
#   'from': P=0.0034 (0.34%)
#   'snow': P=0.0034 (0.34%)
#   'full': P=0.0034 (0.34%)
#   'experts': P=0.0034 (0.34%)
#   'show': P=0.0034 (0.34%)
#   'built': P=0.0034 (0.34%)
#   'emptied': P=0.0034 (0.34%)
#   'forty': P=0.0034 (0.34%)
#   'were': P=0.0034 (0.34%)
#   'on': P=0.0034 (0.34%)
#   'anyway': P=0.0034 (0.34%)
#   'bottle': P=0.0034 (0.34%)
#   'keep': P=0.0034 (0.34%)
#   'wrote': P=0.0034 (0.34%)
#   'taken': P=0.0034 (0.34%)
#   'bad': P=0.0034 (0.34%)
#   'lead': P=0.0034 (0.34%)
#   'opening': P=0.0034 (0.34%)
#   'lie': P=0.0034 (0.34%)
#   'bushes': P=0.0034 (0.34%)
#   'stroked': P=0.0034 (0.34%)
#   'me': P=0.0034 (0.34%)
#   'between': P=0.0034 (0.34%)
#   'wont': P=0.0034 (0.34%)
#   'hes': P=0.0034 (0.34%)
#   'mist': P=0.0034 (0.34%)
#   'nothing': P=0.0034 (0.34%)
#   'better': P=0.0034 (0.34%)
#   'son': P=0.0034 (0.34%)
#   'carried': P=0.0034 (0.34%)
#   'mother': P=0.0034 (0.34%)
#   'neither': P=0.0034 (0.34%)
#   'thought': P=0.0034 (0.34%)
#   'good': P=0.0034 (0.34%)
#   'licked': P=0.0034 (0.34%)
#   'fell': P=0.0034 (0.34%)
#   'set': P=0.0034 (0.34%)
#   'bring': P=0.0034 (0.34%)
#   'sure': P=0.0034 (0.34%)
#   'held': P=0.0034 (0.34%)
#   'push': P=0.0034 (0.34%)
#   'stand': P=0.0034 (0.34%)
#   'swift': P=0.0034 (0.34%)
#   'sproutlands': P=0.0034 (0.34%)
#   'orchard': P=0.0034 (0.34%)
#   'try': P=0.0034 (0.34%)
#   'get': P=0.0034 (0.34%)
#   'moments': P=0.0034 (0.34%)
#   'one': P=0.0034 (0.34%)
#   'she': P=0.0034 (0.34%)
#   'you': P=0.0034 (0.34%)
#   'baileys': P=0.0034 (0.34%)
#   'doubtless': P=0.0034 (0.34%)
#   'by': P=0.0034 (0.34%)
#   'dangle': P=0.0034 (0.34%)
#   'disappeared': P=0.0034 (0.34%)
#   'ended': P=0.0034 (0.34%)
#   'below': P=0.0034 (0.34%)
#   'what': P=0.0034 (0.34%)
#   'dim': P=0.0034 (0.34%)
#   'its': P=0.0034 (0.34%)
#   'smoking': P=0.0034 (0.34%)
#   'gets': P=0.0034 (0.34%)
#   'sos': P=0.0034 (0.34%)
#   'hew': P=0.0034 (0.34%)
#   'shape': P=0.0034 (0.34%)
#   'come': P=0.0034 (0.34%)
#   'begin': P=0.0034 (0.34%)
#   'it': P=0.0034 (0.34%)
#   'build': P=0.0034 (0.34%)
#   'youthful': P=0.0034 (0.34%)
#   'repented': P=0.0034 (0.34%)
#   'color': P=0.0034 (0.34%)
#   'odor': P=0.0034 (0.34%)
#   'go': P=0.0034 (0.34%)
#   'drouth': P=0.0034 (0.34%)
#   'broken': P=0.0034 (0.34%)
#   'theres': P=0.0034 (0.34%)
#   'original': P=0.0034 (0.34%)
#   'thorn': P=0.0034 (0.34%)
#   'stifling': P=0.0034 (0.34%)
#   'wet': P=0.0034 (0.34%)
#   'sound': P=0.0034 (0.34%)
#   'pair': P=0.0034 (0.34%)
#   'got': P=0.0034 (0.34%)
#   'new': P=0.0034 (0.34%)
#   'wife': P=0.0034 (0.34%)
#   'music': P=0.0034 (0.34%)
#   'give': P=0.0034 (0.34%)
#   'fight': P=0.0034 (0.34%)
#   'feather': P=0.0034 (0.34%)
#   'muffled': P=0.0034 (0.34%)
#   'such': P=0.0034 (0.34%)
#   'moon': P=0.0034 (0.34%)
#   'stars': P=0.0034 (0.34%)
#   'mars': P=0.0034 (0.34%)
#   'jupiter': P=0.0034 (0.34%)
#   'taus': P=0.0034 (0.34%)
#   'stirred': P=0.0034 (0.34%)
#   'under': P=0.0034 (0.34%)
#   'nation': P=0.0034 (0.34%)
#   'though': P=0.0034 (0.34%)
#   'tide': P=0.0034 (0.34%)
#   'wheres': P=0.0034 (0.34%)
#   'gone': P=0.0034 (0.34%)
#   'shell': P=0.0034 (0.34%)
#   'lord': P=0.0034 (0.34%)
#   'where': P=0.0034 (0.34%)
#   'no': P=0.0034 (0.34%)
#   'end': P=0.0034 (0.34%)
#   'after': P=0.0034 (0.34%)
#   'cows': P=0.0034 (0.34%)
#   'pigs': P=0.0034 (0.34%)
#   'like': P=0.0034 (0.34%)
#   'youre': P=0.0034 (0.34%)
#   'turn': P=0.0034 (0.34%)
#   'stop': P=0.0034 (0.34%)
#   'romp': P=0.0034 (0.34%)
#   'not': P=0.0034 (0.34%)
#   'last': P=0.0034 (0.34%)
#   'which': P=0.0034 (0.34%)
#   'sport': P=0.0034 (0.34%)
#
# Selected: 'i' (highest probability: 0.0410)
#
# Step 3: Selecting subsequent words with highest second-order probabilities
# ----------------------------------------------------------------------
#
# Selecting word 3 after ('and', 'i'):
#   'END': P=0.2500 (25.00%)
#   'can': P=0.0833 (8.33%)
#   'dont': P=0.0833 (8.33%)
#   'read': P=0.0833 (8.33%)
#   'know': P=0.0833 (8.33%)
#   'dread': P=0.0833 (8.33%)
#   'thought': P=0.0833 (8.33%)
#   'only': P=0.0833 (8.33%)
#   'have': P=0.0833 (8.33%)
#   'get': P=0.0833 (8.33%)
# Selected: 'END' (highest probability: 0.2500)
#
# END token reached. Line complete.
#
# >>> Generated Line 3: and i
#
# ======================================================================
# GENERATING LINE 4
# ======================================================================
#
# Step 1: Selecting first word with highest initial probability
# ----------------------------------------------------------------------
# Word choices and probabilities:
#   'and': P=0.0898 (8.98%)
#   'i': P=0.0822 (8.22%)
#   'the': P=0.0571 (5.71%)
#   'but': P=0.0355 (3.55%)
#   'to': P=0.0348 (3.48%)
#   'you': P=0.0279 (2.79%)
#   'he': P=0.0237 (2.37%)
#   'a': P=0.0209 (2.09%)
#   'in': P=0.0202 (2.02%)
#   'of': P=0.0202 (2.02%)
#   'that': P=0.0202 (2.02%)
#   'it': P=0.0160 (1.60%)
#   'its': P=0.0146 (1.46%)
#   'they': P=0.0132 (1.32%)
#   'with': P=0.0125 (1.25%)
#   'she': P=0.0118 (1.18%)
#   'we': P=0.0104 (1.04%)
#   'as': P=0.0097 (0.97%)
#   'what': P=0.0097 (0.97%)
#   'so': P=0.0091 (0.91%)
#   'not': P=0.0091 (0.91%)
#   'no': P=0.0091 (0.91%)
#   'then': P=0.0084 (0.84%)
#   'if': P=0.0084 (0.84%)
#   'one': P=0.0077 (0.77%)
# ...
#
# >>> Generated Line 4: and i
#
# ======================================================================
# GENERATING LINE 5
# ======================================================================
#
# Step 1: Selecting first word with highest initial probability
# ----------------------------------------------------------------------
# Word choices and probabilities:
#   'and': P=0.0898 (8.98%)
#   'i': P=0.0822 (8.22%)
#   'the': P=0.0571 (5.71%)
#   'but': P=0.0355 (3.55%)
#   'to': P=0.0348 (3.48%)
#   'you': P=0.0279 (2.79%)
#   'he': P=0.0237 (2.37%)
#   'a': P=0.0209 (2.09%)
#   'in': P=0.0202 (2.02%)
#   'of': P=0.0202 (2.02%)
#   'that': P=0.0202 (2.02%)
#   'it': P=0.0160 (1.60%)
#   'its': P=0.0146 (1.46%)
#   'they': P=0.0132 (1.32%)
#   'with': P=0.0125 (1.25%)
#   'she': P=0.0118 (1.18%)
#   'we': P=0.0104 (1.04%)
#   'as': P=0.0097 (0.97%)
#   'what': P=0.0097 (0.97%)
#   'so': P=0.0091 (0.91%)
#   'not': P=0.0091 (0.91%)
#   'no': P=0.0091 (0.91%)
#   'then': P=0.0084 (0.84%)
#   'if': P=0.0084 (0.84%)
#   'one': P=0.0077 (0.77%)
#   'by': P=0.0077 (0.77%)
#   'hes': P=0.0077 (0.77%)
#   'or': P=0.0077 (0.77%)
#   'on': P=0.0077 (0.77%)
#   'from': P=0.0070 (0.70%)
#   'ill': P=0.0070 (0.70%)
#   'when': P=0.0063 (0.63%)
#   'was': P=0.0063 (0.63%)
#   'son': P=0.0063 (0.63%)
#   'two': P=0.0056 (0.56%)
#   'like': P=0.0056 (0.56%)
#   'all': P=0.0056 (0.56%)
#   'where': P=0.0056 (0.56%)
#   'yes': P=0.0056 (0.56%)
#   'though': P=0.0049 (0.49%)
#   'his': P=0.0049 (0.49%)
#   'my': P=0.0049 (0.49%)
#   'up': P=0.0049 (0.49%)
#   'dont': P=0.0049 (0.49%)
#   'for': P=0.0049 (0.49%)
#   'mother': P=0.0049 (0.49%)
#   'at': P=0.0042 (0.42%)
#   'who': P=0.0042 (0.42%)
#   'how': P=0.0042 (0.42%)
#   'there': P=0.0042 (0.42%)
#   'this': P=0.0042 (0.42%)
#   'john': P=0.0042 (0.42%)
#   'some': P=0.0035 (0.35%)
#   'is': P=0.0035 (0.35%)
#   'im': P=0.0035 (0.35%)
#   'only': P=0.0035 (0.35%)
#   'hed': P=0.0035 (0.35%)
#   'over': P=0.0035 (0.35%)
#   'well': P=0.0035 (0.35%)
#   'toffile': P=0.0035 (0.35%)
#   'thats': P=0.0035 (0.35%)
#   'had': P=0.0028 (0.28%)
#   'oh': P=0.0028 (0.28%)
#   'sometimes': P=0.0028 (0.28%)
#   'ive': P=0.0028 (0.28%)
#   'now': P=0.0028 (0.28%)
#   'come': P=0.0028 (0.28%)
#   'here': P=0.0028 (0.28%)
#   'nor': P=0.0028 (0.28%)
#   'whats': P=0.0028 (0.28%)
#   'yet': P=0.0021 (0.21%)
#   'between': P=0.0021 (0.21%)
#   'half': P=0.0021 (0.21%)
#   'were': P=0.0021 (0.21%)
#   'which': P=0.0021 (0.21%)
#   'lets': P=0.0021 (0.21%)
#   'be': P=0.0021 (0.21%)
#   'take': P=0.0021 (0.21%)
#   'why': P=0.0021 (0.21%)
#   'among': P=0.0021 (0.21%)
#   'shes': P=0.0021 (0.21%)
#   'whose': P=0.0014 (0.14%)
#   'her': P=0.0014 (0.14%)
#   'nothing': P=0.0014 (0.14%)
#   'disturbed': P=0.0014 (0.14%)
#   'once': P=0.0014 (0.14%)
#   'brown': P=0.0014 (0.14%)
#   'upon': P=0.0014 (0.14%)
#   'should': P=0.0014 (0.14%)
#   'until': P=0.0014 (0.14%)
#   'couldnt': P=0.0014 (0.14%)
#   'their': P=0.0014 (0.14%)
#   'has': P=0.0014 (0.14%)
#   'off': P=0.0014 (0.14%)
#   'old': P=0.0014 (0.14%)
#   'sos': P=0.0014 (0.14%)
#   'however': P=0.0014 (0.14%)
#   'perhaps': P=0.0014 (0.14%)
#   'our': P=0.0014 (0.14%)
#   'through': P=0.0014 (0.14%)
#   'except': P=0.0014 (0.14%)
#   'books': P=0.0014 (0.14%)
#   'till': P=0.0014 (0.14%)
#   'than': P=0.0014 (0.14%)
#   'behind': P=0.0014 (0.14%)
#   'tell': P=0.0014 (0.14%)
#   'another': P=0.0014 (0.14%)
#   'before': P=0.0014 (0.14%)
#   'let': P=0.0014 (0.14%)
#   'anyone': P=0.0014 (0.14%)
#   'drawn': P=0.0014 (0.14%)
#   'would': P=0.0014 (0.14%)
#   'under': P=0.0014 (0.14%)
#   'does': P=0.0014 (0.14%)
#   'beyond': P=0.0014 (0.14%)
#   'first': P=0.0014 (0.14%)
#   'bless': P=0.0014 (0.14%)
#   'something': P=0.0014 (0.14%)
#   'call': P=0.0014 (0.14%)
#   'will': P=0.0014 (0.14%)
#   'back': P=0.0014 (0.14%)
#   'still': P=0.0014 (0.14%)
#   'make': P=0.0014 (0.14%)
#   'too': P=0.0014 (0.14%)
#   'havent': P=0.0014 (0.14%)
#   'estelles': P=0.0014 (0.14%)
#   'johns': P=0.0014 (0.14%)
#   'because': P=0.0007 (0.07%)
#   'somewhere': P=0.0007 (0.07%)
#   'natures': P=0.0007 (0.07%)
#   'came': P=0.0007 (0.07%)
#   'proclaimed': P=0.0007 (0.07%)
#   'smoothlaid': P=0.0007 (0.07%)
#   'comes': P=0.0007 (0.07%)
#   'ten': P=0.0007 (0.07%)
#   'lifted': P=0.0007 (0.07%)
#   'transfixed': P=0.0007 (0.07%)
#   'across': P=0.0007 (0.07%)
#   'looked': P=0.0007 (0.07%)
#   'stood': P=0.0007 (0.07%)
#   'me': P=0.0007 (0.07%)
#   'cross': P=0.0007 (0.07%)
#   'describing': P=0.0007 (0.07%)
#   'got': P=0.0007 (0.07%)
#   'walls': P=0.0007 (0.07%)
#   'faster': P=0.0007 (0.07%)
#   'sitting': P=0.0007 (0.07%)
#   'according': P=0.0007 (0.07%)
#   'incredulous': P=0.0007 (0.07%)
#   'wellibe': P=0.0007 (0.07%)
#   'yankees': P=0.0007 (0.07%)
#   'after': P=0.0007 (0.07%)
#   'while': P=0.0007 (0.07%)
#   'bout': P=0.0007 (0.07%)
#   'theyve': P=0.0007 (0.07%)
#   'flattered': P=0.0007 (0.07%)
#   'always': P=0.0007 (0.07%)
#   'theyll': P=0.0007 (0.07%)
#   'voted': P=0.0007 (0.07%)
#   'wentworth': P=0.0007 (0.07%)
#   'rights': P=0.0007 (0.07%)
#   'itd': P=0.0007 (0.07%)
#   'said': P=0.0007 (0.07%)
#   'gnaws': P=0.0007 (0.07%)
#   'last': P=0.0007 (0.07%)
#   'thered': P=0.0007 (0.07%)
#   'someday': P=0.0007 (0.07%)
#   'today': P=0.0007 (0.07%)
#   'huh': P=0.0007 (0.07%)
#   'youve': P=0.0007 (0.07%)
#   'can': P=0.0007 (0.07%)
#   'ascending': P=0.0007 (0.07%)
#   'hadnt': P=0.0007 (0.07%)
#   'look': P=0.0007 (0.07%)
#   'excuse': P=0.0007 (0.07%)
#   'life': P=0.0007 (0.07%)
#   'enough': P=0.0007 (0.07%)
#   'unfortunately': P=0.0007 (0.07%)
#   'boys': P=0.0007 (0.07%)
#   'shatter': P=0.0007 (0.07%)
#   'tried': P=0.0007 (0.07%)
#   'having': P=0.0007 (0.07%)
#   'goodlooking': P=0.0007 (0.07%)
#   'both': P=0.0007 (0.07%)
#   'legitimately': P=0.0007 (0.07%)
#   'crosslegged': P=0.0007 (0.07%)
#   'alias': P=0.0007 (0.07%)
#   'about': P=0.0007 (0.07%)
#   'theres': P=0.0007 (0.07%)
#   'give': P=0.0007 (0.07%)
#   'thrown': P=0.0007 (0.07%)
#   'unless': P=0.0007 (0.07%)
#   'summoning': P=0.0007 (0.07%)
#   'whos': P=0.0007 (0.07%)
#   'done': P=0.0007 (0.07%)
#   'rather': P=0.0007 (0.07%)
#   'against': P=0.0007 (0.07%)
#   'halting': P=0.0007 (0.07%)
#   'never': P=0.0007 (0.07%)
#   'right': P=0.0007 (0.07%)
#   'father': P=0.0007 (0.07%)
#   'especially': P=0.0007 (0.07%)
#   'might': P=0.0007 (0.07%)
#   'struck': P=0.0007 (0.07%)
#   'began': P=0.0007 (0.07%)
#   'waiting': P=0.0007 (0.07%)
#   'flashed': P=0.0007 (0.07%)
#   'smoke': P=0.0007 (0.07%)
#   'hand': P=0.0007 (0.07%)
#   'stillgoing': P=0.0007 (0.07%)
#   'almost': P=0.0007 (0.07%)
#   'quick': P=0.0007 (0.07%)
#   'brushing': P=0.0007 (0.07%)
#   'o': P=0.0007 (0.07%)
#   'wed': P=0.0007 (0.07%)
#   'could': P=0.0007 (0.07%)
#   'ancestral': P=0.0007 (0.07%)
#   'someone': P=0.0007 (0.07%)
#   'thence': P=0.0007 (0.07%)
#   'made': P=0.0007 (0.07%)
#   'are': P=0.0007 (0.07%)
#   'strolled': P=0.0007 (0.07%)
#   'provision': P=0.0007 (0.07%)
#   'stark': P=0.0007 (0.07%)
#   'several': P=0.0007 (0.07%)
#   'just': P=0.0007 (0.07%)
#   'bowed': P=0.0007 (0.07%)
#   'four': P=0.0007 (0.07%)
#   'dyou': P=0.0007 (0.07%)
#   'studying': P=0.0007 (0.07%)
#   'heres': P=0.0007 (0.07%)
#   'making': P=0.0007 (0.07%)
#   'see': P=0.0007 (0.07%)
#   'strung': P=0.0007 (0.07%)
#   'speaking': P=0.0007 (0.07%)
#   'strangely': P=0.0007 (0.07%)
#   'nine': P=0.0007 (0.07%)
#   'anything': P=0.0007 (0.07%)
#   'folks': P=0.0007 (0.07%)
#   'mebbe': P=0.0007 (0.07%)
#   'more': P=0.0007 (0.07%)
#   'nowhere': P=0.0007 (0.07%)
#   'builder': P=0.0007 (0.07%)
#   'whatever': P=0.0007 (0.07%)
#   'inscription': P=0.0007 (0.07%)
#   'winds': P=0.0007 (0.07%)
#   'moisture': P=0.0007 (0.07%)
#   'heaven': P=0.0007 (0.07%)
#   'may': P=0.0007 (0.07%)
#   'great': P=0.0007 (0.07%)
#   'long': P=0.0007 (0.07%)
#   'besides': P=0.0007 (0.07%)
#   'charge': P=0.0007 (0.07%)
#   'someones': P=0.0007 (0.07%)
#   'into': P=0.0007 (0.07%)
#   'weep': P=0.0007 (0.07%)
#   'your': P=0.0007 (0.07%)
#   'cold': P=0.0007 (0.07%)
#   'drink': P=0.0007 (0.07%)
#   'wherever': P=0.0007 (0.07%)
#   'birch': P=0.0007 (0.07%)
#   'time': P=0.0007 (0.07%)
#   'small': P=0.0007 (0.07%)
#   'out': P=0.0007 (0.07%)
#   'awake': P=0.0007 (0.07%)
#   'wishing': P=0.0007 (0.07%)
#   'saturn': P=0.0007 (0.07%)
#   'speculation': P=0.0007 (0.07%)
#   'theirs': P=0.0007 (0.07%)
#   'uttered': P=0.0007 (0.07%)
#   'trembled': P=0.0007 (0.07%)
#   'appear': P=0.0007 (0.07%)
#   'around': P=0.0007 (0.07%)
#   'since': P=0.0007 (0.07%)
#   'lord': P=0.0007 (0.07%)
#   'weve': P=0.0007 (0.07%)
#   'left': P=0.0007 (0.07%)
#   'hell': P=0.0007 (0.07%)
#   'skyhigh': P=0.0007 (0.07%)
#   'arent': P=0.0007 (0.07%)
#   'better': P=0.0007 (0.07%)
#   'reason': P=0.0007 (0.07%)
#   'such': P=0.0007 (0.07%)
#   'twas': P=0.0007 (0.07%)
#   'estelle': P=0.0007 (0.07%)
#   'farmers': P=0.0007 (0.07%)
#   'full': P=0.0007 (0.07%)
#   'moving': P=0.0007 (0.07%)
#   'nothings': P=0.0007 (0.07%)
#   'twenty': P=0.0007 (0.07%)
#   'receipted': P=0.0007 (0.07%)
#   'wampum': P=0.0007 (0.07%)
#   'cant': P=0.0007 (0.07%)
#   'being': P=0.0007 (0.07%)
#   'oho': P=0.0007 (0.07%)
#   'bad': P=0.0007 (0.07%)
#   'nonsense': P=0.0007 (0.07%)
#   'whod': P=0.0007 (0.07%)
#   'say': P=0.0007 (0.07%)
#   'youll': P=0.0007 (0.07%)
#   'coming': P=0.0007 (0.07%)
#   'isnt': P=0.0007 (0.07%)
#   'do': P=0.0007 (0.07%)
#   'content': P=0.0007 (0.07%)
#   'an': P=0.0007 (0.07%)
#
# Selected: 'and' (highest probability: 0.0898)
#
# Step 2: Selecting second word with highest first-order probability
# ----------------------------------------------------------------------
# After 'and', possible words:
#   'i': P=0.0410 (4.10%)
#   'the': P=0.0410 (4.10%)
#   'then': P=0.0239 (2.39%)
#   'tell': P=0.0137 (1.37%)
#   'see': P=0.0137 (1.37%)
#   'when': P=0.0102 (1.02%)
#   'how': P=0.0102 (1.02%)
#   'hold': P=0.0102 (1.02%)
#   'swollen': P=0.0102 (1.02%)
#   'a': P=0.0102 (1.02%)
#   'all': P=0.0102 (1.02%)
#   'in': P=0.0102 (1.02%)
#   'sorry': P=0.0068 (0.68%)
#   'be': P=0.0068 (0.68%)
#   'both': P=0.0068 (0.68%)
#   'that': P=0.0068 (0.68%)
#   'miles': P=0.0068 (0.68%)
#   'now': P=0.0068 (0.68%)
#   'put': P=0.0068 (0.68%)
#   'since': P=0.0068 (0.68%)
#   'there': P=0.0068 (0.68%)
#   'he': P=0.0068 (0.68%)
#   'this': P=0.0068 (0.68%)
#   'if': P=0.0068 (0.68%)
#   'had': P=0.0068 (0.68%)
#   'make': P=0.0068 (0.68%)
#   'kick': P=0.0068 (0.68%)
#   'thats': P=0.0068 (0.68%)
#   'spoke': P=0.0068 (0.68%)
#   'save': P=0.0068 (0.68%)
#   'left': P=0.0068 (0.68%)
#   'his': P=0.0068 (0.68%)
#   'headboard': P=0.0068 (0.68%)
#   'buried': P=0.0068 (0.68%)
#   'shouted': P=0.0068 (0.68%)
#   'sit': P=0.0068 (0.68%)
#   'take': P=0.0068 (0.68%)
#   'lift': P=0.0068 (0.68%)
#   'those': P=0.0068 (0.68%)
#   'perhaps': P=0.0068 (0.68%)
#   'still': P=0.0068 (0.68%)
#   'your': P=0.0068 (0.68%)
#   'besides': P=0.0068 (0.68%)
#   'we': P=0.0068 (0.68%)
#   'looked': P=0.0034 (0.34%)
#   'having': P=0.0034 (0.34%)
#   'wanted': P=0.0034 (0.34%)
#   'ages': P=0.0034 (0.34%)
#   'frozen': P=0.0034 (0.34%)
#   'downy': P=0.0034 (0.34%)
#   'deep': P=0.0034 (0.34%)
#   'would': P=0.0034 (0.34%)
#   'back': P=0.0034 (0.34%)
#   'dropped': P=0.0034 (0.34%)
#   'stopped': P=0.0034 (0.34%)
#   'further': P=0.0034 (0.34%)
#   'caught': P=0.0034 (0.34%)
#   'threw': P=0.0034 (0.34%)
#   'wetkneed': P=0.0034 (0.34%)
#   'birds': P=0.0034 (0.34%)
#   'redoubling': P=0.0034 (0.34%)
#   'twitter': P=0.0034 (0.34%)
#   'suddenly': P=0.0034 (0.34%)
#   'scuttled': P=0.0034 (0.34%)
#   'side': P=0.0034 (0.34%)
#   'scurf': P=0.0034 (0.34%)
#   'weary': P=0.0034 (0.34%)
#   'overheated': P=0.0034 (0.34%)
#   'rested': P=0.0034 (0.34%)
#   'raised': P=0.0034 (0.34%)
#   'whats': P=0.0034 (0.34%)
#   'many': P=0.0034 (0.34%)
#   'barn': P=0.0034 (0.34%)
#   'blew': P=0.0034 (0.34%)
#   'stamped': P=0.0034 (0.34%)
#   'said': P=0.0034 (0.34%)
#   'sometimes': P=0.0034 (0.34%)
#   'END': P=0.0034 (0.34%)
#   'some': P=0.0034 (0.34%)
#   'made': P=0.0034 (0.34%)
#   'came': P=0.0034 (0.34%)
#   'politician': P=0.0034 (0.34%)
#   'took': P=0.0034 (0.34%)
#   'warrens': P=0.0034 (0.34%)
#   'thatd': P=0.0034 (0.34%)
#   'rode': P=0.0034 (0.34%)
#   'bones': P=0.0034 (0.34%)
#   'leave': P=0.0034 (0.34%)
#   'as': P=0.0034 (0.34%)
#   'posts': P=0.0034 (0.34%)
#   'fences': P=0.0034 (0.34%)
#   'from': P=0.0034 (0.34%)
#   'snow': P=0.0034 (0.34%)
#   'full': P=0.0034 (0.34%)
#   'experts': P=0.0034 (0.34%)
#   'show': P=0.0034 (0.34%)
#   'built': P=0.0034 (0.34%)
#   'emptied': P=0.0034 (0.34%)
#   'forty': P=0.0034 (0.34%)
#   'were': P=0.0034 (0.34%)
#   'on': P=0.0034 (0.34%)
#   'anyway': P=0.0034 (0.34%)
#   'bottle': P=0.0034 (0.34%)
#   'keep': P=0.0034 (0.34%)
#   'wrote': P=0.0034 (0.34%)
#   'taken': P=0.0034 (0.34%)
#   'bad': P=0.0034 (0.34%)
#   'lead': P=0.0034 (0.34%)
#   'opening': P=0.0034 (0.34%)
#   'lie': P=0.0034 (0.34%)
#   'bushes': P=0.0034 (0.34%)
#   'stroked': P=0.0034 (0.34%)
#   'me': P=0.0034 (0.34%)
#   'between': P=0.0034 (0.34%)
#   'wont': P=0.0034 (0.34%)
#   'hes': P=0.0034 (0.34%)
#   'mist': P=0.0034 (0.34%)
#   'nothing': P=0.0034 (0.34%)
#   'better': P=0.0034 (0.34%)
#   'son': P=0.0034 (0.34%)
#   'carried': P=0.0034 (0.34%)
#   'mother': P=0.0034 (0.34%)
#   'neither': P=0.0034 (0.34%)
#   'thought': P=0.0034 (0.34%)
#   'good': P=0.0034 (0.34%)
#   'licked': P=0.0034 (0.34%)
#   'fell': P=0.0034 (0.34%)
#   'set': P=0.0034 (0.34%)
#   'bring': P=0.0034 (0.34%)
#   'sure': P=0.0034 (0.34%)
#   'held': P=0.0034 (0.34%)
#   'push': P=0.0034 (0.34%)
#   'stand': P=0.0034 (0.34%)
#   'swift': P=0.0034 (0.34%)
#   'sproutlands': P=0.0034 (0.34%)
#   'orchard': P=0.0034 (0.34%)
#   'try': P=0.0034 (0.34%)
#   'get': P=0.0034 (0.34%)
#   'moments': P=0.0034 (0.34%)
#   'one': P=0.0034 (0.34%)
#   'she': P=0.0034 (0.34%)
#   'you': P=0.0034 (0.34%)
#   'baileys': P=0.0034 (0.34%)
#   'doubtless': P=0.0034 (0.34%)
#   'by': P=0.0034 (0.34%)
#   'dangle': P=0.0034 (0.34%)
#   'disappeared': P=0.0034 (0.34%)
#   'ended': P=0.0034 (0.34%)
#   'below': P=0.0034 (0.34%)
#   'what': P=0.0034 (0.34%)
#   'dim': P=0.0034 (0.34%)
#   'its': P=0.0034 (0.34%)
#   'smoking': P=0.0034 (0.34%)
#   'gets': P=0.0034 (0.34%)
#   'sos': P=0.0034 (0.34%)
#   'hew': P=0.0034 (0.34%)
#   'shape': P=0.0034 (0.34%)
#   'come': P=0.0034 (0.34%)
#   'begin': P=0.0034 (0.34%)
#   'it': P=0.0034 (0.34%)
#   'build': P=0.0034 (0.34%)
#   'youthful': P=0.0034 (0.34%)
#   'repented': P=0.0034 (0.34%)
#   'color': P=0.0034 (0.34%)
#   'odor': P=0.0034 (0.34%)
#   'go': P=0.0034 (0.34%)
#   'drouth': P=0.0034 (0.34%)
#   'broken': P=0.0034 (0.34%)
#   'theres': P=0.0034 (0.34%)
#   'original': P=0.0034 (0.34%)
#   'thorn': P=0.0034 (0.34%)
#   'stifling': P=0.0034 (0.34%)
#   'wet': P=0.0034 (0.34%)
#   'sound': P=0.0034 (0.34%)
#   'pair': P=0.0034 (0.34%)
#   'got': P=0.0034 (0.34%)
#   'new': P=0.0034 (0.34%)
#   'wife': P=0.0034 (0.34%)
#   'music': P=0.0034 (0.34%)
#   'give': P=0.0034 (0.34%)
#   'fight': P=0.0034 (0.34%)
#   'feather': P=0.0034 (0.34%)
#   'muffled': P=0.0034 (0.34%)
#   'such': P=0.0034 (0.34%)
#   'moon': P=0.0034 (0.34%)
#   'stars': P=0.0034 (0.34%)
#   'mars': P=0.0034 (0.34%)
#   'jupiter': P=0.0034 (0.34%)
#   'taus': P=0.0034 (0.34%)
#   'stirred': P=0.0034 (0.34%)
#   'under': P=0.0034 (0.34%)
#   'nation': P=0.0034 (0.34%)
#   'though': P=0.0034 (0.34%)
#   'tide': P=0.0034 (0.34%)
#   'wheres': P=0.0034 (0.34%)
#   'gone': P=0.0034 (0.34%)
#   'shell': P=0.0034 (0.34%)
#   'lord': P=0.0034 (0.34%)
#   'where': P=0.0034 (0.34%)
#   'no': P=0.0034 (0.34%)
#   'end': P=0.0034 (0.34%)
#   'after': P=0.0034 (0.34%)
#   'cows': P=0.0034 (0.34%)
#   'pigs': P=0.0034 (0.34%)
#   'like': P=0.0034 (0.34%)
#   'youre': P=0.0034 (0.34%)
#   'turn': P=0.0034 (0.34%)
#   'stop': P=0.0034 (0.34%)
#   'romp': P=0.0034 (0.34%)
#   'not': P=0.0034 (0.34%)
#   'last': P=0.0034 (0.34%)
#   'which': P=0.0034 (0.34%)
#   'sport': P=0.0034 (0.34%)
#
# Selected: 'i' (highest probability: 0.0410)
#
# Step 3: Selecting subsequent words with highest second-order probabilities
# ----------------------------------------------------------------------
#
# Selecting word 3 after ('and', 'i'):
#   'END': P=0.2500 (25.00%)
#   'can': P=0.0833 (8.33%)
#   'dont': P=0.0833 (8.33%)
#   'read': P=0.0833 (8.33%)
#   'know': P=0.0833 (8.33%)
#   'dread': P=0.0833 (8.33%)
#   'thought': P=0.0833 (8.33%)
#   'only': P=0.0833 (8.33%)
#   'have': P=0.0833 (8.33%)
#   'get': P=0.0833 (8.33%)
# Selected: 'END' (highest probability: 0.2500)
#
# END token reached. Line complete.
#
# >>> Generated Line 5: and i
#
# ======================================================================
# GENERATED POEM (METHOD B - DETERMINISTIC):
# ======================================================================
# and i
# and i
# and i
# and i
# and i
# ======================================================================

# %% [markdown]
# ## Final Comparison

# %%
print("\nMethod A (Cumulative Probability - Random):")
print("-" * 70)
for line in generated_poem_a:
    print(line)

print("\n" + "="*70)
print("\nMethod B (Deterministic - Highest Probability):")
print("-" * 70)
for line in generated_poem_b:
    print(line)
# Out:
# Method A (Cumulative Probability - Random):
# ----------------------------------------------------------------------
# the poetess had sighed i knew there must be something
# a stricken bird
# but he didnt enter
# how men will be likely to regard as sacred
# he ever voted
#
# ======================================================================
#
# Method B (Deterministic - Highest Probability):
# ----------------------------------------------------------------------
# and i
# and i
# and i
# and i
# and i
